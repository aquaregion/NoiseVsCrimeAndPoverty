# %%
from numpy import linspace, zeros, cumsum, sqrt, ones, where, mean, std, unique, correlate, corrcoef
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import t
import csv
# %pylab inline
import pyfpgrowth
import apyori
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ###Franco La Bruna & Yuchen Zheng
# ###CSC 440 Final Project
# #Pattern Mining of New York City Data

# %% [markdown]
# ###Note
# To run PyFPGrowth, you have to install the PyFPGrowth package on your computer. Check the folder "fp-growth-master" for details.

# %%
pd.__version__
# Out:
# '0.19.1'

# %%
directory = ""
df = pd.read_csv(directory+"newfinal.csv",sep = '\t')
df['Created_Date'] =pd.to_datetime(df.Created_Date)
df['Neighborhood'] = 'NGHBR: '+df['Neighborhood'].astype(str)
df = df.drop('City',1)
year2010 = df.loc[df["Created_Date"].dt.year == 2010] 
year2011 = df.loc[df["Created_Date"].dt.year == 2011] 
year2012 = df.loc[df["Created_Date"].dt.year == 2012] 
year2013 = df.loc[df["Created_Date"].dt.year == 2013] 
year2014 = df.loc[df["Created_Date"].dt.year == 2014] 
year2015 = df.loc[df["Created_Date"].dt.year == 2015]
#then you can check the size of for example, 2010's 
year2010.shape
#save them into new csv files:
directory1 = ""
year2010.to_csv(directory1+'year2010.csv', sep = "\t")
year2011.to_csv(directory1+'year2011.csv', sep = "\t")
year2012.to_csv(directory1+'year2012.csv', sep = "\t")
year2013.to_csv(directory1+'year2013.csv', sep = "\t")
year2014.to_csv(directory1+'year2014.csv', sep = "\t")
year2015.to_csv(directory1+'year2015.csv', sep = "\t")

# %%
def mine_patterns(data,min_sup,min_conf,filename):
    # Helper function that finds frequent patterns and association rules
    # and saves the results as .csv files.
    thresh = min_sup*len(data)
    pats = pyfpgrowth.find_frequent_patterns(data, thresh)
    norm_pats = {k: v / len(data) for k, v in pats.items()}
    patterns = sorted(norm_pats.items(), key=lambda x: x[1],reverse=True)
    rules1 = pyfpgrowth.generate_association_rules(pats, 0.7)
    rules_sorted1 = sorted(rules1.items(), key=lambda x: x[1],reverse=True)
    directory = "e:/Franco/Documents/DataMining/"
    with open(directory1+filename+'_patterns.csv', 'w', newline='\n') as csvfile:
        filewriter = csv.writer(csvfile)
        filewriter.writerows(patterns)
    with open(directory1+filename+'_rules.csv', 'w', newline='\n') as csvfile:
        filewriter = csv.writer(csvfile)
        filewriter.writerows(rules_sorted1)
    return patterns,rules_sorted1

# %%
thresh = 0.1

# %%
df
# Out:
#          Unnamed: 0         Neighborhood        Created_Date  \
# 0                 0  NGHBR: Borough Park 2010-01-01 00:03:46
# 1                 1  NGHBR: Borough Park 2010-01-01 00:36:01
# 2                 2  NGHBR: Borough Park 2010-01-01 01:21:11
# 3                 3  NGHBR: Borough Park 2010-01-01 02:14:21
# 4                 4  NGHBR: Borough Park 2010-01-01 02:59:07
# 5                 5  NGHBR: Borough Park 2010-01-01 03:35:54
# 6                 6  NGHBR: Borough Park 2010-01-01 15:48:01
# 7                 7  NGHBR: Borough Park 2010-01-01 20:34:37
# 8                 8  NGHBR: Borough Park 2010-01-01 22:33:15
# 9                 9  NGHBR: Borough Park 2010-01-02 07:52:38
# 10               10  NGHBR: Borough Park 2010-01-02 12:43:44
# 11               11  NGHBR: Borough Park 2010-01-03 10:43:41
# 12               12  NGHBR: Borough Park 2010-01-03 10:53:16
# 13               13  NGHBR: Borough Park 2010-01-05 01:41:00
# 14               14  NGHBR: Borough Park 2010-01-05 11:03:22
# 15               15  NGHBR: Borough Park 2010-01-06 09:16:12
# 16               16  NGHBR: Borough Park 2010-01-06 11:11:00
# 17               17  NGHBR: Borough Park 2010-01-07 09:44:15
# 18               18  NGHBR: Borough Park 2010-01-07 15:12:25
# 19               19  NGHBR: Borough Park 2010-01-07 23:38:50
# 20               20  NGHBR: Borough Park 2010-01-08 02:42:50
# 21               21  NGHBR: Borough Park 2010-01-08 03:05:49
# 22               22  NGHBR: Borough Park 2010-01-08 21:46:24
# 23               23  NGHBR: Borough Park 2010-01-08 22:11:17
# 24               24  NGHBR: Borough Park 2010-01-08 23:48:50
# 25               25  NGHBR: Borough Park 2010-01-09 00:29:37
# 26               26  NGHBR: Borough Park 2010-01-09 01:05:37
# 27               27  NGHBR: Borough Park 2010-01-09 03:05:28
# 28               28  NGHBR: Borough Park 2010-01-09 05:22:45
# 29               29  NGHBR: Borough Park 2010-01-09 20:40:10
# ...             ...                  ...                 ...
# 1539552     1539552     NGHBR: Rockaways 2014-08-17 10:47:00
# 1539553     1539553     NGHBR: Rockaways 2014-08-19 13:38:40
# 1539554     1539554     NGHBR: Rockaways 2015-03-31 17:15:36
# 1539555     1539555     NGHBR: Rockaways 2015-04-06 23:13:19
# 1539556     1539556     NGHBR: Rockaways 2015-05-04 02:06:00
# 1539557     1539557     NGHBR: Rockaways 2015-07-01 20:15:06
# 1539558     1539558     NGHBR: Rockaways 2015-07-03 13:27:00
# 1539559     1539559     NGHBR: Rockaways 2015-07-03 13:37:00
# 1539560     1539560     NGHBR: Rockaways 2015-08-28 23:01:21
# 1539561     1539561     NGHBR: Rockaways 2015-09-12 23:55:26
# 1539562     1539562     NGHBR: Rockaways 2015-09-13 10:19:01
# 1539563     1539563     NGHBR: Rockaways 2015-09-15 23:16:42
# 1539564     1539564     NGHBR: Rockaways 2015-10-26 21:56:22
# 1539565     1539565     NGHBR: Rockaways 2015-12-11 13:58:46
# 1539566     1539566           NGHBR: nan 2010-06-25 10:46:13
# 1539567     1539567           NGHBR: nan 2010-07-24 23:15:35
# 1539568     1539568           NGHBR: nan 2011-07-20 23:02:25
# 1539569     1539569           NGHBR: nan 2012-01-28 05:40:44
# 1539570     1539570           NGHBR: nan 2012-05-13 00:03:51
# 1539571     1539571           NGHBR: nan 2012-05-13 01:51:03
# 1539572     1539572           NGHBR: nan 2012-06-10 18:27:47
# 1539573     1539573           NGHBR: nan 2012-06-10 18:33:52
# 1539574     1539574           NGHBR: nan 2013-05-31 20:35:19
# 1539575     1539575           NGHBR: nan 2014-05-08 07:20:00
# 1539576     1539576           NGHBR: nan 2014-05-24 23:10:58
# 1539577     1539577           NGHBR: nan 2015-03-22 16:11:15
# 1539578     1539578           NGHBR: nan 2015-05-09 23:12:07
# 1539579     1539579           NGHBR: nan 2015-09-26 16:58:51
# 1539580     1539580           NGHBR: nan 2015-10-11 18:37:08
# 1539581     1539581           NGHBR: nan 2015-12-06 17:26:22
#
#                   Complaint Type  \
# 0            Noise - Residential
# 1             Noise - Commercial
# 2             Noise - Commercial
# 3             Noise - Commercial
# 4            Noise - Residential
# 5             Noise - Commercial
# 6            Noise - Residential
# 7            Noise - Residential
# 8            Noise - Residential
# 9            Noise - Residential
# 10           Noise - Residential
# 11           Noise - Residential
# 12           Noise - Residential
# 13                         Noise
# 14           Noise - Residential
# 15           Noise - Residential
# 16                         Noise
# 17           Noise - Residential
# 18           Noise - Residential
# 19           Noise - Residential
# 20           Noise - Residential
# 21           Noise - Residential
# 22           Noise - Residential
# 23           Noise - Residential
# 24           Noise - Residential
# 25           Noise - Residential
# 26           Noise - Residential
# 27           Noise - Residential
# 28               Noise - Vehicle
# 29           Noise - Residential
# ...                          ...
# 1539552                    Noise
# 1539553       Noise - Commercial
# 1539554      Noise - Residential
# 1539555      Noise - Residential
# 1539556                    Noise
# 1539557       Noise - Commercial
# 1539558   Collection Truck Noise
# 1539559                    Noise
# 1539560       Noise - Commercial
# 1539561          Noise - Vehicle
# 1539562       Noise - Commercial
# 1539563       Noise - Commercial
# 1539564      Noise - Residential
# 1539565  Noise - Street/Sidewalk
# 1539566  Noise - Street/Sidewalk
# 1539567      Noise - Residential
# 1539568      Noise - Residential
# 1539569      Noise - Residential
# 1539570             Noise Survey
# 1539571             Noise Survey
# 1539572             Noise Survey
# 1539573             Noise Survey
# 1539574      Noise - Residential
# 1539575                    Noise
# 1539576      Noise - Residential
# 1539577          Noise - Vehicle
# 1539578      Noise - Residential
# 1539579          Noise - Vehicle
# 1539580       Noise - Commercial
# 1539581          Noise - Vehicle
#
#                                                 Descriptor  \
# 0                                          Loud Television
# 1                                         Loud Music/Party
# 2                                         Loud Music/Party
# 3                                         Loud Music/Party
# 4                                         Loud Music/Party
# 5                                             Loud Talking
# 6                                         Loud Music/Party
# 7                                         Loud Music/Party
# 8                                             Loud Talking
# 9                                         Banging/Pounding
# 10                                        Loud Music/Party
# 11                                            Loud Talking
# 12                                        Banging/Pounding
# 13       Noise: Air Condition/Ventilation Equip, Reside...
# 14                                        Loud Music/Party
# 15                                        Banging/Pounding
# 16                       Horn Honking Sign Requested (NR9)
# 17                                        Banging/Pounding
# 18                                         Loud Television
# 19                                        Loud Music/Party
# 20                                        Loud Music/Party
# 21                                        Banging/Pounding
# 22                                        Banging/Pounding
# 23                                        Loud Music/Party
# 24                                        Banging/Pounding
# 25                                        Banging/Pounding
# 26                                        Loud Music/Party
# 27                                        Loud Music/Party
# 28                                           Engine Idling
# 29                                        Loud Music/Party
# ...                                                    ...
# 1539552               Noise: Boat(Engine,Music,Etc) (NR10)
# 1539553                                   Loud Music/Party
# 1539554                                   Loud Music/Party
# 1539555                                   Loud Music/Party
# 1539556                        Noise: Jack Hammering (NC2)
# 1539557                                    Car/Truck Music
# 1539558                          21 Collection Truck Noise
# 1539559                 Noise: Private Carting Noise (NQ1)
# 1539560                                   Loud Music/Party
# 1539561                                    Car/Truck Music
# 1539562                                   Loud Music/Party
# 1539563                                   Loud Music/Party
# 1539564                                   Banging/Pounding
# 1539565                                   Loud Music/Party
# 1539566                                       Loud Talking
# 1539567                                   Loud Music/Party
# 1539568                                       Loud Talking
# 1539569                                   Banging/Pounding
# 1539570                               People Created Noise
# 1539571                               People Created Noise
# 1539572                               People Created Noise
# 1539573                               People Created Noise
# 1539574                                   Loud Music/Party
# 1539575       Noise: Construction Before/After Hours (NM1)
# 1539576                                   Loud Music/Party
# 1539577                                     Car/Truck Horn
# 1539578                                   Loud Music/Party
# 1539579                                    Car/Truck Music
# 1539580                                   Banging/Pounding
# 1539581                                      Engine Idling
#
#                       Location Type  Zip Code   Borough  Precinct  \
# 0        Residential Building/House     11230  BROOKLYN        70
# 1                  Store/Commercial     11230  BROOKLYN        70
# 2                  Store/Commercial     11230  BROOKLYN        70
# 3                  Store/Commercial     11230  BROOKLYN        70
# 4        Residential Building/House     11230  BROOKLYN        70
# 5                  Store/Commercial     11230  BROOKLYN        70
# 6        Residential Building/House     11230  BROOKLYN        70
# 7        Residential Building/House     11230  BROOKLYN        70
# 8        Residential Building/House     11230  BROOKLYN        70
# 9        Residential Building/House     11230  BROOKLYN        70
# 10       Residential Building/House     11230  BROOKLYN        70
# 11       Residential Building/House     11230  BROOKLYN        70
# 12       Residential Building/House     11230  BROOKLYN        70
# 13                              NaN     11230  BROOKLYN        70
# 14       Residential Building/House     11230  BROOKLYN        70
# 15       Residential Building/House     11230  BROOKLYN        70
# 16                              NaN     11230  BROOKLYN        70
# 17       Residential Building/House     11230  BROOKLYN        70
# 18       Residential Building/House     11230  BROOKLYN        70
# 19       Residential Building/House     11230  BROOKLYN        70
# 20       Residential Building/House     11230  BROOKLYN        70
# 21       Residential Building/House     11230  BROOKLYN        70
# 22       Residential Building/House     11230  BROOKLYN        70
# 23       Residential Building/House     11230  BROOKLYN        70
# 24       Residential Building/House     11230  BROOKLYN        70
# 25       Residential Building/House     11230  BROOKLYN        70
# 26       Residential Building/House     11230  BROOKLYN        70
# 27       Residential Building/House     11230  BROOKLYN        70
# 28                  Street/Sidewalk     11230  BROOKLYN        70
# 29       Residential Building/House     11230  BROOKLYN        70
# ...                             ...       ...       ...       ...
# 1539552                         NaN     11697    QUEENS       100
# 1539553            Store/Commercial     11697    QUEENS       100
# 1539554  Residential Building/House     11697    QUEENS       100
# 1539555  Residential Building/House     11697    QUEENS       100
# 1539556                         NaN     11697    QUEENS       100
# 1539557            Store/Commercial     11697    QUEENS       100
# 1539558                    Sidewalk     11697    QUEENS       100
# 1539559                         NaN     11697    QUEENS       100
# 1539560         Club/Bar/Restaurant     11697    QUEENS       100
# 1539561             Street/Sidewalk     11697    QUEENS       100
# 1539562            Store/Commercial     11697    QUEENS       100
# 1539563         Club/Bar/Restaurant     11697    QUEENS       100
# 1539564  Residential Building/House     11697    QUEENS       100
# 1539565             Street/Sidewalk     11697    QUEENS       100
# 1539566             Street/Sidewalk     11430    QUEENS       113
# 1539567  Residential Building/House     11430    QUEENS       113
# 1539568  Residential Building/House     11430    QUEENS       113
# 1539569  Residential Building/House     11430    QUEENS       113
# 1539570                        Home     11430    QUEENS       113
# 1539571                        Home     11430    QUEENS       113
# 1539572                        Home     11430    QUEENS       113
# 1539573                        Home     11430    QUEENS       113
# 1539574  Residential Building/House     11430    QUEENS       113
# 1539575                         NaN     11430    QUEENS       113
# 1539576  Residential Building/House     11430    QUEENS       113
# 1539577             Street/Sidewalk     11430    QUEENS       113
# 1539578  Residential Building/House     11430    QUEENS       113
# 1539579             Street/Sidewalk     11430    QUEENS       113
# 1539580            Store/Commercial     11430    QUEENS       113
# 1539581             Street/Sidewalk     11430    QUEENS       113
#
#                          Population  Year      Violence Binning  \
# 0        Population Higher than IQR  2010   VC Within Lower IQR
# 1        Population Higher than IQR  2010   VC Within Lower IQR
# 2        Population Higher than IQR  2010   VC Within Lower IQR
# 3        Population Higher than IQR  2010   VC Within Lower IQR
# 4        Population Higher than IQR  2010   VC Within Lower IQR
# 5        Population Higher than IQR  2010   VC Within Lower IQR
# 6        Population Higher than IQR  2010   VC Within Lower IQR
# 7        Population Higher than IQR  2010   VC Within Lower IQR
# 8        Population Higher than IQR  2010   VC Within Lower IQR
# 9        Population Higher than IQR  2010   VC Within Lower IQR
# 10       Population Higher than IQR  2010   VC Within Lower IQR
# 11       Population Higher than IQR  2010   VC Within Lower IQR
# 12       Population Higher than IQR  2010   VC Within Lower IQR
# 13       Population Higher than IQR  2010   VC Within Lower IQR
# 14       Population Higher than IQR  2010   VC Within Lower IQR
# 15       Population Higher than IQR  2010   VC Within Lower IQR
# 16       Population Higher than IQR  2010   VC Within Lower IQR
# 17       Population Higher than IQR  2010   VC Within Lower IQR
# 18       Population Higher than IQR  2010   VC Within Lower IQR
# 19       Population Higher than IQR  2010   VC Within Lower IQR
# 20       Population Higher than IQR  2010   VC Within Lower IQR
# 21       Population Higher than IQR  2010   VC Within Lower IQR
# 22       Population Higher than IQR  2010   VC Within Lower IQR
# 23       Population Higher than IQR  2010   VC Within Lower IQR
# 24       Population Higher than IQR  2010   VC Within Lower IQR
# 25       Population Higher than IQR  2010   VC Within Lower IQR
# 26       Population Higher than IQR  2010   VC Within Lower IQR
# 27       Population Higher than IQR  2010   VC Within Lower IQR
# 28       Population Higher than IQR  2010   VC Within Lower IQR
# 29       Population Higher than IQR  2010   VC Within Lower IQR
# ...                             ...   ...                   ...
# 1539552   Population Lower than IQR  2014     VC Lower than IQR
# 1539553   Population Lower than IQR  2014     VC Lower than IQR
# 1539554   Population Lower than IQR  2015     VC Lower than IQR
# 1539555   Population Lower than IQR  2015     VC Lower than IQR
# 1539556   Population Lower than IQR  2015     VC Lower than IQR
# 1539557   Population Lower than IQR  2015     VC Lower than IQR
# 1539558   Population Lower than IQR  2015     VC Lower than IQR
# 1539559   Population Lower than IQR  2015     VC Lower than IQR
# 1539560   Population Lower than IQR  2015     VC Lower than IQR
# 1539561   Population Lower than IQR  2015     VC Lower than IQR
# 1539562   Population Lower than IQR  2015     VC Lower than IQR
# 1539563   Population Lower than IQR  2015     VC Lower than IQR
# 1539564   Population Lower than IQR  2015     VC Lower than IQR
# 1539565   Population Lower than IQR  2015     VC Lower than IQR
# 1539566   Population Lower than IQR  2010  VC Within Higher IQR
# 1539567   Population Lower than IQR  2010  VC Within Higher IQR
# 1539568   Population Lower than IQR  2011  VC Within Higher IQR
# 1539569   Population Lower than IQR  2012  VC Within Higher IQR
# 1539570   Population Lower than IQR  2012  VC Within Higher IQR
# 1539571   Population Lower than IQR  2012  VC Within Higher IQR
# 1539572   Population Lower than IQR  2012  VC Within Higher IQR
# 1539573   Population Lower than IQR  2012  VC Within Higher IQR
# 1539574   Population Lower than IQR  2013  VC Within Higher IQR
# 1539575   Population Lower than IQR  2014   VC Within Lower IQR
# 1539576   Population Lower than IQR  2014   VC Within Lower IQR
# 1539577   Population Lower than IQR  2015   VC Within Lower IQR
# 1539578   Population Lower than IQR  2015   VC Within Lower IQR
# 1539579   Population Lower than IQR  2015   VC Within Lower IQR
# 1539580   Population Lower than IQR  2015   VC Within Lower IQR
# 1539581   Population Lower than IQR  2015   VC Within Lower IQR
#
#                    Misd Binning            Major Binning  \
# 0        Misd Within Higher IQR    Major Higher than IQR
# 1        Misd Within Higher IQR    Major Higher than IQR
# 2        Misd Within Higher IQR    Major Higher than IQR
# 3        Misd Within Higher IQR    Major Higher than IQR
# 4        Misd Within Higher IQR    Major Higher than IQR
# 5        Misd Within Higher IQR    Major Higher than IQR
# 6        Misd Within Higher IQR    Major Higher than IQR
# 7        Misd Within Higher IQR    Major Higher than IQR
# 8        Misd Within Higher IQR    Major Higher than IQR
# 9        Misd Within Higher IQR    Major Higher than IQR
# 10       Misd Within Higher IQR    Major Higher than IQR
# 11       Misd Within Higher IQR    Major Higher than IQR
# 12       Misd Within Higher IQR    Major Higher than IQR
# 13       Misd Within Higher IQR    Major Higher than IQR
# 14       Misd Within Higher IQR    Major Higher than IQR
# 15       Misd Within Higher IQR    Major Higher than IQR
# 16       Misd Within Higher IQR    Major Higher than IQR
# 17       Misd Within Higher IQR    Major Higher than IQR
# 18       Misd Within Higher IQR    Major Higher than IQR
# 19       Misd Within Higher IQR    Major Higher than IQR
# 20       Misd Within Higher IQR    Major Higher than IQR
# 21       Misd Within Higher IQR    Major Higher than IQR
# 22       Misd Within Higher IQR    Major Higher than IQR
# 23       Misd Within Higher IQR    Major Higher than IQR
# 24       Misd Within Higher IQR    Major Higher than IQR
# 25       Misd Within Higher IQR    Major Higher than IQR
# 26       Misd Within Higher IQR    Major Higher than IQR
# 27       Misd Within Higher IQR    Major Higher than IQR
# 28       Misd Within Higher IQR    Major Higher than IQR
# 29       Misd Within Higher IQR    Major Higher than IQR
# ...                         ...                      ...
# 1539552     Misd Lower than IQR     Major Lower than IQR
# 1539553     Misd Lower than IQR     Major Lower than IQR
# 1539554     Misd Lower than IQR     Major Lower than IQR
# 1539555     Misd Lower than IQR     Major Lower than IQR
# 1539556     Misd Lower than IQR     Major Lower than IQR
# 1539557     Misd Lower than IQR     Major Lower than IQR
# 1539558     Misd Lower than IQR     Major Lower than IQR
# 1539559     Misd Lower than IQR     Major Lower than IQR
# 1539560     Misd Lower than IQR     Major Lower than IQR
# 1539561     Misd Lower than IQR     Major Lower than IQR
# 1539562     Misd Lower than IQR     Major Lower than IQR
# 1539563     Misd Lower than IQR     Major Lower than IQR
# 1539564     Misd Lower than IQR     Major Lower than IQR
# 1539565     Misd Lower than IQR     Major Lower than IQR
# 1539566    Misd Higher than IQR    Major Higher than IQR
# 1539567    Misd Higher than IQR    Major Higher than IQR
# 1539568    Misd Higher than IQR    Major Higher than IQR
# 1539569  Misd Within Higher IQR    Major Higher than IQR
# 1539570  Misd Within Higher IQR    Major Higher than IQR
# 1539571  Misd Within Higher IQR    Major Higher than IQR
# 1539572  Misd Within Higher IQR    Major Higher than IQR
# 1539573  Misd Within Higher IQR    Major Higher than IQR
# 1539574  Misd Within Higher IQR    Major Higher than IQR
# 1539575    Misd Higher than IQR    Major Higher than IQR
# 1539576    Misd Higher than IQR    Major Higher than IQR
# 1539577  Misd Within Higher IQR  Major Within Higher IQR
# 1539578  Misd Within Higher IQR  Major Within Higher IQR
# 1539579  Misd Within Higher IQR  Major Within Higher IQR
# 1539580  Misd Within Higher IQR  Major Within Higher IQR
# 1539581  Misd Within Higher IQR  Major Within Higher IQR
#
#                    Nonmajor Binning           Noise Binning  \
# 0        Nonmajor Within Higher IQR  Noise Within Lower IQR
# 1        Nonmajor Within Higher IQR  Noise Within Lower IQR
# 2        Nonmajor Within Higher IQR  Noise Within Lower IQR
# 3        Nonmajor Within Higher IQR  Noise Within Lower IQR
# 4        Nonmajor Within Higher IQR  Noise Within Lower IQR
# 5        Nonmajor Within Higher IQR  Noise Within Lower IQR
# 6        Nonmajor Within Higher IQR  Noise Within Lower IQR
# 7        Nonmajor Within Higher IQR  Noise Within Lower IQR
# 8        Nonmajor Within Higher IQR  Noise Within Lower IQR
# 9        Nonmajor Within Higher IQR  Noise Within Lower IQR
# 10       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 11       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 12       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 13       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 14       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 15       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 16       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 17       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 18       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 19       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 20       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 21       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 22       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 23       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 24       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 25       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 26       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 27       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 28       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 29       Nonmajor Within Higher IQR  Noise Within Lower IQR
# ...                             ...                     ...
# 1539552     Nonmajor Lower than IQR    Noise Lower than IQR
# 1539553     Nonmajor Lower than IQR    Noise Lower than IQR
# 1539554   Nonmajor Within Lower IQR    Noise Lower than IQR
# 1539555   Nonmajor Within Lower IQR    Noise Lower than IQR
# 1539556   Nonmajor Within Lower IQR    Noise Lower than IQR
# 1539557   Nonmajor Within Lower IQR    Noise Lower than IQR
# 1539558   Nonmajor Within Lower IQR    Noise Lower than IQR
# 1539559   Nonmajor Within Lower IQR    Noise Lower than IQR
# 1539560   Nonmajor Within Lower IQR    Noise Lower than IQR
# 1539561   Nonmajor Within Lower IQR    Noise Lower than IQR
# 1539562   Nonmajor Within Lower IQR    Noise Lower than IQR
# 1539563   Nonmajor Within Lower IQR    Noise Lower than IQR
# 1539564   Nonmajor Within Lower IQR    Noise Lower than IQR
# 1539565   Nonmajor Within Lower IQR    Noise Lower than IQR
# 1539566    Nonmajor Higher than IQR    Noise Lower than IQR
# 1539567    Nonmajor Higher than IQR    Noise Lower than IQR
# 1539568    Nonmajor Higher than IQR    Noise Lower than IQR
# 1539569    Nonmajor Higher than IQR    Noise Lower than IQR
# 1539570    Nonmajor Higher than IQR    Noise Lower than IQR
# 1539571    Nonmajor Higher than IQR    Noise Lower than IQR
# 1539572    Nonmajor Higher than IQR    Noise Lower than IQR
# 1539573    Nonmajor Higher than IQR    Noise Lower than IQR
# 1539574    Nonmajor Higher than IQR    Noise Lower than IQR
# 1539575    Nonmajor Higher than IQR    Noise Lower than IQR
# 1539576    Nonmajor Higher than IQR    Noise Lower than IQR
# 1539577    Nonmajor Higher than IQR    Noise Lower than IQR
# 1539578    Nonmajor Higher than IQR    Noise Lower than IQR
# 1539579    Nonmajor Higher than IQR    Noise Lower than IQR
# 1539580    Nonmajor Higher than IQR    Noise Lower than IQR
# 1539581    Nonmajor Higher than IQR    Noise Lower than IQR
#
#                             Poverty Level
# 0        Poverty Level Higher than Median
# 1        Poverty Level Higher than Median
# 2        Poverty Level Higher than Median
# 3        Poverty Level Higher than Median
# 4        Poverty Level Higher than Median
# 5        Poverty Level Higher than Median
# 6        Poverty Level Higher than Median
# 7        Poverty Level Higher than Median
# 8        Poverty Level Higher than Median
# 9        Poverty Level Higher than Median
# 10       Poverty Level Higher than Median
# 11       Poverty Level Higher than Median
# 12       Poverty Level Higher than Median
# 13       Poverty Level Higher than Median
# 14       Poverty Level Higher than Median
# 15       Poverty Level Higher than Median
# 16       Poverty Level Higher than Median
# 17       Poverty Level Higher than Median
# 18       Poverty Level Higher than Median
# 19       Poverty Level Higher than Median
# 20       Poverty Level Higher than Median
# 21       Poverty Level Higher than Median
# 22       Poverty Level Higher than Median
# 23       Poverty Level Higher than Median
# 24       Poverty Level Higher than Median
# 25       Poverty Level Higher than Median
# 26       Poverty Level Higher than Median
# 27       Poverty Level Higher than Median
# 28       Poverty Level Higher than Median
# 29       Poverty Level Higher than Median
# ...                                   ...
# 1539552  Poverty Level Higher than Median
# 1539553  Poverty Level Higher than Median
# 1539554  Poverty Level Higher than Median
# 1539555  Poverty Level Higher than Median
# 1539556  Poverty Level Higher than Median
# 1539557  Poverty Level Higher than Median
# 1539558  Poverty Level Higher than Median
# 1539559  Poverty Level Higher than Median
# 1539560  Poverty Level Higher than Median
# 1539561  Poverty Level Higher than Median
# 1539562  Poverty Level Higher than Median
# 1539563  Poverty Level Higher than Median
# 1539564  Poverty Level Higher than Median
# 1539565  Poverty Level Higher than Median
# 1539566  Poverty Level Higher than Median
# 1539567  Poverty Level Higher than Median
# 1539568  Poverty Level Higher than Median
# 1539569  Poverty Level Higher than Median
# 1539570  Poverty Level Higher than Median
# 1539571  Poverty Level Higher than Median
# 1539572  Poverty Level Higher than Median
# 1539573  Poverty Level Higher than Median
# 1539574  Poverty Level Higher than Median
# 1539575  Poverty Level Higher than Median
# 1539576  Poverty Level Higher than Median
# 1539577  Poverty Level Higher than Median
# 1539578  Poverty Level Higher than Median
# 1539579  Poverty Level Higher than Median
# 1539580  Poverty Level Higher than Median
# 1539581  Poverty Level Higher than Median
#
# [1539582 rows x 17 columns]

# %%
df = df.applymap(str)
total_data = df.values.tolist()

# %%
total_data
# Out:
# [['0',
#   'NGHBR: Borough Park',
#   '2010-01-01 00:03:46',
#   'Noise - Residential',
#   'Loud Television',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['1',
#   'NGHBR: Borough Park',
#   '2010-01-01 00:36:01',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Store/Commercial',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['2',
#   'NGHBR: Borough Park',
#   '2010-01-01 01:21:11',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Store/Commercial',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['3',
#   'NGHBR: Borough Park',
#   '2010-01-01 02:14:21',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Store/Commercial',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['4',
#   'NGHBR: Borough Park',
#   '2010-01-01 02:59:07',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['5',
#   'NGHBR: Borough Park',
#   '2010-01-01 03:35:54',
#   'Noise - Commercial',
#   'Loud Talking',
#   'Store/Commercial',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['6',
#   'NGHBR: Borough Park',
#   '2010-01-01 15:48:01',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['7',
#   'NGHBR: Borough Park',
#   '2010-01-01 20:34:37',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['8',
#   'NGHBR: Borough Park',
#   '2010-01-01 22:33:15',
#   'Noise - Residential',
#   'Loud Talking',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['9',
#   'NGHBR: Borough Park',
#   '2010-01-02 07:52:38',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['10',
#   'NGHBR: Borough Park',
#   '2010-01-02 12:43:44',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['11',
#   'NGHBR: Borough Park',
#   '2010-01-03 10:43:41',
#   'Noise - Residential',
#   'Loud Talking',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['12',
#   'NGHBR: Borough Park',
#   '2010-01-03 10:53:16',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['13',
#   'NGHBR: Borough Park',
#   '2010-01-05 01:41:00',
#   'Noise',
#   'Noise: Air Condition/Ventilation Equip, Residential (NJ1)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['14',
#   'NGHBR: Borough Park',
#   '2010-01-05 11:03:22',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['15',
#   'NGHBR: Borough Park',
#   '2010-01-06 09:16:12',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['16',
#   'NGHBR: Borough Park',
#   '2010-01-06 11:11:00',
#   'Noise',
#   'Horn Honking Sign Requested (NR9)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['17',
#   'NGHBR: Borough Park',
#   '2010-01-07 09:44:15',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['18',
#   'NGHBR: Borough Park',
#   '2010-01-07 15:12:25',
#   'Noise - Residential',
#   'Loud Television',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['19',
#   'NGHBR: Borough Park',
#   '2010-01-07 23:38:50',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['20',
#   'NGHBR: Borough Park',
#   '2010-01-08 02:42:50',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['21',
#   'NGHBR: Borough Park',
#   '2010-01-08 03:05:49',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['22',
#   'NGHBR: Borough Park',
#   '2010-01-08 21:46:24',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['23',
#   'NGHBR: Borough Park',
#   '2010-01-08 22:11:17',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['24',
#   'NGHBR: Borough Park',
#   '2010-01-08 23:48:50',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['25',
#   'NGHBR: Borough Park',
#   '2010-01-09 00:29:37',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['26',
#   'NGHBR: Borough Park',
#   '2010-01-09 01:05:37',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['27',
#   'NGHBR: Borough Park',
#   '2010-01-09 03:05:28',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['28',
#   'NGHBR: Borough Park',
#   '2010-01-09 05:22:45',
#   'Noise - Vehicle',
#   'Engine Idling',
#   'Street/Sidewalk',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['29',
#   'NGHBR: Borough Park',
#   '2010-01-09 20:40:10',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['30',
#   'NGHBR: Borough Park',
#   '2010-01-09 21:50:33',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['31',
#   'NGHBR: Borough Park',
#   '2010-01-10 08:21:00',
#   'Noise',
#   'Noise: Air Condition/Ventilation Equip, Residential (NJ1)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['32',
#   'NGHBR: Borough Park',
#   '2010-01-10 09:04:14',
#   'Noise - Vehicle',
#   'Engine Idling',
#   'Street/Sidewalk',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['33',
#   'NGHBR: Borough Park',
#   '2010-01-10 09:20:32',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['34',
#   'NGHBR: Borough Park',
#   '2010-01-10 13:49:10',
#   'Noise - Park',
#   'Loud Talking',
#   'Park/Playground',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['35',
#   'NGHBR: Borough Park',
#   '2010-01-11 01:19:45',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['36',
#   'NGHBR: Borough Park',
#   '2010-01-11 20:27:50',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['37',
#   'NGHBR: Borough Park',
#   '2010-01-12 08:46:00',
#   'Noise',
#   'Noise: Air Condition/Ventilation Equip, Residential (NJ1)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['38',
#   'NGHBR: Borough Park',
#   '2010-01-12 14:04:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['39',
#   'NGHBR: Borough Park',
#   '2010-01-12 19:02:13',
#   'Noise - Vehicle',
#   'Car/Truck Horn',
#   'Street/Sidewalk',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['40',
#   'NGHBR: Borough Park',
#   '2010-01-12 19:11:00',
#   'Noise',
#   'Horn Honking Sign Requested (NR9)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['41',
#   'NGHBR: Borough Park',
#   '2010-01-13 00:13:00',
#   'Collection Truck Noise',
#   '21 Collection Truck Noise',
#   'Sidewalk',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['42',
#   'NGHBR: Borough Park',
#   '2010-01-13 12:27:32',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['43',
#   'NGHBR: Borough Park',
#   '2010-01-13 14:30:59',
#   'Noise - Vehicle',
#   'Engine Idling',
#   'Street/Sidewalk',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['44',
#   'NGHBR: Borough Park',
#   '2010-01-13 23:06:25',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['45',
#   'NGHBR: Borough Park',
#   '2010-01-14 00:08:49',
#   'Noise - Residential',
#   'Loud Talking',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['46',
#   'NGHBR: Borough Park',
#   '2010-01-14 02:50:28',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['47',
#   'NGHBR: Borough Park',
#   '2010-01-14 11:06:07',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['48',
#   'NGHBR: Borough Park',
#   '2010-01-14 13:04:02',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['49',
#   'NGHBR: Borough Park',
#   '2010-01-15 09:42:40',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['50',
#   'NGHBR: Borough Park',
#   '2010-01-15 12:59:38',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['51',
#   'NGHBR: Borough Park',
#   '2010-01-15 15:07:08',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['52',
#   'NGHBR: Borough Park',
#   '2010-01-15 16:21:02',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['53',
#   'NGHBR: Borough Park',
#   '2010-01-15 16:28:10',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['54',
#   'NGHBR: Borough Park',
#   '2010-01-15 20:55:00',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['55',
#   'NGHBR: Borough Park',
#   '2010-01-15 23:51:55',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['56',
#   'NGHBR: Borough Park',
#   '2010-01-16 10:26:52',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['57',
#   'NGHBR: Borough Park',
#   '2010-01-16 16:10:30',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Store/Commercial',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['58',
#   'NGHBR: Borough Park',
#   '2010-01-16 22:36:15',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['59',
#   'NGHBR: Borough Park',
#   '2010-01-17 03:20:06',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['60',
#   'NGHBR: Borough Park',
#   '2010-01-17 16:11:49',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['61',
#   'NGHBR: Borough Park',
#   '2010-01-17 19:09:56',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['62',
#   'NGHBR: Borough Park',
#   '2010-01-17 23:07:57',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Club/Bar/Restaurant',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['63',
#   'NGHBR: Borough Park',
#   '2010-01-18 10:26:00',
#   'Noise',
#   'Noise: Air Condition/Ventilation Equip, Residential (NJ1)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['64',
#   'NGHBR: Borough Park',
#   '2010-01-18 12:18:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['65',
#   'NGHBR: Borough Park',
#   '2010-01-18 14:00:43',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['66',
#   'NGHBR: Borough Park',
#   '2010-01-18 18:44:54',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['67',
#   'NGHBR: Borough Park',
#   '2010-01-18 21:42:25',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['68',
#   'NGHBR: Borough Park',
#   '2010-01-18 23:03:00',
#   'Noise',
#   'Horn Honking Sign Requested (NR9)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['69',
#   'NGHBR: Borough Park',
#   '2010-01-18 23:09:18',
#   'Noise - Residential',
#   'Loud Talking',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['70',
#   'NGHBR: Borough Park',
#   '2010-01-19 00:00:00',
#   'Noise',
#   'Noise: Alarms (NR3)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['71',
#   'NGHBR: Borough Park',
#   '2010-01-19 01:00:04',
#   'Noise - Street/Sidewalk',
#   'Loud Talking',
#   'Street/Sidewalk',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['72',
#   'NGHBR: Borough Park',
#   '2010-01-19 02:24:47',
#   'Noise - Residential',
#   'Loud Talking',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['73',
#   'NGHBR: Borough Park',
#   '2010-01-19 11:26:38',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['74',
#   'NGHBR: Borough Park',
#   '2010-01-19 16:11:35',
#   'Noise - Street/Sidewalk',
#   'Loud Talking',
#   'Street/Sidewalk',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['75',
#   'NGHBR: Borough Park',
#   '2010-01-19 22:30:41',
#   'Noise - Vehicle',
#   'Car/Truck Horn',
#   'Street/Sidewalk',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['76',
#   'NGHBR: Borough Park',
#   '2010-01-20 00:29:54',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['77',
#   'NGHBR: Borough Park',
#   '2010-01-20 01:26:20',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['78',
#   'NGHBR: Borough Park',
#   '2010-01-21 10:46:00',
#   'Noise',
#   'Noise: Construction Equipment (NC1)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['79',
#   'NGHBR: Borough Park',
#   '2010-01-21 19:52:08',
#   'Noise - Commercial',
#   'Car/Truck Horn',
#   'Store/Commercial',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['80',
#   'NGHBR: Borough Park',
#   '2010-01-22 02:10:15',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['81',
#   'NGHBR: Borough Park',
#   '2010-01-22 10:46:24',
#   'Noise - Residential',
#   'Loud Talking',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['82',
#   'NGHBR: Borough Park',
#   '2010-01-22 11:27:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['83',
#   'NGHBR: Borough Park',
#   '2010-01-22 18:04:43',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['84',
#   'NGHBR: Borough Park',
#   '2010-01-23 17:08:40',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['85',
#   'NGHBR: Borough Park',
#   '2010-01-23 19:02:57',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['86',
#   'NGHBR: Borough Park',
#   '2010-01-23 23:52:23',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['87',
#   'NGHBR: Borough Park',
#   '2010-01-24 01:45:35',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['88',
#   'NGHBR: Borough Park',
#   '2010-01-24 03:44:55',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Club/Bar/Restaurant',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['89',
#   'NGHBR: Borough Park',
#   '2010-01-24 15:01:17',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['90',
#   'NGHBR: Borough Park',
#   '2010-01-24 20:32:25',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['91',
#   'NGHBR: Borough Park',
#   '2010-01-24 22:45:23',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['92',
#   'NGHBR: Borough Park',
#   '2010-01-24 23:58:13',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['93',
#   'NGHBR: Borough Park',
#   '2010-01-25 16:12:00',
#   'Noise',
#   'Noise: Alarms (NR3)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['94',
#   'NGHBR: Borough Park',
#   '2010-01-25 20:02:35',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['95',
#   'NGHBR: Borough Park',
#   '2010-01-26 02:12:12',
#   'Noise - Residential',
#   'Loud Television',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['96',
#   'NGHBR: Borough Park',
#   '2010-01-26 18:42:46',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['97',
#   'NGHBR: Borough Park',
#   '2010-01-26 22:37:21',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['98',
#   'NGHBR: Borough Park',
#   '2010-01-26 23:04:56',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['99',
#   'NGHBR: Borough Park',
#   '2010-01-26 23:50:37',
#   'Noise - Residential',
#   'Loud Talking',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['100',
#   'NGHBR: Borough Park',
#   '2010-01-28 17:38:23',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['101',
#   'NGHBR: Borough Park',
#   '2010-01-28 21:28:00',
#   'Noise',
#   'Noise: Construction Equipment (NC1)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['102',
#   'NGHBR: Borough Park',
#   '2010-01-28 21:58:00',
#   'Noise',
#   'Noise: Construction Before/After Hours (NM1)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['103',
#   'NGHBR: Borough Park',
#   '2010-01-29 01:58:22',
#   'Noise - Residential',
#   'Loud Talking',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['104',
#   'NGHBR: Borough Park',
#   '2010-01-30 02:28:37',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['105',
#   'NGHBR: Borough Park',
#   '2010-01-30 19:12:22',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['106',
#   'NGHBR: Borough Park',
#   '2010-01-30 20:06:53',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['107',
#   'NGHBR: Borough Park',
#   '2010-01-31 01:41:21',
#   'Noise - Residential',
#   'Loud Television',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['108',
#   'NGHBR: Borough Park',
#   '2010-01-31 19:49:35',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['109',
#   'NGHBR: Borough Park',
#   '2010-01-31 23:35:44',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['110',
#   'NGHBR: Borough Park',
#   '2010-02-01 01:07:03',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['111',
#   'NGHBR: Borough Park',
#   '2010-02-01 22:13:00',
#   'Noise',
#   'Noise: Construction Before/After Hours (NM1)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['112',
#   'NGHBR: Borough Park',
#   '2010-02-02 23:07:37',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['113',
#   'NGHBR: Borough Park',
#   '2010-02-03 01:57:26',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['114',
#   'NGHBR: Borough Park',
#   '2010-02-03 21:01:54',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['115',
#   'NGHBR: Borough Park',
#   '2010-02-04 00:23:06',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['116',
#   'NGHBR: Borough Park',
#   '2010-02-04 01:09:41',
#   'Noise - Residential',
#   'Loud Television',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['117',
#   'NGHBR: Borough Park',
#   '2010-02-04 12:06:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['118',
#   'NGHBR: Borough Park',
#   '2010-02-04 17:45:32',
#   'Noise - Residential',
#   'Loud Television',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['119',
#   'NGHBR: Borough Park',
#   '2010-02-05 06:10:56',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['120',
#   'NGHBR: Borough Park',
#   '2010-02-05 16:09:35',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['121',
#   'NGHBR: Borough Park',
#   '2010-02-06 01:16:09',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['122',
#   'NGHBR: Borough Park',
#   '2010-02-06 01:26:24',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['123',
#   'NGHBR: Borough Park',
#   '2010-02-06 02:44:27',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['124',
#   'NGHBR: Borough Park',
# ...
#  ['958',
#   'NGHBR: Borough Park',
#   '2010-09-07 02:38:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['959',
#   'NGHBR: Borough Park',
#   '2010-09-07 12:43:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['960',
#   'NGHBR: Borough Park',
#   '2010-09-08 19:35:27',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['961',
#   'NGHBR: Borough Park',
#   '2010-09-08 23:33:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['962',
#   'NGHBR: Borough Park',
#   '2010-09-08 23:42:40',
#   'Noise - Residential',
#   'Loud Talking',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['963',
#   'NGHBR: Borough Park',
#   '2010-09-09 00:12:37',
#   'Noise - Residential',
#   'Loud Talking',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['964',
#   'NGHBR: Borough Park',
#   '2010-09-09 01:18:38',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['965',
#   'NGHBR: Borough Park',
#   '2010-09-09 01:32:01',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['966',
#   'NGHBR: Borough Park',
#   '2010-09-09 05:02:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['967',
#   'NGHBR: Borough Park',
#   '2010-09-09 14:57:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['968',
#   'NGHBR: Borough Park',
#   '2010-09-09 21:25:51',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['969',
#   'NGHBR: Borough Park',
#   '2010-09-09 21:40:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['970',
#   'NGHBR: Borough Park',
#   '2010-09-09 21:42:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['971',
#   'NGHBR: Borough Park',
#   '2010-09-09 21:44:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['972',
#   'NGHBR: Borough Park',
#   '2010-09-09 22:01:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['973',
#   'NGHBR: Borough Park',
#   '2010-09-10 01:25:00',
#   'Noise',
#   'Noise: Construction Before/After Hours (NM1)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['974',
#   'NGHBR: Borough Park',
#   '2010-09-10 02:41:48',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['975',
#   'NGHBR: Borough Park',
#   '2010-09-10 03:48:13',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['976',
#   'NGHBR: Borough Park',
#   '2010-09-10 09:10:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['977',
#   'NGHBR: Borough Park',
#   '2010-09-10 17:24:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['978',
#   'NGHBR: Borough Park',
#   '2010-09-10 19:50:43',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['979',
#   'NGHBR: Borough Park',
#   '2010-09-10 20:10:49',
#   'Noise - Vehicle',
#   'Car/Truck Music',
#   'Street/Sidewalk',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['980',
#   'NGHBR: Borough Park',
#   '2010-09-10 23:07:04',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['981',
#   'NGHBR: Borough Park',
#   '2010-09-11 11:25:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['982',
#   'NGHBR: Borough Park',
#   '2010-09-11 21:22:05',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['983',
#   'NGHBR: Borough Park',
#   '2010-09-11 21:30:14',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['984',
#   'NGHBR: Borough Park',
#   '2010-09-11 22:06:00',
#   'Noise',
#   'Noise: Construction Before/After Hours (NM1)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['985',
#   'NGHBR: Borough Park',
#   '2010-09-11 23:30:27',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['986',
#   'NGHBR: Borough Park',
#   '2010-09-12 01:43:50',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['987',
#   'NGHBR: Borough Park',
#   '2010-09-12 07:55:32',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['988',
#   'NGHBR: Borough Park',
#   '2010-09-12 14:24:30',
#   'Noise - Vehicle',
#   'Car/Truck Horn',
#   'Street/Sidewalk',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['989',
#   'NGHBR: Borough Park',
#   '2010-09-12 14:37:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['990',
#   'NGHBR: Borough Park',
#   '2010-09-12 18:51:14',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['991',
#   'NGHBR: Borough Park',
#   '2010-09-12 19:10:01',
#   'Noise - Street/Sidewalk',
#   'Loud Talking',
#   'Street/Sidewalk',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['992',
#   'NGHBR: Borough Park',
#   '2010-09-12 20:24:19',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['993',
#   'NGHBR: Borough Park',
#   '2010-09-12 21:24:41',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['994',
#   'NGHBR: Borough Park',
#   '2010-09-12 22:25:45',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['995',
#   'NGHBR: Borough Park',
#   '2010-09-13 02:43:00',
#   'Noise',
#   'Noise: Construction Before/After Hours (NM1)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['996',
#   'NGHBR: Borough Park',
#   '2010-09-13 03:14:00',
#   'Collection Truck Noise',
#   '21 Collection Truck Noise',
#   'Sidewalk',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['997',
#   'NGHBR: Borough Park',
#   '2010-09-13 13:58:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['998',
#   'NGHBR: Borough Park',
#   '2010-09-13 14:39:10',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['999',
#   'NGHBR: Borough Park',
#   '2010-09-13 17:13:00',
#   'Collection Truck Noise',
#   '21 Collection Truck Noise',
#   'Sidewalk',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ...]

# %%
patterns,rules = mine_patterns(total_data,thresh,0.7,'Citywide')

# %% [markdown]
# ##Find Patterns by Borough

# %%
Bronx = df.loc[df["Borough"] == 'BRONX']
Bronx = Bronx.drop('Borough',1)
bronx = Bronx.applymap(str)
bronx1 = bronx.values.tolist()
bronx_pats,bronx_rules = mine_patterns(bronx1,thresh,0.7,'Bronx')

# %%
Brook = df.loc[df["Borough"] == 'BROOKLYN']
Brook = Brook.drop('Borough',1)
brook = Brook.applymap(str)
brook1 = brook.values.tolist()
brook_pats,brook_rules = mine_patterns(brook1,thresh,0.7,'Brooklyn')

# %%
Man = df.loc[df["Borough"] == 'MANHATTAN']
Man = Man.drop('Borough',1)
Man = Man.applymap(str)
Man1 = Man.values.tolist()
Man_pats,Man_rules = mine_patterns(Man1,thresh,0.7,'Manhattan')

# %%
staten = df.loc[df["Borough"] == 'STATEN ISLAND']
staten = staten.drop('Borough',1)
staten = staten.applymap(str)
staten1 = staten.values.tolist()
staten_pats,staten_rules = mine_patterns(staten1,thresh,0.7,'Staten_Island')

# %%
queens = df.loc[df["Borough"] == 'QUEENS']
queens = queens.drop('Borough',1)
queens = queens.applymap(str)
queens1 = queens.values.tolist()
queens_pats,queens_rules = mine_patterns(queens1,thresh,0.7,'Queens')

# %% [markdown]
# ##Find Patterns by Year

# %%
year2010 = year2010.drop('Year',1)

# %%
year2010 = year2010.applymap(str)

# %%
year2010.dtypes
# Out:
# Unnamed: 0          object
# Neighborhood        object
# Created_Date        object
# Complaint Type      object
# Descriptor          object
# Location Type       object
# Zip Code            object
# Borough             object
# Precinct            object
# Population          object
# Violence Binning    object
# Misd Binning        object
# Major Binning       object
# Nonmajor Binning    object
# Noise Binning       object
# Poverty Level       object
# dtype: object

# %%
y2010 = year2010.values.tolist()

# %%
y2010
# Out:
# [['0',
#   'NGHBR: Borough Park',
#   '2010-01-01 00:03:46',
#   'Noise - Residential',
#   'Loud Television',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['1',
#   'NGHBR: Borough Park',
#   '2010-01-01 00:36:01',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Store/Commercial',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['2',
#   'NGHBR: Borough Park',
#   '2010-01-01 01:21:11',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Store/Commercial',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['3',
#   'NGHBR: Borough Park',
#   '2010-01-01 02:14:21',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Store/Commercial',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['4',
#   'NGHBR: Borough Park',
#   '2010-01-01 02:59:07',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['5',
#   'NGHBR: Borough Park',
#   '2010-01-01 03:35:54',
#   'Noise - Commercial',
#   'Loud Talking',
#   'Store/Commercial',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['6',
#   'NGHBR: Borough Park',
#   '2010-01-01 15:48:01',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['7',
#   'NGHBR: Borough Park',
#   '2010-01-01 20:34:37',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['8',
#   'NGHBR: Borough Park',
#   '2010-01-01 22:33:15',
#   'Noise - Residential',
#   'Loud Talking',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['9',
#   'NGHBR: Borough Park',
#   '2010-01-02 07:52:38',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['10',
#   'NGHBR: Borough Park',
#   '2010-01-02 12:43:44',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['11',
#   'NGHBR: Borough Park',
#   '2010-01-03 10:43:41',
#   'Noise - Residential',
#   'Loud Talking',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['12',
#   'NGHBR: Borough Park',
#   '2010-01-03 10:53:16',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['13',
#   'NGHBR: Borough Park',
#   '2010-01-05 01:41:00',
#   'Noise',
#   'Noise: Air Condition/Ventilation Equip, Residential (NJ1)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['14',
#   'NGHBR: Borough Park',
#   '2010-01-05 11:03:22',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['15',
#   'NGHBR: Borough Park',
#   '2010-01-06 09:16:12',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['16',
#   'NGHBR: Borough Park',
#   '2010-01-06 11:11:00',
#   'Noise',
#   'Horn Honking Sign Requested (NR9)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['17',
#   'NGHBR: Borough Park',
#   '2010-01-07 09:44:15',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['18',
#   'NGHBR: Borough Park',
#   '2010-01-07 15:12:25',
#   'Noise - Residential',
#   'Loud Television',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['19',
#   'NGHBR: Borough Park',
#   '2010-01-07 23:38:50',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['20',
#   'NGHBR: Borough Park',
#   '2010-01-08 02:42:50',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['21',
#   'NGHBR: Borough Park',
#   '2010-01-08 03:05:49',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['22',
#   'NGHBR: Borough Park',
#   '2010-01-08 21:46:24',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['23',
#   'NGHBR: Borough Park',
#   '2010-01-08 22:11:17',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['24',
#   'NGHBR: Borough Park',
#   '2010-01-08 23:48:50',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['25',
#   'NGHBR: Borough Park',
#   '2010-01-09 00:29:37',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['26',
#   'NGHBR: Borough Park',
#   '2010-01-09 01:05:37',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['27',
#   'NGHBR: Borough Park',
#   '2010-01-09 03:05:28',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['28',
#   'NGHBR: Borough Park',
#   '2010-01-09 05:22:45',
#   'Noise - Vehicle',
#   'Engine Idling',
#   'Street/Sidewalk',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['29',
#   'NGHBR: Borough Park',
#   '2010-01-09 20:40:10',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['30',
#   'NGHBR: Borough Park',
#   '2010-01-09 21:50:33',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['31',
#   'NGHBR: Borough Park',
#   '2010-01-10 08:21:00',
#   'Noise',
#   'Noise: Air Condition/Ventilation Equip, Residential (NJ1)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['32',
#   'NGHBR: Borough Park',
#   '2010-01-10 09:04:14',
#   'Noise - Vehicle',
#   'Engine Idling',
#   'Street/Sidewalk',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['33',
#   'NGHBR: Borough Park',
#   '2010-01-10 09:20:32',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['34',
#   'NGHBR: Borough Park',
#   '2010-01-10 13:49:10',
#   'Noise - Park',
#   'Loud Talking',
#   'Park/Playground',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['35',
#   'NGHBR: Borough Park',
#   '2010-01-11 01:19:45',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['36',
#   'NGHBR: Borough Park',
#   '2010-01-11 20:27:50',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['37',
#   'NGHBR: Borough Park',
#   '2010-01-12 08:46:00',
#   'Noise',
#   'Noise: Air Condition/Ventilation Equip, Residential (NJ1)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['38',
#   'NGHBR: Borough Park',
#   '2010-01-12 14:04:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['39',
#   'NGHBR: Borough Park',
#   '2010-01-12 19:02:13',
#   'Noise - Vehicle',
#   'Car/Truck Horn',
#   'Street/Sidewalk',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['40',
#   'NGHBR: Borough Park',
#   '2010-01-12 19:11:00',
#   'Noise',
#   'Horn Honking Sign Requested (NR9)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['41',
#   'NGHBR: Borough Park',
#   '2010-01-13 00:13:00',
#   'Collection Truck Noise',
#   '21 Collection Truck Noise',
#   'Sidewalk',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['42',
#   'NGHBR: Borough Park',
#   '2010-01-13 12:27:32',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['43',
#   'NGHBR: Borough Park',
#   '2010-01-13 14:30:59',
#   'Noise - Vehicle',
#   'Engine Idling',
#   'Street/Sidewalk',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['44',
#   'NGHBR: Borough Park',
#   '2010-01-13 23:06:25',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['45',
#   'NGHBR: Borough Park',
#   '2010-01-14 00:08:49',
#   'Noise - Residential',
#   'Loud Talking',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['46',
#   'NGHBR: Borough Park',
#   '2010-01-14 02:50:28',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['47',
#   'NGHBR: Borough Park',
#   '2010-01-14 11:06:07',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['48',
#   'NGHBR: Borough Park',
#   '2010-01-14 13:04:02',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['49',
#   'NGHBR: Borough Park',
#   '2010-01-15 09:42:40',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['50',
#   'NGHBR: Borough Park',
#   '2010-01-15 12:59:38',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['51',
#   'NGHBR: Borough Park',
#   '2010-01-15 15:07:08',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['52',
#   'NGHBR: Borough Park',
#   '2010-01-15 16:21:02',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['53',
#   'NGHBR: Borough Park',
#   '2010-01-15 16:28:10',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['54',
#   'NGHBR: Borough Park',
#   '2010-01-15 20:55:00',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['55',
#   'NGHBR: Borough Park',
#   '2010-01-15 23:51:55',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['56',
#   'NGHBR: Borough Park',
#   '2010-01-16 10:26:52',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['57',
#   'NGHBR: Borough Park',
#   '2010-01-16 16:10:30',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Store/Commercial',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['58',
#   'NGHBR: Borough Park',
#   '2010-01-16 22:36:15',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['59',
#   'NGHBR: Borough Park',
#   '2010-01-17 03:20:06',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['60',
#   'NGHBR: Borough Park',
#   '2010-01-17 16:11:49',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['61',
#   'NGHBR: Borough Park',
#   '2010-01-17 19:09:56',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['62',
#   'NGHBR: Borough Park',
#   '2010-01-17 23:07:57',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Club/Bar/Restaurant',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['63',
#   'NGHBR: Borough Park',
#   '2010-01-18 10:26:00',
#   'Noise',
#   'Noise: Air Condition/Ventilation Equip, Residential (NJ1)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['64',
#   'NGHBR: Borough Park',
#   '2010-01-18 12:18:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['65',
#   'NGHBR: Borough Park',
#   '2010-01-18 14:00:43',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['66',
#   'NGHBR: Borough Park',
#   '2010-01-18 18:44:54',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['67',
#   'NGHBR: Borough Park',
#   '2010-01-18 21:42:25',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['68',
#   'NGHBR: Borough Park',
#   '2010-01-18 23:03:00',
#   'Noise',
#   'Horn Honking Sign Requested (NR9)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['69',
#   'NGHBR: Borough Park',
#   '2010-01-18 23:09:18',
#   'Noise - Residential',
#   'Loud Talking',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['70',
#   'NGHBR: Borough Park',
#   '2010-01-19 00:00:00',
#   'Noise',
#   'Noise: Alarms (NR3)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['71',
#   'NGHBR: Borough Park',
#   '2010-01-19 01:00:04',
#   'Noise - Street/Sidewalk',
#   'Loud Talking',
#   'Street/Sidewalk',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['72',
#   'NGHBR: Borough Park',
#   '2010-01-19 02:24:47',
#   'Noise - Residential',
#   'Loud Talking',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['73',
#   'NGHBR: Borough Park',
#   '2010-01-19 11:26:38',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['74',
#   'NGHBR: Borough Park',
#   '2010-01-19 16:11:35',
#   'Noise - Street/Sidewalk',
#   'Loud Talking',
#   'Street/Sidewalk',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['75',
#   'NGHBR: Borough Park',
#   '2010-01-19 22:30:41',
#   'Noise - Vehicle',
#   'Car/Truck Horn',
#   'Street/Sidewalk',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['76',
#   'NGHBR: Borough Park',
#   '2010-01-20 00:29:54',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['77',
#   'NGHBR: Borough Park',
#   '2010-01-20 01:26:20',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['78',
#   'NGHBR: Borough Park',
#   '2010-01-21 10:46:00',
#   'Noise',
#   'Noise: Construction Equipment (NC1)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['79',
#   'NGHBR: Borough Park',
#   '2010-01-21 19:52:08',
#   'Noise - Commercial',
#   'Car/Truck Horn',
#   'Store/Commercial',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['80',
#   'NGHBR: Borough Park',
#   '2010-01-22 02:10:15',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['81',
#   'NGHBR: Borough Park',
#   '2010-01-22 10:46:24',
#   'Noise - Residential',
#   'Loud Talking',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['82',
#   'NGHBR: Borough Park',
#   '2010-01-22 11:27:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['83',
#   'NGHBR: Borough Park',
#   '2010-01-22 18:04:43',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['84',
#   'NGHBR: Borough Park',
#   '2010-01-23 17:08:40',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['85',
#   'NGHBR: Borough Park',
#   '2010-01-23 19:02:57',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['86',
#   'NGHBR: Borough Park',
#   '2010-01-23 23:52:23',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['87',
#   'NGHBR: Borough Park',
#   '2010-01-24 01:45:35',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['88',
#   'NGHBR: Borough Park',
#   '2010-01-24 03:44:55',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Club/Bar/Restaurant',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['89',
#   'NGHBR: Borough Park',
#   '2010-01-24 15:01:17',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['90',
#   'NGHBR: Borough Park',
#   '2010-01-24 20:32:25',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['91',
#   'NGHBR: Borough Park',
#   '2010-01-24 22:45:23',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['92',
#   'NGHBR: Borough Park',
#   '2010-01-24 23:58:13',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['93',
#   'NGHBR: Borough Park',
#   '2010-01-25 16:12:00',
#   'Noise',
#   'Noise: Alarms (NR3)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['94',
#   'NGHBR: Borough Park',
#   '2010-01-25 20:02:35',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['95',
#   'NGHBR: Borough Park',
#   '2010-01-26 02:12:12',
#   'Noise - Residential',
#   'Loud Television',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['96',
#   'NGHBR: Borough Park',
#   '2010-01-26 18:42:46',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['97',
#   'NGHBR: Borough Park',
#   '2010-01-26 22:37:21',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['98',
#   'NGHBR: Borough Park',
#   '2010-01-26 23:04:56',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['99',
#   'NGHBR: Borough Park',
#   '2010-01-26 23:50:37',
#   'Noise - Residential',
#   'Loud Talking',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['100',
#   'NGHBR: Borough Park',
#   '2010-01-28 17:38:23',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['101',
#   'NGHBR: Borough Park',
#   '2010-01-28 21:28:00',
#   'Noise',
#   'Noise: Construction Equipment (NC1)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['102',
#   'NGHBR: Borough Park',
#   '2010-01-28 21:58:00',
#   'Noise',
#   'Noise: Construction Before/After Hours (NM1)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['103',
#   'NGHBR: Borough Park',
#   '2010-01-29 01:58:22',
#   'Noise - Residential',
#   'Loud Talking',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['104',
#   'NGHBR: Borough Park',
#   '2010-01-30 02:28:37',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['105',
#   'NGHBR: Borough Park',
#   '2010-01-30 19:12:22',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['106',
#   'NGHBR: Borough Park',
#   '2010-01-30 20:06:53',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['107',
#   'NGHBR: Borough Park',
#   '2010-01-31 01:41:21',
#   'Noise - Residential',
#   'Loud Television',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['108',
#   'NGHBR: Borough Park',
#   '2010-01-31 19:49:35',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['109',
#   'NGHBR: Borough Park',
#   '2010-01-31 23:35:44',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['110',
#   'NGHBR: Borough Park',
#   '2010-02-01 01:07:03',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['111',
#   'NGHBR: Borough Park',
#   '2010-02-01 22:13:00',
#   'Noise',
#   'Noise: Construction Before/After Hours (NM1)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['112',
#   'NGHBR: Borough Park',
#   '2010-02-02 23:07:37',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['113',
#   'NGHBR: Borough Park',
#   '2010-02-03 01:57:26',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['114',
#   'NGHBR: Borough Park',
#   '2010-02-03 21:01:54',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['115',
#   'NGHBR: Borough Park',
#   '2010-02-04 00:23:06',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['116',
#   'NGHBR: Borough Park',
#   '2010-02-04 01:09:41',
#   'Noise - Residential',
#   'Loud Television',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['117',
#   'NGHBR: Borough Park',
#   '2010-02-04 12:06:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['118',
#   'NGHBR: Borough Park',
#   '2010-02-04 17:45:32',
#   'Noise - Residential',
#   'Loud Television',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['119',
#   'NGHBR: Borough Park',
#   '2010-02-05 06:10:56',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['120',
#   'NGHBR: Borough Park',
#   '2010-02-05 16:09:35',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['121',
#   'NGHBR: Borough Park',
#   '2010-02-06 01:16:09',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['122',
#   'NGHBR: Borough Park',
#   '2010-02-06 01:26:24',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['123',
#   'NGHBR: Borough Park',
#   '2010-02-06 02:44:27',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['124',
#   'NGHBR: Borough Park',
#   '2010-02-06 02:58:03',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['125',
#   'NGHBR: Borough Park',
#   '2010-02-06 03:53:18',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['126',
#   'NGHBR: Borough Park',
#   '2010-02-06 12:05:58',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['127',
#   'NGHBR: Borough Park',
#   '2010-02-06 23:24:33',
#   'Noise - Residential',
#   'Loud Talking',
#   'Residential Building/House',
# ...
#   'Poverty Level Higher than Median'],
#  ['957',
#   'NGHBR: Borough Park',
#   '2010-09-06 23:56:34',
#   'Noise - Residential',
#   'Loud Television',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['958',
#   'NGHBR: Borough Park',
#   '2010-09-07 02:38:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['959',
#   'NGHBR: Borough Park',
#   '2010-09-07 12:43:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['960',
#   'NGHBR: Borough Park',
#   '2010-09-08 19:35:27',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['961',
#   'NGHBR: Borough Park',
#   '2010-09-08 23:33:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['962',
#   'NGHBR: Borough Park',
#   '2010-09-08 23:42:40',
#   'Noise - Residential',
#   'Loud Talking',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['963',
#   'NGHBR: Borough Park',
#   '2010-09-09 00:12:37',
#   'Noise - Residential',
#   'Loud Talking',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['964',
#   'NGHBR: Borough Park',
#   '2010-09-09 01:18:38',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['965',
#   'NGHBR: Borough Park',
#   '2010-09-09 01:32:01',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['966',
#   'NGHBR: Borough Park',
#   '2010-09-09 05:02:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['967',
#   'NGHBR: Borough Park',
#   '2010-09-09 14:57:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['968',
#   'NGHBR: Borough Park',
#   '2010-09-09 21:25:51',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['969',
#   'NGHBR: Borough Park',
#   '2010-09-09 21:40:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['970',
#   'NGHBR: Borough Park',
#   '2010-09-09 21:42:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['971',
#   'NGHBR: Borough Park',
#   '2010-09-09 21:44:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['972',
#   'NGHBR: Borough Park',
#   '2010-09-09 22:01:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['973',
#   'NGHBR: Borough Park',
#   '2010-09-10 01:25:00',
#   'Noise',
#   'Noise: Construction Before/After Hours (NM1)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['974',
#   'NGHBR: Borough Park',
#   '2010-09-10 02:41:48',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['975',
#   'NGHBR: Borough Park',
#   '2010-09-10 03:48:13',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['976',
#   'NGHBR: Borough Park',
#   '2010-09-10 09:10:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['977',
#   'NGHBR: Borough Park',
#   '2010-09-10 17:24:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['978',
#   'NGHBR: Borough Park',
#   '2010-09-10 19:50:43',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['979',
#   'NGHBR: Borough Park',
#   '2010-09-10 20:10:49',
#   'Noise - Vehicle',
#   'Car/Truck Music',
#   'Street/Sidewalk',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['980',
#   'NGHBR: Borough Park',
#   '2010-09-10 23:07:04',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['981',
#   'NGHBR: Borough Park',
#   '2010-09-11 11:25:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['982',
#   'NGHBR: Borough Park',
#   '2010-09-11 21:22:05',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['983',
#   'NGHBR: Borough Park',
#   '2010-09-11 21:30:14',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['984',
#   'NGHBR: Borough Park',
#   '2010-09-11 22:06:00',
#   'Noise',
#   'Noise: Construction Before/After Hours (NM1)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['985',
#   'NGHBR: Borough Park',
#   '2010-09-11 23:30:27',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['986',
#   'NGHBR: Borough Park',
#   '2010-09-12 01:43:50',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['987',
#   'NGHBR: Borough Park',
#   '2010-09-12 07:55:32',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['988',
#   'NGHBR: Borough Park',
#   '2010-09-12 14:24:30',
#   'Noise - Vehicle',
#   'Car/Truck Horn',
#   'Street/Sidewalk',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['989',
#   'NGHBR: Borough Park',
#   '2010-09-12 14:37:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['990',
#   'NGHBR: Borough Park',
#   '2010-09-12 18:51:14',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['991',
#   'NGHBR: Borough Park',
#   '2010-09-12 19:10:01',
#   'Noise - Street/Sidewalk',
#   'Loud Talking',
#   'Street/Sidewalk',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['992',
#   'NGHBR: Borough Park',
#   '2010-09-12 20:24:19',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['993',
#   'NGHBR: Borough Park',
#   '2010-09-12 21:24:41',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['994',
#   'NGHBR: Borough Park',
#   '2010-09-12 22:25:45',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['995',
#   'NGHBR: Borough Park',
#   '2010-09-13 02:43:00',
#   'Noise',
#   'Noise: Construction Before/After Hours (NM1)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['996',
#   'NGHBR: Borough Park',
#   '2010-09-13 03:14:00',
#   'Collection Truck Noise',
#   '21 Collection Truck Noise',
#   'Sidewalk',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['997',
#   'NGHBR: Borough Park',
#   '2010-09-13 13:58:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['998',
#   'NGHBR: Borough Park',
#   '2010-09-13 14:39:10',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ['999',
#   'NGHBR: Borough Park',
#   '2010-09-13 17:13:00',
#   'Collection Truck Noise',
#   '21 Collection Truck Noise',
#   'Sidewalk',
#   '11230',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Within Lower IQR',
#   'Poverty Level Higher than Median'],
#  ...]

# %%
thresh = 0.1
min_sup = thresh*len(y2010)
patterns2010 = pyfpgrowth.find_frequent_patterns(y2010, min_sup)
p2010_norm = {k: v / len(y2010) for k, v in patterns2010.items()}
patterns_sorted1 = sorted(p2010_norm.items(), key=lambda x: x[1],reverse=True)
rules1 = pyfpgrowth.generate_association_rules(patterns2010, 0.7)
rules_sorted1 = sorted(rules1.items(), key=lambda x: x[1],reverse=True)
directory = "e:/Franco/Documents/DataMining/"
with open(directory1+'patterns2010.csv', 'w', newline='\n') as csvfile:
    filewriter = csv.writer(csvfile)
    filewriter.writerows(patterns_sorted1)
with open(directory1+'rules2010.csv', 'w', newline='\n') as csvfile:
    filewriter = csv.writer(csvfile)
    filewriter.writerows(rules_sorted1)

# %%
#year2011 = year2011.drop(year2011.columns[[0,1,2]],axis=1)
year2011 = year2011.drop('Year',1)
year2011 = year2011.applymap(str)
y2011 = year2011.values.tolist()
min_sup = thresh*len(y2011)
patterns2011 = pyfpgrowth.find_frequent_patterns(y2011, min_sup)
p2011_norm = {k: v / len(y2011) for k, v in patterns2011.items()}
patterns_sorted1 = sorted(p2011_norm.items(), key=lambda x: x[1],reverse=True)
rules1 = pyfpgrowth.generate_association_rules(patterns2011, 0.7)
rules_sorted1 = sorted(rules1.items(), key=lambda x: x[1],reverse=True)
directory = "e:/Franco/Documents/DataMining/"
with open(directory1+'patterns2011.csv', 'w', newline='\n') as csvfile:
    filewriter = csv.writer(csvfile)
    filewriter.writerows(patterns_sorted1)
with open(directory1+'rules2011.csv', 'w', newline='\n') as csvfile:
    filewriter = csv.writer(csvfile)
    filewriter.writerows(rules_sorted1)

# %%
#year2012 = year2012.drop(year2012.columns[[0,1,2]],axis=1)
year2012 = year2012.drop('Year',1)
year2012 = year2012.applymap(str)
y2012 = year2012.values.tolist()
min_sup = thresh*len(y2012)
patterns2012 = pyfpgrowth.find_frequent_patterns(y2012, min_sup)
p2012_norm = {k: v / len(y2012) for k, v in patterns2012.items()}
patterns_sorted1 = sorted(p2012_norm.items(), key=lambda x: x[1],reverse=True)
rules1 = pyfpgrowth.generate_association_rules(patterns2012, 0.7)
rules_sorted1 = sorted(rules1.items(), key=lambda x: x[1],reverse=True)
directory = "e:/Franco/Documents/DataMining/"
with open(directory1+'patterns2012.csv', 'w', newline='\n') as csvfile:
    filewriter = csv.writer(csvfile)
    filewriter.writerows(patterns_sorted1)
with open(directory1+'rules2012.csv', 'w', newline='\n') as csvfile:
    filewriter = csv.writer(csvfile)
    filewriter.writerows(rules_sorted1)

# %%
#year2013 = year2013.drop(year2013.columns[[0,1,2]],axis=1)
year2013 = year2013.drop('Year',1)
year2013 = year2013.applymap(str)
y2013 = year2013.values.tolist()
min_sup = thresh*len(y2013)
patterns2013 = pyfpgrowth.find_frequent_patterns(y2013, min_sup)
p2013_norm = {k: v / len(y2013) for k, v in patterns2013.items()}
patterns_sorted1 = sorted(p2013_norm.items(), key=lambda x: x[1],reverse=True)
rules1 = pyfpgrowth.generate_association_rules(patterns2013, 0.7)
rules_sorted1 = sorted(rules1.items(), key=lambda x: x[1],reverse=True)
directory = "e:/Franco/Documents/DataMining/"
with open(directory1+'patterns2013.csv', 'w', newline='\n') as csvfile:
    filewriter = csv.writer(csvfile)
    filewriter.writerows(patterns_sorted1)
with open(directory1+'rules2013.csv', 'w', newline='\n') as csvfile:
    filewriter = csv.writer(csvfile)
    filewriter.writerows(rules_sorted1)

# %%
#year2014 = year2014.drop(year2014.columns[[0,1,2]],axis=1)
year2014 = year2014.drop('Year',1)
year2014 = year2014.applymap(str)
y2014 = year2014.values.tolist()
min_sup = thresh*len(y2014)
patterns2014 = pyfpgrowth.find_frequent_patterns(y2014, min_sup)
p2014_norm = {k: v / len(y2014) for k, v in patterns2014.items()}
patterns_sorted1 = sorted(p2014_norm.items(), key=lambda x: x[1],reverse=True)
rules1 = pyfpgrowth.generate_association_rules(patterns2014, 0.7)
rules_sorted1 = sorted(rules1.items(), key=lambda x: x[1],reverse=True)
directory = "e:/Franco/Documents/DataMining/"
with open(directory1+'patterns2014.csv', 'w', newline='\n') as csvfile:
    filewriter = csv.writer(csvfile)
    filewriter.writerows(patterns_sorted1)
with open(directory1+'rules2014.csv', 'w', newline='\n') as csvfile:
    filewriter = csv.writer(csvfile)
    filewriter.writerows(rules_sorted1)

# %%
#year2015 = year2015.drop(year2015.columns[[0,1,2]],axis=1)
year2015 = year2015.drop('Year',1)
year2015 = year2015.applymap(str)
y2015 = year2015.values.tolist()
min_sup = thresh*len(y2015)
patterns2015 = pyfpgrowth.find_frequent_patterns(y2015, min_sup)
p2015_norm = {k: v / len(y2015) for k, v in patterns2015.items()}
patterns_sorted1 = sorted(p2015_norm.items(), key=lambda x: x[1],reverse=True)
rules1 = pyfpgrowth.generate_association_rules(patterns2015, 0.7)
rules_sorted1 = sorted(rules1.items(), key=lambda x: x[1],reverse=True)
directory = "e:/Franco/Documents/DataMining/"
with open(directory1+'patterns2015.csv', 'w', newline='\n') as csvfile:
    filewriter = csv.writer(csvfile)
    filewriter.writerows(patterns_sorted1)
with open(directory1+'rules2015.csv', 'w', newline='\n') as csvfile:
    filewriter = csv.writer(csvfile)
    filewriter.writerows(rules_sorted1)

# %% [markdown]
# #Based on Separate Boroughs
# This area has code for reading the separate boroughs, rather than a single file. Since we decided on using a single file, this section was not used for the final results.

# %%
directory = "e:/Franco/Documents/DataMining/"
bronx = pd.read_csv(directory+"bronx1.csv",sep = '\t')
staten = pd.read_csv(directory+"staten.csv",sep = '\t')
Man = pd.read_csv(directory+"manhattan.csv",sep = '\t')
Brook = pd.read_csv(directory+"brooklyn.csv",sep = '\t')
queens = pd.read_csv(directory+"queens.csv",sep = '\t')
df1 = [bronx,queens,Man,Brook,staten]
df2 = pd.concat(df1)
df2 = df2.drop('City',1)
df2['Created_Date'] =pd.to_datetime(df2.Created_Date)
df2['Neighborhood'] = 'NGHBR: '+df2['Neighborhood'].astype(str)
df2 = df2.sort_values('Year')
year2010 = df2.loc[df2["Created_Date"].dt.year == 2010] 
year2011 = df2.loc[df2["Created_Date"].dt.year == 2011] 
year2012 = df2.loc[df2["Created_Date"].dt.year == 2012] 
year2013 = df2.loc[df2["Created_Date"].dt.year == 2013] 
year2014 = df2.loc[df2["Created_Date"].dt.year == 2014] 
year2015 = df2.loc[df2["Created_Date"].dt.year == 2015]
#then you can check the size of for example, 2010's 
year2010.shape
#save them into new csv files:
directory1 = "e:/Franco/Documents/DataMining/"
year2010.to_csv(directory1+'year2010.csv', sep = "\t")
year2011.to_csv(directory1+'year2011.csv', sep = "\t")
year2012.to_csv(directory1+'year2012.csv', sep = "\t")
year2013.to_csv(directory1+'year2013.csv', sep = "\t")
year2014.to_csv(directory1+'year2014.csv', sep = "\t")
year2015.to_csv(directory1+'year2015.csv', sep = "\t")

# %%
df2 = df2.drop(df2[[0]],1)

# %%
df2 = df2.applymap(str)
total_data = df2.values.tolist()

# %%
total_data
# Out:
# [['NGHBR: Central Bronx',
#   '2010-01-01 00:19:07',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   'BRONX',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-15 23:01:07',
#   'Noise - Street/Sidewalk',
#   'Loud Talking',
#   'Street/Sidewalk',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-15 20:50:54',
#   'Noise - Residential',
#   'Loud Television',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-15 20:45:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-14 22:57:09',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-14 22:39:56',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-14 22:23:00',
#   'Noise',
#   'Noise: Air Condition/Ventilation Equip, Residential (NJ1)',
#   'nan',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-14 22:22:05',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-14 21:22:00',
#   'Noise',
#   'Noise: Air Condition/Ventilation Equip, Residential (NJ1)',
#   'nan',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-14 09:22:26',
#   'Noise - Residential',
#   'Loud Talking',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-14 02:46:52',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-14 01:55:51',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-17 01:24:10',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-14 01:00:46',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-12 22:26:47',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-11 20:10:57',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-11 17:14:27',
#   'Noise - Street/Sidewalk',
#   'Loud Music/Party',
#   'Street/Sidewalk',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-10 16:20:22',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-10 09:45:49',
#   'Noise - Commercial',
#   'Loud Talking',
#   'Store/Commercial',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-09 09:44:19',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-08 11:09:05',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-07 23:36:21',
#   'Noise - Vehicle',
#   'Car/Truck Music',
#   'Street/Sidewalk',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-07 22:24:01',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-07 07:31:29',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-06 15:23:03',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-13 19:26:42',
#   'Noise - Residential',
#   'Loud Talking',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-17 03:00:40',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-17 21:20:39',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-17 22:04:50',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-29 23:41:31',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-28 23:30:53',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-27 11:26:50',
#   'Noise - Vehicle',
#   'Car/Truck Music',
#   'Street/Sidewalk',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-26 22:34:35',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-26 11:02:00',
#   'Noise',
#   'Noise: Private Carting Noise (NQ1)',
#   'nan',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-26 09:52:38',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-26 09:01:32',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Store/Commercial',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-25 23:23:04',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-25 18:04:16',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-25 03:30:42',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-24 22:20:06',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-24 22:09:07',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-24 21:00:40',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-24 19:04:00',
#   'Noise',
#   'Noise: Air Condition/Ventilation Equip, Residential (NJ1)',
#   'nan',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-24 00:10:41',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-22 18:03:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-22 03:59:10',
#   'Noise - Vehicle',
#   'Car/Truck Music',
#   'Street/Sidewalk',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-20 20:28:51',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-20 20:13:03',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-19 22:00:04',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-18 14:28:45',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-18 04:38:54',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-18 01:44:19',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-18 00:46:05',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-18 00:44:00',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-05 13:35:49',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-03 21:38:11',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-03 15:22:39',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-03 12:09:27',
#   'Noise - Street/Sidewalk',
#   'Loud Music/Party',
#   'Street/Sidewalk',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-13 08:23:34',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-11 15:53:14',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-11 09:07:08',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-11 06:33:10',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-10 01:55:33',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-09 20:56:51',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-07 22:46:08',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-07 06:25:44',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-07 01:24:13',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Club/Bar/Restaurant',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-06 20:43:41',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-06 16:10:46',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-06 05:19:07',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-04 10:30:48',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-02 22:03:31',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-02 21:15:30',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-01 10:47:22',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-02-28 06:42:57',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-02-27 20:47:32',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-02-25 18:22:37',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-02-24 12:32:42',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-02-24 11:27:40',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-02-24 02:18:39',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-02-23 18:37:41',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-02-23 13:41:32',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-02-22 17:20:26',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-14 04:03:45',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-30 21:49:21',
#   'Noise - Residential',
#   'Loud Talking',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-15 05:40:06',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-15 18:19:28',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-03 05:35:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-02 21:22:29',
#   'Noise - Street/Sidewalk',
#   'Loud Music/Party',
#   'Street/Sidewalk',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-02 20:04:08',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-02 02:49:14',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Club/Bar/Restaurant',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-31 11:51:54',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-30 17:55:54',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-29 20:01:55',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-28 23:35:00',
#   'Noise',
#   'Noise: Air Condition/Ventilation Equip, Residential (NJ1)',
#   'nan',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-28 20:20:53',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-27 19:46:55',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-22 00:33:34',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-21 05:47:16',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-20 16:38:46',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-20 15:50:18',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-20 02:06:26',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-19 23:33:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-19 15:13:12',
#   'Noise - Vehicle',
#   'Car/Truck Music',
#   'Street/Sidewalk',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-19 09:46:43',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Store/Commercial',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-19 09:19:30',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Store/Commercial',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-19 02:25:44',
#   'Noise - Park',
#   'Loud Talking',
#   'Park/Playground',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-18 21:55:45',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-17 22:41:34',
#   'Noise - Street/Sidewalk',
#   'Loud Talking',
#   'Street/Sidewalk',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-17 21:36:50',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-16 23:30:52',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-16 19:55:52',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-03-15 08:54:29',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-02-21 23:04:38',
#   'Noise - Residential',
#   'Loud Talking',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-04-30 22:51:45',
#   'Noise - Residential',
#   'Loud Talking',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-05-01 16:51:00',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-05-29 17:58:22',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-05-29 17:49:57',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-05-29 17:39:33',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-05-29 17:02:00',
#   'Noise',
#   'Noise: Air Condition/Ventilation Equip, Residential (NJ1)',
#   'nan',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-05-29 04:41:07',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-05-29 00:25:03',
#   'Noise - Street/Sidewalk',
#   'Loud Talking',
#   'Street/Sidewalk',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-05-28 21:23:07',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-05-28 20:56:07',
#   'Noise - Vehicle',
#   'Car/Truck Music',
#   'Street/Sidewalk',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-05-28 19:58:38',
#   'Noise - Street/Sidewalk',
#   'Loud Music/Party',
#   'Street/Sidewalk',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-05-27 22:09:27',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Club/Bar/Restaurant',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-05-27 19:56:22',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-05-29 20:25:40',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Jamaica',
#   '2010-05-27 08:19:52',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11433',
#   'QUEENS',
#   '103',
#   'Population Lower than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
# ...
#   'Noise - Street/Sidewalk',
#   'Loud Talking',
#   'Street/Sidewalk',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-07-29 21:43:04',
#   'Noise - Residential',
#   'Loud Talking',
#   'Residential Building/House',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-07-28 02:56:00',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-07-28 01:54:57',
#   'Noise - Street/Sidewalk',
#   'Loud Talking',
#   'Street/Sidewalk',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-07-28 01:44:44',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Club/Bar/Restaurant',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-07-27 23:00:52',
#   'Noise - Commercial',
#   'Loud Talking',
#   'Club/Bar/Restaurant',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-07-27 17:33:01',
#   'Noise - Vehicle',
#   'Car/Truck Music',
#   'Street/Sidewalk',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-07-27 01:33:22',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-07-27 01:17:07',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-07-26 23:38:37',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-07-25 02:33:08',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-07-25 00:47:06',
#   'Noise - Commercial',
#   'Car/Truck Music',
#   'Store/Commercial',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-07-23 23:23:46',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-07-23 11:11:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-07-22 13:44:00',
#   'Noise',
#   'Noise, Ice Cream Truck (NR4)',
#   'nan',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-07-22 13:13:00',
#   'Noise',
#   'Noise, Ice Cream Truck (NR4)',
#   'nan',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-07-21 14:31:32',
#   'Noise - Street/Sidewalk',
#   'Loud Music/Party',
#   'Street/Sidewalk',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-07-21 13:51:40',
#   'Noise - Street/Sidewalk',
#   'Loud Talking',
#   'Street/Sidewalk',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-07-21 13:13:46',
#   'Noise - Street/Sidewalk',
#   'Loud Talking',
#   'Street/Sidewalk',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-07-03 14:28:07',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-07-02 00:33:04',
#   'Noise - Street/Sidewalk',
#   'Loud Talking',
#   'Street/Sidewalk',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-06-30 22:47:00',
#   'Noise',
#   'Noise: Construction Before/After Hours (NM1)',
#   'nan',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-06-30 21:32:15',
#   'Noise - Street/Sidewalk',
#   'Loud Music/Party',
#   'Street/Sidewalk',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-06-13 23:57:42',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Club/Bar/Restaurant',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-06-13 18:22:00',
#   'Noise',
#   'Noise: Air Condition/Ventilation Equip, Commercial (NJ2)',
#   'nan',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-06-13 05:48:35',
#   'Noise - Street/Sidewalk',
#   'Loud Talking',
#   'Street/Sidewalk',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-06-13 02:17:50',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Club/Bar/Restaurant',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-06-13 01:25:50',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Club/Bar/Restaurant',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-06-13 00:23:04',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Club/Bar/Restaurant',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-06-12 09:15:37',
#   'Noise - Commercial',
#   'Loud Talking',
#   'Club/Bar/Restaurant',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-06-12 09:02:07',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Club/Bar/Restaurant',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-06-11 22:39:39',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-06-10 01:27:37',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Club/Bar/Restaurant',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-06-10 01:16:09',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-06-09 21:05:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-06-09 04:02:57',
#   'Noise - Street/Sidewalk',
#   'Loud Music/Party',
#   'Street/Sidewalk',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-06-09 01:23:01',
#   'Noise - Street/Sidewalk',
#   'Loud Talking',
#   'Street/Sidewalk',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-06-08 23:34:45',
#   'Noise - Commercial',
#   'Loud Talking',
#   'Club/Bar/Restaurant',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-06-08 17:41:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   'nan',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-06-08 13:18:00',
#   'Noise',
#   'Noise: Air Condition/Ventilation Equip, Commercial (NJ2)',
#   'nan',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-06-08 12:45:00',
#   'Noise',
#   'Noise: Jack Hammering (NC2)',
#   'nan',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-06-08 02:01:00',
#   'Noise',
#   'Noise: Construction Equipment (NC1)',
#   'nan',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ['NGHBR: Northwest Queens',
#   '2010-06-06 23:58:55',
#   'Noise - Park',
#   'Loud Talking',
#   'Park/Playground',
#   '11103',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR',
#   'Noise Lower than IQR'],
#  ...]

# %%
bronx = bronx.drop('City',1)
bronx = bronx.drop('Borough',1)
bronx['Neighborhood'] = 'NGHBR: '+bronx['Neighborhood'].astype(str)
bronx = bronx.applymap(str)
bronx1 = bronx.values.tolist()
bronx_pats,bronx_rules = mine_patterns(bronx1,thresh,0.7,'Bronx')

# %%
brook
# Out:
#         Unnamed: 0            Neighborhood         Created_Date  \
# 0                0            Borough Park  2010-01-01 00:03:46
# 1                1            Borough Park  2010-01-01 00:36:01
# 2                2            Borough Park  2010-01-01 01:21:11
# 3                3            Borough Park  2010-01-01 02:14:21
# 4                4            Borough Park  2010-01-01 02:59:07
# 5                5            Borough Park  2010-01-01 03:35:54
# 6                6            Borough Park  2010-01-01 15:48:01
# 7                7            Borough Park  2010-01-01 20:34:37
# 8                8            Borough Park  2010-01-01 22:33:15
# 9                9            Borough Park  2010-01-02 07:52:38
# 10              10            Borough Park  2010-01-02 12:43:44
# 11              11            Borough Park  2010-01-03 10:43:41
# 12              12            Borough Park  2010-01-03 10:53:16
# 13              13            Borough Park  2010-01-05 01:41:00
# 14              14            Borough Park  2010-01-05 11:03:22
# 15              15            Borough Park  2010-01-06 09:16:12
# 16              16            Borough Park  2010-01-06 11:11:00
# 17              17            Borough Park  2010-01-07 09:44:15
# 18              18            Borough Park  2010-01-07 15:12:25
# 19              19            Borough Park  2010-01-07 23:38:50
# 20              20            Borough Park  2010-01-08 02:42:50
# 21              21            Borough Park  2010-01-08 03:05:49
# 22              22            Borough Park  2010-01-08 21:46:24
# 23              23            Borough Park  2010-01-08 22:11:17
# 24              24            Borough Park  2010-01-08 23:48:50
# 25              25            Borough Park  2010-01-09 00:29:37
# 26              26            Borough Park  2010-01-09 01:05:37
# 27              27            Borough Park  2010-01-09 03:05:28
# 28              28            Borough Park  2010-01-09 05:22:45
# 29              29            Borough Park  2010-01-09 20:40:10
# ...            ...                     ...                  ...
# 1518549    1518549  Canarsie and Flatlands  2015-09-12 19:15:03
# 1518550    1518550  Canarsie and Flatlands  2015-09-12 23:27:11
# 1518551    1518551  Canarsie and Flatlands  2015-09-17 16:03:09
# 1518552    1518552  Canarsie and Flatlands  2015-09-17 20:19:03
# 1518553    1518553  Canarsie and Flatlands  2015-09-20 00:49:47
# 1518554    1518554  Canarsie and Flatlands  2015-09-20 13:40:43
# 1518555    1518555  Canarsie and Flatlands  2015-09-20 13:51:26
# 1518556    1518556  Canarsie and Flatlands  2015-09-20 14:36:15
# 1518557    1518557  Canarsie and Flatlands  2015-09-22 12:32:08
# 1518558    1518558  Canarsie and Flatlands  2015-10-05 19:54:02
# 1518559    1518559  Canarsie and Flatlands  2015-10-09 14:01:52
# 1518560    1518560  Canarsie and Flatlands  2015-10-10 16:40:24
# 1518561    1518561  Canarsie and Flatlands  2015-10-11 03:42:34
# 1518562    1518562  Canarsie and Flatlands  2015-10-18 19:51:01
# 1518563    1518563  Canarsie and Flatlands  2015-10-18 23:00:24
# 1518564    1518564  Canarsie and Flatlands  2015-10-29 11:18:00
# 1518565    1518565  Canarsie and Flatlands  2015-10-31 23:52:03
# 1518566    1518566  Canarsie and Flatlands  2015-11-07 00:06:22
# 1518567    1518567  Canarsie and Flatlands  2015-11-11 19:35:31
# 1518568    1518568  Canarsie and Flatlands  2015-11-13 18:54:14
# 1518569    1518569  Canarsie and Flatlands  2015-11-13 19:42:29
# 1518570    1518570  Canarsie and Flatlands  2015-11-17 17:10:00
# 1518571    1518571  Canarsie and Flatlands  2015-11-23 23:06:33
# 1518572    1518572  Canarsie and Flatlands  2015-11-27 00:29:10
# 1518573    1518573  Canarsie and Flatlands  2015-11-30 10:20:57
# 1518574    1518574  Canarsie and Flatlands  2015-12-04 13:01:00
# 1518575    1518575  Canarsie and Flatlands  2015-12-12 11:37:53
# 1518576    1518576  Canarsie and Flatlands  2015-12-15 08:00:24
# 1518577    1518577  Canarsie and Flatlands  2015-12-26 03:10:54
# 1518578    1518578  Canarsie and Flatlands  2015-12-31 13:47:57
#
#               Complaint Type  \
# 0        Noise - Residential
# 1         Noise - Commercial
# 2         Noise - Commercial
# 3         Noise - Commercial
# 4        Noise - Residential
# 5         Noise - Commercial
# 6        Noise - Residential
# 7        Noise - Residential
# 8        Noise - Residential
# 9        Noise - Residential
# 10       Noise - Residential
# 11       Noise - Residential
# 12       Noise - Residential
# 13                     Noise
# 14       Noise - Residential
# 15       Noise - Residential
# 16                     Noise
# 17       Noise - Residential
# 18       Noise - Residential
# 19       Noise - Residential
# 20       Noise - Residential
# 21       Noise - Residential
# 22       Noise - Residential
# 23       Noise - Residential
# 24       Noise - Residential
# 25       Noise - Residential
# 26       Noise - Residential
# 27       Noise - Residential
# 28           Noise - Vehicle
# 29       Noise - Residential
# ...                      ...
# 1518549  Noise - Residential
# 1518550  Noise - Residential
# 1518551  Noise - Residential
# 1518552  Noise - Residential
# 1518553  Noise - Residential
# 1518554  Noise - Residential
# 1518555  Noise - Residential
# 1518556  Noise - Residential
# 1518557  Noise - Residential
# 1518558  Noise - Residential
# 1518559  Noise - Residential
# 1518560  Noise - Residential
# 1518561  Noise - Residential
# 1518562  Noise - Residential
# 1518563  Noise - Residential
# 1518564  Noise - Residential
# 1518565  Noise - Residential
# 1518566  Noise - Residential
# 1518567  Noise - Residential
# 1518568  Noise - Residential
# 1518569  Noise - Residential
# 1518570                Noise
# 1518571  Noise - Residential
# 1518572  Noise - Residential
# 1518573  Noise - Residential
# 1518574                Noise
# 1518575  Noise - Residential
# 1518576  Noise - Residential
# 1518577  Noise - Residential
# 1518578  Noise - Residential
#
#                                                 Descriptor  \
# 0                                          Loud Television
# 1                                         Loud Music/Party
# 2                                         Loud Music/Party
# 3                                         Loud Music/Party
# 4                                         Loud Music/Party
# 5                                             Loud Talking
# 6                                         Loud Music/Party
# 7                                         Loud Music/Party
# 8                                             Loud Talking
# 9                                         Banging/Pounding
# 10                                        Loud Music/Party
# 11                                            Loud Talking
# 12                                        Banging/Pounding
# 13       Noise: Air Condition/Ventilation Equip, Reside...
# 14                                        Loud Music/Party
# 15                                        Banging/Pounding
# 16                       Horn Honking Sign Requested (NR9)
# 17                                        Banging/Pounding
# 18                                         Loud Television
# 19                                        Loud Music/Party
# 20                                        Loud Music/Party
# 21                                        Banging/Pounding
# 22                                        Banging/Pounding
# 23                                        Loud Music/Party
# 24                                        Banging/Pounding
# 25                                        Banging/Pounding
# 26                                        Loud Music/Party
# 27                                        Loud Music/Party
# 28                                           Engine Idling
# 29                                        Loud Music/Party
# ...                                                    ...
# 1518549                                   Banging/Pounding
# 1518550                                   Banging/Pounding
# 1518551                                   Banging/Pounding
# 1518552                                   Banging/Pounding
# 1518553                                   Loud Music/Party
# 1518554                                   Banging/Pounding
# 1518555                                   Banging/Pounding
# 1518556                                   Banging/Pounding
# 1518557                                   Banging/Pounding
# 1518558                                   Banging/Pounding
# 1518559                                   Banging/Pounding
# 1518560                                   Banging/Pounding
# 1518561                                   Loud Music/Party
# 1518562                                   Banging/Pounding
# 1518563                                   Banging/Pounding
# 1518564                                   Banging/Pounding
# 1518565                                   Loud Music/Party
# 1518566                                   Loud Music/Party
# 1518567                                   Banging/Pounding
# 1518568                                       Loud Talking
# 1518569                                       Loud Talking
# 1518570                           Noise, Barking Dog (NR5)
# 1518571                                   Loud Music/Party
# 1518572                                   Loud Music/Party
# 1518573                                   Banging/Pounding
# 1518574                           Noise, Barking Dog (NR5)
# 1518575                                   Loud Music/Party
# 1518576                                   Loud Music/Party
# 1518577                                   Loud Music/Party
# 1518578                                   Banging/Pounding
#
#                       Location Type Zip Code             City Precinct  \
# 0        Residential Building/House    11230  NGHBR: BROOKLYN       70
# 1                  Store/Commercial    11230  NGHBR: BROOKLYN       70
# 2                  Store/Commercial    11230  NGHBR: BROOKLYN       70
# 3                  Store/Commercial    11230  NGHBR: BROOKLYN       70
# 4        Residential Building/House    11230  NGHBR: BROOKLYN       70
# 5                  Store/Commercial    11230  NGHBR: BROOKLYN       70
# 6        Residential Building/House    11230  NGHBR: BROOKLYN       70
# 7        Residential Building/House    11230  NGHBR: BROOKLYN       70
# 8        Residential Building/House    11230  NGHBR: BROOKLYN       70
# 9        Residential Building/House    11230  NGHBR: BROOKLYN       70
# 10       Residential Building/House    11230  NGHBR: BROOKLYN       70
# 11       Residential Building/House    11230  NGHBR: BROOKLYN       70
# 12       Residential Building/House    11230  NGHBR: BROOKLYN       70
# 13                              nan    11230  NGHBR: BROOKLYN       70
# 14       Residential Building/House    11230  NGHBR: BROOKLYN       70
# 15       Residential Building/House    11230  NGHBR: BROOKLYN       70
# 16                              nan    11230  NGHBR: BROOKLYN       70
# 17       Residential Building/House    11230  NGHBR: BROOKLYN       70
# 18       Residential Building/House    11230  NGHBR: BROOKLYN       70
# 19       Residential Building/House    11230  NGHBR: BROOKLYN       70
# 20       Residential Building/House    11230  NGHBR: BROOKLYN       70
# 21       Residential Building/House    11230  NGHBR: BROOKLYN       70
# 22       Residential Building/House    11230  NGHBR: BROOKLYN       70
# 23       Residential Building/House    11230  NGHBR: BROOKLYN       70
# 24       Residential Building/House    11230  NGHBR: BROOKLYN       70
# 25       Residential Building/House    11230  NGHBR: BROOKLYN       70
# 26       Residential Building/House    11230  NGHBR: BROOKLYN       70
# 27       Residential Building/House    11230  NGHBR: BROOKLYN       70
# 28                  Street/Sidewalk    11230  NGHBR: BROOKLYN       70
# 29       Residential Building/House    11230  NGHBR: BROOKLYN       70
# ...                             ...      ...              ...      ...
# 1518549  Residential Building/House    11239  NGHBR: BROOKLYN       75
# 1518550  Residential Building/House    11239  NGHBR: BROOKLYN       75
# 1518551  Residential Building/House    11239  NGHBR: BROOKLYN       75
# 1518552  Residential Building/House    11239  NGHBR: BROOKLYN       75
# 1518553  Residential Building/House    11239  NGHBR: BROOKLYN       75
# 1518554  Residential Building/House    11239  NGHBR: BROOKLYN       75
# 1518555  Residential Building/House    11239  NGHBR: BROOKLYN       75
# 1518556  Residential Building/House    11239  NGHBR: BROOKLYN       75
# 1518557  Residential Building/House    11239  NGHBR: BROOKLYN       75
# 1518558  Residential Building/House    11239  NGHBR: BROOKLYN       75
# 1518559  Residential Building/House    11239  NGHBR: BROOKLYN       75
# 1518560  Residential Building/House    11239  NGHBR: BROOKLYN       75
# 1518561  Residential Building/House    11239  NGHBR: BROOKLYN       75
# 1518562  Residential Building/House    11239  NGHBR: BROOKLYN       75
# 1518563  Residential Building/House    11239  NGHBR: BROOKLYN       75
# 1518564  Residential Building/House    11239  NGHBR: BROOKLYN       75
# 1518565  Residential Building/House    11239  NGHBR: BROOKLYN       75
# 1518566  Residential Building/House    11239  NGHBR: BROOKLYN       75
# 1518567  Residential Building/House    11239  NGHBR: BROOKLYN       75
# 1518568  Residential Building/House    11239  NGHBR: BROOKLYN       75
# 1518569  Residential Building/House    11239  NGHBR: BROOKLYN       75
# 1518570                         nan    11239  NGHBR: BROOKLYN       75
# 1518571  Residential Building/House    11239  NGHBR: BROOKLYN       75
# 1518572  Residential Building/House    11239  NGHBR: BROOKLYN       75
# 1518573  Residential Building/House    11239  NGHBR: BROOKLYN       75
# 1518574                         nan    11239  NGHBR: BROOKLYN       75
# 1518575  Residential Building/House    11239  NGHBR: BROOKLYN       75
# 1518576  Residential Building/House    11239  NGHBR: BROOKLYN       75
# 1518577  Residential Building/House    11239  NGHBR: BROOKLYN       75
# 1518578  Residential Building/House    11239  NGHBR: BROOKLYN       75
#
#                          Population  Year     Violence Binning  \
# 0        Population Higher than IQR  2010  VC Within Lower IQR
# 1        Population Higher than IQR  2010  VC Within Lower IQR
# 2        Population Higher than IQR  2010  VC Within Lower IQR
# 3        Population Higher than IQR  2010  VC Within Lower IQR
# 4        Population Higher than IQR  2010  VC Within Lower IQR
# 5        Population Higher than IQR  2010  VC Within Lower IQR
# 6        Population Higher than IQR  2010  VC Within Lower IQR
# 7        Population Higher than IQR  2010  VC Within Lower IQR
# 8        Population Higher than IQR  2010  VC Within Lower IQR
# 9        Population Higher than IQR  2010  VC Within Lower IQR
# 10       Population Higher than IQR  2010  VC Within Lower IQR
# 11       Population Higher than IQR  2010  VC Within Lower IQR
# 12       Population Higher than IQR  2010  VC Within Lower IQR
# 13       Population Higher than IQR  2010  VC Within Lower IQR
# 14       Population Higher than IQR  2010  VC Within Lower IQR
# 15       Population Higher than IQR  2010  VC Within Lower IQR
# 16       Population Higher than IQR  2010  VC Within Lower IQR
# 17       Population Higher than IQR  2010  VC Within Lower IQR
# 18       Population Higher than IQR  2010  VC Within Lower IQR
# 19       Population Higher than IQR  2010  VC Within Lower IQR
# 20       Population Higher than IQR  2010  VC Within Lower IQR
# 21       Population Higher than IQR  2010  VC Within Lower IQR
# 22       Population Higher than IQR  2010  VC Within Lower IQR
# 23       Population Higher than IQR  2010  VC Within Lower IQR
# 24       Population Higher than IQR  2010  VC Within Lower IQR
# 25       Population Higher than IQR  2010  VC Within Lower IQR
# 26       Population Higher than IQR  2010  VC Within Lower IQR
# 27       Population Higher than IQR  2010  VC Within Lower IQR
# 28       Population Higher than IQR  2010  VC Within Lower IQR
# 29       Population Higher than IQR  2010  VC Within Lower IQR
# ...                             ...   ...                  ...
# 1518549   Population Lower than IQR  2015     VC High Outliers
# 1518550   Population Lower than IQR  2015     VC High Outliers
# 1518551   Population Lower than IQR  2015     VC High Outliers
# 1518552   Population Lower than IQR  2015     VC High Outliers
# 1518553   Population Lower than IQR  2015     VC High Outliers
# 1518554   Population Lower than IQR  2015     VC High Outliers
# 1518555   Population Lower than IQR  2015     VC High Outliers
# 1518556   Population Lower than IQR  2015     VC High Outliers
# 1518557   Population Lower than IQR  2015     VC High Outliers
# 1518558   Population Lower than IQR  2015     VC High Outliers
# 1518559   Population Lower than IQR  2015     VC High Outliers
# 1518560   Population Lower than IQR  2015     VC High Outliers
# 1518561   Population Lower than IQR  2015     VC High Outliers
# 1518562   Population Lower than IQR  2015     VC High Outliers
# 1518563   Population Lower than IQR  2015     VC High Outliers
# 1518564   Population Lower than IQR  2015     VC High Outliers
# 1518565   Population Lower than IQR  2015     VC High Outliers
# 1518566   Population Lower than IQR  2015     VC High Outliers
# 1518567   Population Lower than IQR  2015     VC High Outliers
# 1518568   Population Lower than IQR  2015     VC High Outliers
# 1518569   Population Lower than IQR  2015     VC High Outliers
# 1518570   Population Lower than IQR  2015     VC High Outliers
# 1518571   Population Lower than IQR  2015     VC High Outliers
# 1518572   Population Lower than IQR  2015     VC High Outliers
# 1518573   Population Lower than IQR  2015     VC High Outliers
# 1518574   Population Lower than IQR  2015     VC High Outliers
# 1518575   Population Lower than IQR  2015     VC High Outliers
# 1518576   Population Lower than IQR  2015     VC High Outliers
# 1518577   Population Lower than IQR  2015     VC High Outliers
# 1518578   Population Lower than IQR  2015     VC High Outliers
#
#                    Misd Binning          Major Binning  \
# 0        Misd Within Higher IQR  Major Higher than IQR
# 1        Misd Within Higher IQR  Major Higher than IQR
# 2        Misd Within Higher IQR  Major Higher than IQR
# 3        Misd Within Higher IQR  Major Higher than IQR
# 4        Misd Within Higher IQR  Major Higher than IQR
# 5        Misd Within Higher IQR  Major Higher than IQR
# 6        Misd Within Higher IQR  Major Higher than IQR
# 7        Misd Within Higher IQR  Major Higher than IQR
# 8        Misd Within Higher IQR  Major Higher than IQR
# 9        Misd Within Higher IQR  Major Higher than IQR
# 10       Misd Within Higher IQR  Major Higher than IQR
# 11       Misd Within Higher IQR  Major Higher than IQR
# 12       Misd Within Higher IQR  Major Higher than IQR
# 13       Misd Within Higher IQR  Major Higher than IQR
# 14       Misd Within Higher IQR  Major Higher than IQR
# 15       Misd Within Higher IQR  Major Higher than IQR
# 16       Misd Within Higher IQR  Major Higher than IQR
# 17       Misd Within Higher IQR  Major Higher than IQR
# 18       Misd Within Higher IQR  Major Higher than IQR
# 19       Misd Within Higher IQR  Major Higher than IQR
# 20       Misd Within Higher IQR  Major Higher than IQR
# 21       Misd Within Higher IQR  Major Higher than IQR
# 22       Misd Within Higher IQR  Major Higher than IQR
# 23       Misd Within Higher IQR  Major Higher than IQR
# 24       Misd Within Higher IQR  Major Higher than IQR
# 25       Misd Within Higher IQR  Major Higher than IQR
# 26       Misd Within Higher IQR  Major Higher than IQR
# 27       Misd Within Higher IQR  Major Higher than IQR
# 28       Misd Within Higher IQR  Major Higher than IQR
# 29       Misd Within Higher IQR  Major Higher than IQR
# ...                         ...                    ...
# 1518549      Misd High Outliers    Major High Outliers
# 1518550      Misd High Outliers    Major High Outliers
# 1518551      Misd High Outliers    Major High Outliers
# 1518552      Misd High Outliers    Major High Outliers
# 1518553      Misd High Outliers    Major High Outliers
# 1518554      Misd High Outliers    Major High Outliers
# 1518555      Misd High Outliers    Major High Outliers
# 1518556      Misd High Outliers    Major High Outliers
# 1518557      Misd High Outliers    Major High Outliers
# 1518558      Misd High Outliers    Major High Outliers
# 1518559      Misd High Outliers    Major High Outliers
# 1518560      Misd High Outliers    Major High Outliers
# 1518561      Misd High Outliers    Major High Outliers
# 1518562      Misd High Outliers    Major High Outliers
# 1518563      Misd High Outliers    Major High Outliers
# 1518564      Misd High Outliers    Major High Outliers
# 1518565      Misd High Outliers    Major High Outliers
# 1518566      Misd High Outliers    Major High Outliers
# 1518567      Misd High Outliers    Major High Outliers
# 1518568      Misd High Outliers    Major High Outliers
# 1518569      Misd High Outliers    Major High Outliers
# 1518570      Misd High Outliers    Major High Outliers
# 1518571      Misd High Outliers    Major High Outliers
# 1518572      Misd High Outliers    Major High Outliers
# 1518573      Misd High Outliers    Major High Outliers
# 1518574      Misd High Outliers    Major High Outliers
# 1518575      Misd High Outliers    Major High Outliers
# 1518576      Misd High Outliers    Major High Outliers
# 1518577      Misd High Outliers    Major High Outliers
# 1518578      Misd High Outliers    Major High Outliers
#
#                    Nonmajor Binning           Noise Binning  \
# 0        Nonmajor Within Higher IQR  Noise Within Lower IQR
# 1        Nonmajor Within Higher IQR  Noise Within Lower IQR
# 2        Nonmajor Within Higher IQR  Noise Within Lower IQR
# 3        Nonmajor Within Higher IQR  Noise Within Lower IQR
# 4        Nonmajor Within Higher IQR  Noise Within Lower IQR
# 5        Nonmajor Within Higher IQR  Noise Within Lower IQR
# 6        Nonmajor Within Higher IQR  Noise Within Lower IQR
# 7        Nonmajor Within Higher IQR  Noise Within Lower IQR
# 8        Nonmajor Within Higher IQR  Noise Within Lower IQR
# 9        Nonmajor Within Higher IQR  Noise Within Lower IQR
# 10       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 11       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 12       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 13       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 14       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 15       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 16       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 17       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 18       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 19       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 20       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 21       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 22       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 23       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 24       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 25       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 26       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 27       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 28       Nonmajor Within Higher IQR  Noise Within Lower IQR
# 29       Nonmajor Within Higher IQR  Noise Within Lower IQR
# ...                             ...                     ...
# 1518549      Nonmajor High Outliers    Noise Lower than IQR
# 1518550      Nonmajor High Outliers    Noise Lower than IQR
# 1518551      Nonmajor High Outliers    Noise Lower than IQR
# 1518552      Nonmajor High Outliers    Noise Lower than IQR
# 1518553      Nonmajor High Outliers    Noise Lower than IQR
# 1518554      Nonmajor High Outliers    Noise Lower than IQR
# 1518555      Nonmajor High Outliers    Noise Lower than IQR
# 1518556      Nonmajor High Outliers    Noise Lower than IQR
# 1518557      Nonmajor High Outliers    Noise Lower than IQR
# 1518558      Nonmajor High Outliers    Noise Lower than IQR
# 1518559      Nonmajor High Outliers    Noise Lower than IQR
# 1518560      Nonmajor High Outliers    Noise Lower than IQR
# 1518561      Nonmajor High Outliers    Noise Lower than IQR
# 1518562      Nonmajor High Outliers    Noise Lower than IQR
# 1518563      Nonmajor High Outliers    Noise Lower than IQR
# 1518564      Nonmajor High Outliers    Noise Lower than IQR
# 1518565      Nonmajor High Outliers    Noise Lower than IQR
# 1518566      Nonmajor High Outliers    Noise Lower than IQR
# 1518567      Nonmajor High Outliers    Noise Lower than IQR
# 1518568      Nonmajor High Outliers    Noise Lower than IQR
# 1518569      Nonmajor High Outliers    Noise Lower than IQR
# 1518570      Nonmajor High Outliers    Noise Lower than IQR
# 1518571      Nonmajor High Outliers    Noise Lower than IQR
# 1518572      Nonmajor High Outliers    Noise Lower than IQR
# 1518573      Nonmajor High Outliers    Noise Lower than IQR
# 1518574      Nonmajor High Outliers    Noise Lower than IQR
# 1518575      Nonmajor High Outliers    Noise Lower than IQR
# 1518576      Nonmajor High Outliers    Noise Lower than IQR
# 1518577      Nonmajor High Outliers    Noise Lower than IQR
# 1518578      Nonmajor High Outliers    Noise Lower than IQR
#
#                             Poverty Level
# 0        Poverty Level Higher than Median
# 1        Poverty Level Higher than Median
# 2        Poverty Level Higher than Median
# 3        Poverty Level Higher than Median
# 4        Poverty Level Higher than Median
# 5        Poverty Level Higher than Median
# 6        Poverty Level Higher than Median
# 7        Poverty Level Higher than Median
# 8        Poverty Level Higher than Median
# 9        Poverty Level Higher than Median
# 10       Poverty Level Higher than Median
# 11       Poverty Level Higher than Median
# 12       Poverty Level Higher than Median
# 13       Poverty Level Higher than Median
# 14       Poverty Level Higher than Median
# 15       Poverty Level Higher than Median
# 16       Poverty Level Higher than Median
# 17       Poverty Level Higher than Median
# 18       Poverty Level Higher than Median
# 19       Poverty Level Higher than Median
# 20       Poverty Level Higher than Median
# 21       Poverty Level Higher than Median
# 22       Poverty Level Higher than Median
# 23       Poverty Level Higher than Median
# 24       Poverty Level Higher than Median
# 25       Poverty Level Higher than Median
# 26       Poverty Level Higher than Median
# 27       Poverty Level Higher than Median
# 28       Poverty Level Higher than Median
# 29       Poverty Level Higher than Median
# ...                                   ...
# 1518549   Poverty Level Lower than Median
# 1518550   Poverty Level Lower than Median
# 1518551   Poverty Level Lower than Median
# 1518552   Poverty Level Lower than Median
# 1518553   Poverty Level Lower than Median
# 1518554   Poverty Level Lower than Median
# 1518555   Poverty Level Lower than Median
# 1518556   Poverty Level Lower than Median
# 1518557   Poverty Level Lower than Median
# 1518558   Poverty Level Lower than Median
# 1518559   Poverty Level Lower than Median
# 1518560   Poverty Level Lower than Median
# 1518561   Poverty Level Lower than Median
# 1518562   Poverty Level Lower than Median
# 1518563   Poverty Level Lower than Median
# 1518564   Poverty Level Lower than Median
# 1518565   Poverty Level Lower than Median
# 1518566   Poverty Level Lower than Median
# 1518567   Poverty Level Lower than Median
# 1518568   Poverty Level Lower than Median
# 1518569   Poverty Level Lower than Median
# 1518570   Poverty Level Lower than Median
# 1518571   Poverty Level Lower than Median
# 1518572   Poverty Level Lower than Median
# 1518573   Poverty Level Lower than Median
# 1518574   Poverty Level Lower than Median
# 1518575   Poverty Level Lower than Median
# 1518576   Poverty Level Lower than Median
# 1518577   Poverty Level Lower than Median
# 1518578   Poverty Level Lower than Median
#
# [466355 rows x 17 columns]

# %%
staten = staten.drop('City',1)
staten = staten.drop('Borough',1)
staten['Neighborhood'] = 'NGHBR: '+staten['Neighborhood'].astype(str)
staten = staten.drop(staten.columns[[0]],axis=1)
staten = staten.applymap(str)
staten1 = staten.values.tolist()
staten_pats,staten_rules = mine_patterns(staten1,thresh,0.7,'Staten')

# %%
Man = Man.drop('City',1)
Man = Man.drop('Borough',1)
Man['Neighborhood'] = 'NGHBR: '+Man['Neighborhood'].astype(str)
Man = Man.drop(Man.columns[[0,]],axis=1)
Man = Man.applymap(str)
Man1 = Man.values.tolist()
Man_pats,Man_rules = mine_patterns(Man1,thresh,0.7,'Manhattan')

# %%
Man
# Out:
#                              Neighborhood         Created_Date  \
# 0       NGHBR: Greenwich Village and Soho  2010-01-01 00:15:12
# 1       NGHBR: Greenwich Village and Soho  2010-01-01 00:48:39
# 2       NGHBR: Greenwich Village and Soho  2010-01-01 22:15:59
# 3       NGHBR: Greenwich Village and Soho  2010-01-01 23:56:53
# 4       NGHBR: Greenwich Village and Soho  2010-01-03 01:19:15
# 5       NGHBR: Greenwich Village and Soho  2010-01-04 23:16:24
# 6       NGHBR: Greenwich Village and Soho  2010-01-06 09:39:00
# 7       NGHBR: Greenwich Village and Soho  2010-01-06 11:51:00
# 8       NGHBR: Greenwich Village and Soho  2010-01-06 22:54:08
# 9       NGHBR: Greenwich Village and Soho  2010-01-06 23:48:16
# 10      NGHBR: Greenwich Village and Soho  2010-01-07 09:08:00
# 11      NGHBR: Greenwich Village and Soho  2010-01-07 23:27:46
# 12      NGHBR: Greenwich Village and Soho  2010-01-08 00:33:00
# 13      NGHBR: Greenwich Village and Soho  2010-01-08 01:32:05
# 14      NGHBR: Greenwich Village and Soho  2010-01-08 16:30:00
# 15      NGHBR: Greenwich Village and Soho  2010-01-08 22:33:07
# 16      NGHBR: Greenwich Village and Soho  2010-01-09 00:10:36
# 17      NGHBR: Greenwich Village and Soho  2010-01-09 02:48:59
# 18      NGHBR: Greenwich Village and Soho  2010-01-09 02:58:06
# 19      NGHBR: Greenwich Village and Soho  2010-01-09 12:37:11
# 20      NGHBR: Greenwich Village and Soho  2010-01-09 14:05:00
# 21      NGHBR: Greenwich Village and Soho  2010-01-09 17:03:18
# 22      NGHBR: Greenwich Village and Soho  2010-01-09 22:25:15
# 23      NGHBR: Greenwich Village and Soho  2010-01-09 23:01:10
# 24      NGHBR: Greenwich Village and Soho  2010-01-10 00:44:41
# 25      NGHBR: Greenwich Village and Soho  2010-01-10 00:56:06
# 26      NGHBR: Greenwich Village and Soho  2010-01-10 23:44:55
# 27      NGHBR: Greenwich Village and Soho  2010-01-11 12:59:50
# 28      NGHBR: Greenwich Village and Soho  2010-01-11 15:01:00
# 29      NGHBR: Greenwich Village and Soho  2010-01-11 19:51:49
# ...                                   ...                  ...
# 459806                         NGHBR: nan  2014-10-22 00:25:00
# 459807                         NGHBR: nan  2014-10-22 00:31:00
# 459808                         NGHBR: nan  2014-10-25 12:17:51
# 459809                         NGHBR: nan  2014-11-01 00:37:12
# 459810                         NGHBR: nan  2015-04-01 21:48:00
# 459811                         NGHBR: nan  2015-04-17 21:45:00
# 459812                         NGHBR: nan  2015-04-18 22:32:04
# 459813                         NGHBR: nan  2015-04-24 21:48:32
# 459814                         NGHBR: nan  2015-04-27 22:37:57
# 459815                         NGHBR: nan  2015-04-29 20:53:46
# 459816                         NGHBR: nan  2015-04-29 23:46:22
# 459817                         NGHBR: nan  2015-04-30 22:04:41
# 459818                         NGHBR: nan  2015-05-01 20:47:55
# 459819                         NGHBR: nan  2015-05-01 20:56:19
# 459820                         NGHBR: nan  2015-05-01 20:57:04
# 459821                         NGHBR: nan  2015-05-01 20:57:34
# 459822                         NGHBR: nan  2015-05-01 20:58:05
# 459823                         NGHBR: nan  2015-05-01 20:58:38
# 459824                         NGHBR: nan  2015-05-01 20:59:09
# 459825                         NGHBR: nan  2015-05-01 20:59:42
# 459826                         NGHBR: nan  2015-05-01 21:00:20
# 459827                         NGHBR: nan  2015-05-01 21:00:57
# 459828                         NGHBR: nan  2015-05-01 21:01:29
# 459829                         NGHBR: nan  2015-05-04 21:24:00
# 459830                         NGHBR: nan  2015-05-14 21:59:47
# 459831                         NGHBR: nan  2015-06-02 00:14:08
# 459832                         NGHBR: nan  2015-06-23 10:51:00
# 459833                         NGHBR: nan  2015-07-07 07:33:51
# 459834                         NGHBR: nan  2015-10-13 23:43:00
# 459835                         NGHBR: nan  2015-12-20 01:34:20
#
#                  Complaint Type  \
# 0           Noise - Residential
# 1            Noise - Commercial
# 2            Noise - Commercial
# 3            Noise - Commercial
# 4            Noise - Commercial
# 5            Noise - Commercial
# 6                         Noise
# 7                         Noise
# 8           Noise - Residential
# 9            Noise - Commercial
# 10                        Noise
# 11           Noise - Commercial
# 12                        Noise
# 13           Noise - Commercial
# 14                        Noise
# 15           Noise - Commercial
# 16           Noise - Commercial
# 17          Noise - Residential
# 18           Noise - Commercial
# 19              Noise - Vehicle
# 20          Noise - Residential
# 21           Noise - Commercial
# 22           Noise - Commercial
# 23           Noise - Commercial
# 24           Noise - Commercial
# 25           Noise - Commercial
# 26           Noise - Commercial
# 27          Noise - Residential
# 28                        Noise
# 29          Noise - Residential
# ...                         ...
# 459806                    Noise
# 459807                    Noise
# 459808  Noise - Street/Sidewalk
# 459809      Noise - Residential
# 459810                    Noise
# 459811                    Noise
# 459812      Noise - Residential
# 459813       Noise - Commercial
# 459814       Noise - Commercial
# 459815       Noise - Commercial
# 459816       Noise - Commercial
# 459817       Noise - Commercial
# 459818       Noise - Commercial
# 459819       Noise - Commercial
# 459820       Noise - Commercial
# 459821       Noise - Commercial
# 459822       Noise - Commercial
# 459823       Noise - Commercial
# 459824       Noise - Commercial
# 459825       Noise - Commercial
# 459826       Noise - Commercial
# 459827       Noise - Commercial
# 459828       Noise - Commercial
# 459829       Noise - Commercial
# 459830       Noise - Commercial
# 459831       Noise - Commercial
# 459832                    Noise
# 459833      Noise - Residential
# 459834                    Noise
# 459835      Noise - Residential
#
#                                                Descriptor  \
# 0                                        Loud Music/Party
# 1                                        Loud Music/Party
# 2                                        Loud Music/Party
# 3                                        Loud Music/Party
# 4                                        Loud Music/Party
# 5                                        Loud Music/Party
# 6                     Noise: Construction Equipment (NC1)
# 7       Noise: Air Condition/Ventilation Equip, Commer...
# 8                                        Loud Music/Party
# 9                                        Loud Music/Party
# 10      Noise: Air Condition/Ventilation Equip, Commer...
# 11                                       Loud Music/Party
# 12           Noise: Construction Before/After Hours (NM1)
# 13                                       Loud Music/Party
# 14                            Noise: Jack Hammering (NC2)
# 15                                       Loud Music/Party
# 16                                       Loud Music/Party
# 17                                       Banging/Pounding
# 18                                       Loud Music/Party
# 19                                        Car/Truck Music
# 20                                       Loud Music/Party
# 21                                       Loud Music/Party
# 22                                       Loud Music/Party
# 23                                       Loud Music/Party
# 24                                       Loud Music/Party
# 25                                       Loud Music/Party
# 26                                       Loud Music/Party
# 27                                       Banging/Pounding
# 28                            Noise: Jack Hammering (NC2)
# 29                                       Loud Music/Party
# ...                                                   ...
# 459806       Noise: Construction Before/After Hours (NM1)
# 459807       Noise: Construction Before/After Hours (NM1)
# 459808                                   Loud Music/Party
# 459809                                   Loud Music/Party
# 459810                        Noise: Jack Hammering (NC2)
# 459811       Noise: Construction Before/After Hours (NM1)
# 459812                                   Banging/Pounding
# 459813                                   Banging/Pounding
# 459814                                   Banging/Pounding
# 459815                                   Banging/Pounding
# 459816                                   Banging/Pounding
# 459817                                   Banging/Pounding
# 459818                                   Banging/Pounding
# 459819                                   Banging/Pounding
# 459820                                   Banging/Pounding
# 459821                                   Banging/Pounding
# 459822                                   Banging/Pounding
# 459823                                   Banging/Pounding
# 459824                                   Banging/Pounding
# 459825                                   Banging/Pounding
# 459826                                   Banging/Pounding
# 459827                                   Banging/Pounding
# 459828                                   Banging/Pounding
# 459829                                   Banging/Pounding
# 459830                                   Banging/Pounding
# 459831                                     Car/Truck Horn
# 459832                        Noise: Jack Hammering (NC2)
# 459833                                    Loud Television
# 459834       Noise: Construction Before/After Hours (NM1)
# 459835                                   Loud Music/Party
#
#                      Location Type Zip Code Precinct  \
# 0       Residential Building/House    10014        6
# 1              Club/Bar/Restaurant    10014        6
# 2              Club/Bar/Restaurant    10014        6
# 3              Club/Bar/Restaurant    10014        6
# 4              Club/Bar/Restaurant    10014        6
# 5              Club/Bar/Restaurant    10014        6
# 6                              nan    10014        6
# 7                              nan    10014        6
# 8       Residential Building/House    10014        6
# 9              Club/Bar/Restaurant    10014        6
# 10                             nan    10014        6
# 11             Club/Bar/Restaurant    10014        6
# 12                             nan    10014        6
# 13             Club/Bar/Restaurant    10014        6
# 14                             nan    10014        6
# 15             Club/Bar/Restaurant    10014        6
# 16             Club/Bar/Restaurant    10014        6
# 17      Residential Building/House    10014        6
# 18             Club/Bar/Restaurant    10014        6
# 19                 Street/Sidewalk    10014        6
# 20      Residential Building/House    10014        6
# 21             Club/Bar/Restaurant    10014        6
# 22             Club/Bar/Restaurant    10014        6
# 23             Club/Bar/Restaurant    10014        6
# 24             Club/Bar/Restaurant    10014        6
# 25             Club/Bar/Restaurant    10014        6
# 26             Club/Bar/Restaurant    10014        6
# 27      Residential Building/House    10014        6
# 28                             nan    10014        6
# 29      Residential Building/House    10014        6
# ...                            ...      ...      ...
# 459806                         nan    10162       19
# 459807                         nan    10162       19
# 459808             Street/Sidewalk    10162       19
# 459809  Residential Building/House    10162       19
# 459810                         nan    10162       19
# 459811                         nan    10162       19
# 459812  Residential Building/House    10162       19
# 459813            Store/Commercial    10162       19
# 459814            Store/Commercial    10162       19
# 459815            Store/Commercial    10162       19
# 459816            Store/Commercial    10162       19
# 459817            Store/Commercial    10162       19
# 459818            Store/Commercial    10162       19
# 459819            Store/Commercial    10162       19
# 459820            Store/Commercial    10162       19
# 459821            Store/Commercial    10162       19
# 459822            Store/Commercial    10162       19
# 459823            Store/Commercial    10162       19
# 459824            Store/Commercial    10162       19
# 459825            Store/Commercial    10162       19
# 459826            Store/Commercial    10162       19
# 459827            Store/Commercial    10162       19
# 459828            Store/Commercial    10162       19
# 459829            Store/Commercial    10162       19
# 459830            Store/Commercial    10162       19
# 459831            Store/Commercial    10162       19
# 459832                         nan    10162       19
# 459833  Residential Building/House    10162       19
# 459834                         nan    10162       19
# 459835  Residential Building/House    10162       19
#
#                        Population                 % Poverty Level  Year  \
# 0       Population Lower than IQR  % Poverty Level Lower than IQR  2010
# 1       Population Lower than IQR  % Poverty Level Lower than IQR  2010
# 2       Population Lower than IQR  % Poverty Level Lower than IQR  2010
# 3       Population Lower than IQR  % Poverty Level Lower than IQR  2010
# 4       Population Lower than IQR  % Poverty Level Lower than IQR  2010
# 5       Population Lower than IQR  % Poverty Level Lower than IQR  2010
# 6       Population Lower than IQR  % Poverty Level Lower than IQR  2010
# 7       Population Lower than IQR  % Poverty Level Lower than IQR  2010
# 8       Population Lower than IQR  % Poverty Level Lower than IQR  2010
# 9       Population Lower than IQR  % Poverty Level Lower than IQR  2010
# 10      Population Lower than IQR  % Poverty Level Lower than IQR  2010
# 11      Population Lower than IQR  % Poverty Level Lower than IQR  2010
# 12      Population Lower than IQR  % Poverty Level Lower than IQR  2010
# 13      Population Lower than IQR  % Poverty Level Lower than IQR  2010
# 14      Population Lower than IQR  % Poverty Level Lower than IQR  2010
# 15      Population Lower than IQR  % Poverty Level Lower than IQR  2010
# 16      Population Lower than IQR  % Poverty Level Lower than IQR  2010
# 17      Population Lower than IQR  % Poverty Level Lower than IQR  2010
# 18      Population Lower than IQR  % Poverty Level Lower than IQR  2010
# 19      Population Lower than IQR  % Poverty Level Lower than IQR  2010
# 20      Population Lower than IQR  % Poverty Level Lower than IQR  2010
# 21      Population Lower than IQR  % Poverty Level Lower than IQR  2010
# 22      Population Lower than IQR  % Poverty Level Lower than IQR  2010
# 23      Population Lower than IQR  % Poverty Level Lower than IQR  2010
# 24      Population Lower than IQR  % Poverty Level Lower than IQR  2010
# 25      Population Lower than IQR  % Poverty Level Lower than IQR  2010
# 26      Population Lower than IQR  % Poverty Level Lower than IQR  2010
# 27      Population Lower than IQR  % Poverty Level Lower than IQR  2010
# 28      Population Lower than IQR  % Poverty Level Lower than IQR  2010
# 29      Population Lower than IQR  % Poverty Level Lower than IQR  2010
# ...                           ...                             ...   ...
# 459806  Population Lower than IQR  % Poverty Level Lower than IQR  2014
# 459807  Population Lower than IQR  % Poverty Level Lower than IQR  2014
# 459808  Population Lower than IQR  % Poverty Level Lower than IQR  2014
# 459809  Population Lower than IQR  % Poverty Level Lower than IQR  2014
# 459810  Population Lower than IQR  % Poverty Level Lower than IQR  2015
# 459811  Population Lower than IQR  % Poverty Level Lower than IQR  2015
# 459812  Population Lower than IQR  % Poverty Level Lower than IQR  2015
# 459813  Population Lower than IQR  % Poverty Level Lower than IQR  2015
# 459814  Population Lower than IQR  % Poverty Level Lower than IQR  2015
# 459815  Population Lower than IQR  % Poverty Level Lower than IQR  2015
# 459816  Population Lower than IQR  % Poverty Level Lower than IQR  2015
# 459817  Population Lower than IQR  % Poverty Level Lower than IQR  2015
# 459818  Population Lower than IQR  % Poverty Level Lower than IQR  2015
# 459819  Population Lower than IQR  % Poverty Level Lower than IQR  2015
# 459820  Population Lower than IQR  % Poverty Level Lower than IQR  2015
# 459821  Population Lower than IQR  % Poverty Level Lower than IQR  2015
# 459822  Population Lower than IQR  % Poverty Level Lower than IQR  2015
# 459823  Population Lower than IQR  % Poverty Level Lower than IQR  2015
# 459824  Population Lower than IQR  % Poverty Level Lower than IQR  2015
# 459825  Population Lower than IQR  % Poverty Level Lower than IQR  2015
# 459826  Population Lower than IQR  % Poverty Level Lower than IQR  2015
# 459827  Population Lower than IQR  % Poverty Level Lower than IQR  2015
# 459828  Population Lower than IQR  % Poverty Level Lower than IQR  2015
# 459829  Population Lower than IQR  % Poverty Level Lower than IQR  2015
# 459830  Population Lower than IQR  % Poverty Level Lower than IQR  2015
# 459831  Population Lower than IQR  % Poverty Level Lower than IQR  2015
# 459832  Population Lower than IQR  % Poverty Level Lower than IQR  2015
# 459833  Population Lower than IQR  % Poverty Level Lower than IQR  2015
# 459834  Population Lower than IQR  % Poverty Level Lower than IQR  2015
# 459835  Population Lower than IQR  % Poverty Level Lower than IQR  2015
#
#          Violence Binning           Misd Binning            Major Binning  \
# 0       VC Lower than IQR  Misd Within Lower IQR  Major Within Higher IQR
# 1       VC Lower than IQR  Misd Within Lower IQR  Major Within Higher IQR
# 2       VC Lower than IQR  Misd Within Lower IQR  Major Within Higher IQR
# 3       VC Lower than IQR  Misd Within Lower IQR  Major Within Higher IQR
# 4       VC Lower than IQR  Misd Within Lower IQR  Major Within Higher IQR
# 5       VC Lower than IQR  Misd Within Lower IQR  Major Within Higher IQR
# 6       VC Lower than IQR  Misd Within Lower IQR  Major Within Higher IQR
# 7       VC Lower than IQR  Misd Within Lower IQR  Major Within Higher IQR
# 8       VC Lower than IQR  Misd Within Lower IQR  Major Within Higher IQR
# 9       VC Lower than IQR  Misd Within Lower IQR  Major Within Higher IQR
# 10      VC Lower than IQR  Misd Within Lower IQR  Major Within Higher IQR
# 11      VC Lower than IQR  Misd Within Lower IQR  Major Within Higher IQR
# 12      VC Lower than IQR  Misd Within Lower IQR  Major Within Higher IQR
# 13      VC Lower than IQR  Misd Within Lower IQR  Major Within Higher IQR
# 14      VC Lower than IQR  Misd Within Lower IQR  Major Within Higher IQR
# 15      VC Lower than IQR  Misd Within Lower IQR  Major Within Higher IQR
# 16      VC Lower than IQR  Misd Within Lower IQR  Major Within Higher IQR
# 17      VC Lower than IQR  Misd Within Lower IQR  Major Within Higher IQR
# 18      VC Lower than IQR  Misd Within Lower IQR  Major Within Higher IQR
# 19      VC Lower than IQR  Misd Within Lower IQR  Major Within Higher IQR
# 20      VC Lower than IQR  Misd Within Lower IQR  Major Within Higher IQR
# 21      VC Lower than IQR  Misd Within Lower IQR  Major Within Higher IQR
# 22      VC Lower than IQR  Misd Within Lower IQR  Major Within Higher IQR
# 23      VC Lower than IQR  Misd Within Lower IQR  Major Within Higher IQR
# 24      VC Lower than IQR  Misd Within Lower IQR  Major Within Higher IQR
# 25      VC Lower than IQR  Misd Within Lower IQR  Major Within Higher IQR
# 26      VC Lower than IQR  Misd Within Lower IQR  Major Within Higher IQR
# 27      VC Lower than IQR  Misd Within Lower IQR  Major Within Higher IQR
# 28      VC Lower than IQR  Misd Within Lower IQR  Major Within Higher IQR
# 29      VC Lower than IQR  Misd Within Lower IQR  Major Within Higher IQR
# ...                   ...                    ...                      ...
# 459806  VC Lower than IQR    Misd Lower than IQR    Major Higher than IQR
# 459807  VC Lower than IQR    Misd Lower than IQR    Major Higher than IQR
# 459808  VC Lower than IQR    Misd Lower than IQR    Major Higher than IQR
# 459809  VC Lower than IQR    Misd Lower than IQR    Major Higher than IQR
# 459810  VC Lower than IQR    Misd Lower than IQR    Major Higher than IQR
# 459811  VC Lower than IQR    Misd Lower than IQR    Major Higher than IQR
# 459812  VC Lower than IQR    Misd Lower than IQR    Major Higher than IQR
# 459813  VC Lower than IQR    Misd Lower than IQR    Major Higher than IQR
# 459814  VC Lower than IQR    Misd Lower than IQR    Major Higher than IQR
# 459815  VC Lower than IQR    Misd Lower than IQR    Major Higher than IQR
# 459816  VC Lower than IQR    Misd Lower than IQR    Major Higher than IQR
# 459817  VC Lower than IQR    Misd Lower than IQR    Major Higher than IQR
# 459818  VC Lower than IQR    Misd Lower than IQR    Major Higher than IQR
# 459819  VC Lower than IQR    Misd Lower than IQR    Major Higher than IQR
# 459820  VC Lower than IQR    Misd Lower than IQR    Major Higher than IQR
# 459821  VC Lower than IQR    Misd Lower than IQR    Major Higher than IQR
# 459822  VC Lower than IQR    Misd Lower than IQR    Major Higher than IQR
# 459823  VC Lower than IQR    Misd Lower than IQR    Major Higher than IQR
# 459824  VC Lower than IQR    Misd Lower than IQR    Major Higher than IQR
# 459825  VC Lower than IQR    Misd Lower than IQR    Major Higher than IQR
# 459826  VC Lower than IQR    Misd Lower than IQR    Major Higher than IQR
# 459827  VC Lower than IQR    Misd Lower than IQR    Major Higher than IQR
# 459828  VC Lower than IQR    Misd Lower than IQR    Major Higher than IQR
# 459829  VC Lower than IQR    Misd Lower than IQR    Major Higher than IQR
# 459830  VC Lower than IQR    Misd Lower than IQR    Major Higher than IQR
# 459831  VC Lower than IQR    Misd Lower than IQR    Major Higher than IQR
# 459832  VC Lower than IQR    Misd Lower than IQR    Major Higher than IQR
# 459833  VC Lower than IQR    Misd Lower than IQR    Major Higher than IQR
# 459834  VC Lower than IQR    Misd Lower than IQR    Major Higher than IQR
# 459835  VC Lower than IQR    Misd Lower than IQR    Major Higher than IQR
#
#                  Nonmajor Binning           Noise Binning
# 0       Nonmajor Within Lower IQR  Noise Within Lower IQR
# 1       Nonmajor Within Lower IQR  Noise Within Lower IQR
# 2       Nonmajor Within Lower IQR  Noise Within Lower IQR
# 3       Nonmajor Within Lower IQR  Noise Within Lower IQR
# 4       Nonmajor Within Lower IQR  Noise Within Lower IQR
# 5       Nonmajor Within Lower IQR  Noise Within Lower IQR
# 6       Nonmajor Within Lower IQR  Noise Within Lower IQR
# 7       Nonmajor Within Lower IQR  Noise Within Lower IQR
# 8       Nonmajor Within Lower IQR  Noise Within Lower IQR
# 9       Nonmajor Within Lower IQR  Noise Within Lower IQR
# 10      Nonmajor Within Lower IQR  Noise Within Lower IQR
# 11      Nonmajor Within Lower IQR  Noise Within Lower IQR
# 12      Nonmajor Within Lower IQR  Noise Within Lower IQR
# 13      Nonmajor Within Lower IQR  Noise Within Lower IQR
# 14      Nonmajor Within Lower IQR  Noise Within Lower IQR
# 15      Nonmajor Within Lower IQR  Noise Within Lower IQR
# 16      Nonmajor Within Lower IQR  Noise Within Lower IQR
# 17      Nonmajor Within Lower IQR  Noise Within Lower IQR
# 18      Nonmajor Within Lower IQR  Noise Within Lower IQR
# 19      Nonmajor Within Lower IQR  Noise Within Lower IQR
# 20      Nonmajor Within Lower IQR  Noise Within Lower IQR
# 21      Nonmajor Within Lower IQR  Noise Within Lower IQR
# 22      Nonmajor Within Lower IQR  Noise Within Lower IQR
# 23      Nonmajor Within Lower IQR  Noise Within Lower IQR
# 24      Nonmajor Within Lower IQR  Noise Within Lower IQR
# 25      Nonmajor Within Lower IQR  Noise Within Lower IQR
# 26      Nonmajor Within Lower IQR  Noise Within Lower IQR
# 27      Nonmajor Within Lower IQR  Noise Within Lower IQR
# 28      Nonmajor Within Lower IQR  Noise Within Lower IQR
# 29      Nonmajor Within Lower IQR  Noise Within Lower IQR
# ...                           ...                     ...
# 459806    Nonmajor Lower than IQR    Noise Lower than IQR
# 459807    Nonmajor Lower than IQR    Noise Lower than IQR
# 459808    Nonmajor Lower than IQR    Noise Lower than IQR
# 459809    Nonmajor Lower than IQR    Noise Lower than IQR
# 459810    Nonmajor Lower than IQR    Noise Lower than IQR
# 459811    Nonmajor Lower than IQR    Noise Lower than IQR
# 459812    Nonmajor Lower than IQR    Noise Lower than IQR
# 459813    Nonmajor Lower than IQR    Noise Lower than IQR
# 459814    Nonmajor Lower than IQR    Noise Lower than IQR
# 459815    Nonmajor Lower than IQR    Noise Lower than IQR
# 459816    Nonmajor Lower than IQR    Noise Lower than IQR
# 459817    Nonmajor Lower than IQR    Noise Lower than IQR
# 459818    Nonmajor Lower than IQR    Noise Lower than IQR
# 459819    Nonmajor Lower than IQR    Noise Lower than IQR
# 459820    Nonmajor Lower than IQR    Noise Lower than IQR
# 459821    Nonmajor Lower than IQR    Noise Lower than IQR
# 459822    Nonmajor Lower than IQR    Noise Lower than IQR
# 459823    Nonmajor Lower than IQR    Noise Lower than IQR
# 459824    Nonmajor Lower than IQR    Noise Lower than IQR
# 459825    Nonmajor Lower than IQR    Noise Lower than IQR
# 459826    Nonmajor Lower than IQR    Noise Lower than IQR
# 459827    Nonmajor Lower than IQR    Noise Lower than IQR
# 459828    Nonmajor Lower than IQR    Noise Lower than IQR
# 459829    Nonmajor Lower than IQR    Noise Lower than IQR
# 459830    Nonmajor Lower than IQR    Noise Lower than IQR
# 459831    Nonmajor Lower than IQR    Noise Lower than IQR
# 459832    Nonmajor Lower than IQR    Noise Lower than IQR
# 459833    Nonmajor Lower than IQR    Noise Lower than IQR
# 459834    Nonmajor Lower than IQR    Noise Lower than IQR
# 459835    Nonmajor Lower than IQR    Noise Lower than IQR
#
# [459836 rows x 15 columns]

# %%
Brook = Brook.drop('City',1)
Brook = Brook.drop('Borough',1)
Brook['Neighborhood'] = 'NGHBR: '+Brook['Neighborhood'].astype(str)
Brook = Brook.drop(Brook.columns[[0]],axis=1)
brook = Brook.applymap(str)
brook1 = brook.values.tolist()
brook_pats,brook_rules = mine_patterns(brook1,thresh,0.7,'Brooklyn')

# %%
queens = queens.drop('City',1)
queens = queens.drop('Borough',1)
queens['Neighborhood'] = 'NGHBR: '+queens['Neighborhood'].astype(str)
queens = queens.drop(queens.columns[[0]],axis=1)
queens = queens.applymap(str)
queens1 = queens.values.tolist()
queens_pats,queens_rules = mine_patterns(queens1,thresh,0.7,'Queens')

# %%
bronx1
# Out:
# [['0',
#   'NGHBR: Central Bronx',
#   '2010-01-01 00:19:07',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['1',
#   'NGHBR: Central Bronx',
#   '2010-01-01 03:08:12',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['2',
#   'NGHBR: Central Bronx',
#   '2010-01-01 04:36:53',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['3',
#   'NGHBR: Central Bronx',
#   '2010-01-01 04:44:35',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['4',
#   'NGHBR: Central Bronx',
#   '2010-01-01 05:29:48',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['5',
#   'NGHBR: Central Bronx',
#   '2010-01-01 05:59:35',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['6',
#   'NGHBR: Central Bronx',
#   '2010-01-01 06:11:31',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['7',
#   'NGHBR: Central Bronx',
#   '2010-01-01 06:29:01',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['8',
#   'NGHBR: Central Bronx',
#   '2010-01-01 10:44:04',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['9',
#   'NGHBR: Central Bronx',
#   '2010-01-01 11:25:20',
#   'Noise - Street/Sidewalk',
#   'Loud Music/Party',
#   'Street/Sidewalk',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['10',
#   'NGHBR: Central Bronx',
#   '2010-01-01 11:44:22',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['11',
#   'NGHBR: Central Bronx',
#   '2010-01-01 14:04:09',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['12',
#   'NGHBR: Central Bronx',
#   '2010-01-01 14:43:57',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['13',
#   'NGHBR: Central Bronx',
#   '2010-01-01 15:47:54',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['14',
#   'NGHBR: Central Bronx',
#   '2010-01-01 20:12:04',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['15',
#   'NGHBR: Central Bronx',
#   '2010-01-01 20:50:01',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['16',
#   'NGHBR: Central Bronx',
#   '2010-01-01 22:38:12',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['17',
#   'NGHBR: Central Bronx',
#   '2010-01-02 00:56:42',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['18',
#   'NGHBR: Central Bronx',
#   '2010-01-02 01:12:47',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['19',
#   'NGHBR: Central Bronx',
#   '2010-01-02 11:48:10',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['20',
#   'NGHBR: Central Bronx',
#   '2010-01-02 16:15:11',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['21',
#   'NGHBR: Central Bronx',
#   '2010-01-02 17:34:28',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['22',
#   'NGHBR: Central Bronx',
#   '2010-01-02 21:44:45',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['23',
#   'NGHBR: Central Bronx',
#   '2010-01-02 22:22:31',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['24',
#   'NGHBR: Central Bronx',
#   '2010-01-03 00:41:53',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['25',
#   'NGHBR: Central Bronx',
#   '2010-01-03 04:59:09',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['26',
#   'NGHBR: Central Bronx',
#   '2010-01-03 12:34:54',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['27',
#   'NGHBR: Central Bronx',
#   '2010-01-03 12:47:04',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['28',
#   'NGHBR: Central Bronx',
#   '2010-01-03 15:58:40',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['29',
#   'NGHBR: Central Bronx',
#   '2010-01-03 22:16:39',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['30',
#   'NGHBR: Central Bronx',
#   '2010-01-03 23:20:24',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['31',
#   'NGHBR: Central Bronx',
#   '2010-01-04 01:42:44',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['32',
#   'NGHBR: Central Bronx',
#   '2010-01-04 17:59:42',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['33',
#   'NGHBR: Central Bronx',
#   '2010-01-04 18:09:42',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['34',
#   'NGHBR: Central Bronx',
#   '2010-01-04 21:36:09',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['35',
#   'NGHBR: Central Bronx',
#   '2010-01-05 07:47:00',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['36',
#   'NGHBR: Central Bronx',
#   '2010-01-05 21:34:27',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['37',
#   'NGHBR: Central Bronx',
#   '2010-01-05 22:41:05',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['38',
#   'NGHBR: Central Bronx',
#   '2010-01-05 23:12:01',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['39',
#   'NGHBR: Central Bronx',
#   '2010-01-06 01:58:41',
#   'Noise - Residential',
#   'Loud Talking',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['40',
#   'NGHBR: Central Bronx',
#   '2010-01-06 20:58:13',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['41',
#   'NGHBR: Central Bronx',
#   '2010-01-06 22:51:32',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['42',
#   'NGHBR: Central Bronx',
#   '2010-01-06 23:07:52',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['43',
#   'NGHBR: Central Bronx',
#   '2010-01-07 08:07:12',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['44',
#   'NGHBR: Central Bronx',
#   '2010-01-07 14:34:50',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['45',
#   'NGHBR: Central Bronx',
#   '2010-01-07 22:28:41',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['46',
#   'NGHBR: Central Bronx',
#   '2010-01-08 00:13:27',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['47',
#   'NGHBR: Central Bronx',
#   '2010-01-08 00:13:29',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['48',
#   'NGHBR: Central Bronx',
#   '2010-01-08 05:57:14',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['49',
#   'NGHBR: Central Bronx',
#   '2010-01-08 19:32:53',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['50',
#   'NGHBR: Central Bronx',
#   '2010-01-08 22:42:33',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['51',
#   'NGHBR: Central Bronx',
#   '2010-01-09 01:52:21',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['52',
#   'NGHBR: Central Bronx',
#   '2010-01-09 02:40:23',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['53',
#   'NGHBR: Central Bronx',
#   '2010-01-09 02:43:06',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['54',
#   'NGHBR: Central Bronx',
#   '2010-01-09 03:22:16',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['55',
#   'NGHBR: Central Bronx',
#   '2010-01-09 04:02:23',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['56',
#   'NGHBR: Central Bronx',
#   '2010-01-09 10:06:31',
#   'Noise - Residential',
#   'Loud Talking',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['57',
#   'NGHBR: Central Bronx',
#   '2010-01-09 12:31:29',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['58',
#   'NGHBR: Central Bronx',
#   '2010-01-09 15:55:48',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['59',
#   'NGHBR: Central Bronx',
#   '2010-01-09 15:56:50',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['60',
#   'NGHBR: Central Bronx',
#   '2010-01-09 21:51:20',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['61',
#   'NGHBR: Central Bronx',
#   '2010-01-09 23:28:53',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['62',
#   'NGHBR: Central Bronx',
#   '2010-01-09 23:53:21',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['63',
#   'NGHBR: Central Bronx',
#   '2010-01-10 00:27:09',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['64',
#   'NGHBR: Central Bronx',
#   '2010-01-10 00:56:09',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['65',
#   'NGHBR: Central Bronx',
#   '2010-01-10 02:17:28',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['66',
#   'NGHBR: Central Bronx',
#   '2010-01-10 02:32:28',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['67',
#   'NGHBR: Central Bronx',
#   '2010-01-10 04:36:34',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['68',
#   'NGHBR: Central Bronx',
#   '2010-01-10 06:05:04',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['69',
#   'NGHBR: Central Bronx',
#   '2010-01-10 07:08:00',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['70',
#   'NGHBR: Central Bronx',
#   '2010-01-10 16:12:08',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['71',
#   'NGHBR: Central Bronx',
#   '2010-01-10 23:54:07',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['72',
#   'NGHBR: Central Bronx',
#   '2010-01-11 01:24:39',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['73',
#   'NGHBR: Central Bronx',
#   '2010-01-11 20:51:47',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['74',
#   'NGHBR: Central Bronx',
#   '2010-01-12 11:09:25',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['75',
#   'NGHBR: Central Bronx',
#   '2010-01-12 18:32:52',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['76',
#   'NGHBR: Central Bronx',
#   '2010-01-12 19:12:26',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['77',
#   'NGHBR: Central Bronx',
#   '2010-01-12 20:02:21',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['78',
#   'NGHBR: Central Bronx',
#   '2010-01-12 23:07:23',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['79',
#   'NGHBR: Central Bronx',
#   '2010-01-13 09:49:00',
#   'Noise',
#   'Noise, Other Animals (NR6)',
#   'nan',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['80',
#   'NGHBR: Central Bronx',
#   '2010-01-13 11:07:20',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['81',
#   'NGHBR: Central Bronx',
#   '2010-01-13 11:49:54',
#   'Noise - House of Worship',
#   'Loud Music/Party',
#   'House of Worship',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['82',
#   'NGHBR: Central Bronx',
#   '2010-01-13 17:42:18',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['83',
#   'NGHBR: Central Bronx',
#   '2010-01-13 18:29:54',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['84',
#   'NGHBR: Central Bronx',
#   '2010-01-13 19:40:57',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['85',
#   'NGHBR: Central Bronx',
#   '2010-01-13 20:35:25',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['86',
#   'NGHBR: Central Bronx',
#   '2010-01-13 22:49:14',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['87',
#   'NGHBR: Central Bronx',
#   '2010-01-15 08:06:27',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['88',
#   'NGHBR: Central Bronx',
#   '2010-01-15 09:17:13',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['89',
#   'NGHBR: Central Bronx',
#   '2010-01-15 11:20:20',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['90',
#   'NGHBR: Central Bronx',
#   '2010-01-15 20:12:57',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['91',
#   'NGHBR: Central Bronx',
#   '2010-01-15 22:07:59',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['92',
#   'NGHBR: Central Bronx',
#   '2010-01-15 22:56:57',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['93',
#   'NGHBR: Central Bronx',
#   '2010-01-15 23:38:34',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['94',
#   'NGHBR: Central Bronx',
#   '2010-01-16 01:58:12',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['95',
#   'NGHBR: Central Bronx',
#   '2010-01-16 02:18:57',
#   'Noise - Residential',
#   'Loud Talking',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['96',
#   'NGHBR: Central Bronx',
#   '2010-01-16 02:57:59',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['97',
#   'NGHBR: Central Bronx',
#   '2010-01-16 04:23:08',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['98',
#   'NGHBR: Central Bronx',
#   '2010-01-16 11:35:37',
#   'Noise - Vehicle',
#   'Car/Truck Music',
#   'Street/Sidewalk',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['99',
#   'NGHBR: Central Bronx',
#   '2010-01-16 11:43:03',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['100',
#   'NGHBR: Central Bronx',
#   '2010-01-16 12:49:14',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['101',
#   'NGHBR: Central Bronx',
#   '2010-01-16 15:54:28',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['102',
#   'NGHBR: Central Bronx',
#   '2010-01-16 19:15:15',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['103',
#   'NGHBR: Central Bronx',
#   '2010-01-16 21:07:46',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['104',
#   'NGHBR: Central Bronx',
#   '2010-01-16 21:51:05',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['105',
#   'NGHBR: Central Bronx',
#   '2010-01-16 22:02:25',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['106',
#   'NGHBR: Central Bronx',
#   '2010-01-16 22:25:54',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Store/Commercial',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['107',
#   'NGHBR: Central Bronx',
#   '2010-01-16 23:10:56',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['108',
#   'NGHBR: Central Bronx',
#   '2010-01-17 01:53:02',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['109',
#   'NGHBR: Central Bronx',
#   '2010-01-17 02:59:43',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['110',
#   'NGHBR: Central Bronx',
#   '2010-01-17 03:19:55',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['111',
#   'NGHBR: Central Bronx',
#   '2010-01-17 04:25:10',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['112',
#   'NGHBR: Central Bronx',
#   '2010-01-17 05:01:51',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['113',
#   'NGHBR: Central Bronx',
#   '2010-01-17 05:55:50',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['114',
#   'NGHBR: Central Bronx',
#   '2010-01-17 12:10:54',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['115',
#   'NGHBR: Central Bronx',
#   '2010-01-17 15:17:22',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Store/Commercial',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['116',
#   'NGHBR: Central Bronx',
#   '2010-01-17 15:41:10',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['117',
#   'NGHBR: Central Bronx',
#   '2010-01-17 16:47:38',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['118',
#   'NGHBR: Central Bronx',
#   '2010-01-17 17:39:26',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['119',
#   'NGHBR: Central Bronx',
#   '2010-01-17 19:04:03',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['120',
#   'NGHBR: Central Bronx',
#   '2010-01-17 22:47:28',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['121',
#   'NGHBR: Central Bronx',
#   '2010-01-17 22:57:25',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['122',
#   'NGHBR: Central Bronx',
#   '2010-01-17 23:34:54',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['123',
#   'NGHBR: Central Bronx',
#   '2010-01-18 00:39:33',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['124',
#   'NGHBR: Central Bronx',
#   '2010-01-18 04:12:17',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['125',
#   'NGHBR: Central Bronx',
#   '2010-01-18 13:18:30',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['126',
#   'NGHBR: Central Bronx',
#   '2010-01-18 13:33:06',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Store/Commercial',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['127',
#   'NGHBR: Central Bronx',
#   '2010-01-18 14:31:57',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
# ...
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['958',
#   'NGHBR: Central Bronx',
#   '2010-04-18 22:33:31',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['959',
#   'NGHBR: Central Bronx',
#   '2010-04-18 23:27:15',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['960',
#   'NGHBR: Central Bronx',
#   '2010-04-19 02:25:33',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['961',
#   'NGHBR: Central Bronx',
#   '2010-04-19 14:22:04',
#   'Noise - Residential',
#   'Loud Talking',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['962',
#   'NGHBR: Central Bronx',
#   '2010-04-19 14:57:13',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['963',
#   'NGHBR: Central Bronx',
#   '2010-04-19 20:32:49',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['964',
#   'NGHBR: Central Bronx',
#   '2010-04-19 22:43:11',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['965',
#   'NGHBR: Central Bronx',
#   '2010-04-20 00:49:35',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['966',
#   'NGHBR: Central Bronx',
#   '2010-04-20 01:38:55',
#   'Noise - Residential',
#   'Loud Talking',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['967',
#   'NGHBR: Central Bronx',
#   '2010-04-20 01:42:24',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['968',
#   'NGHBR: Central Bronx',
#   '2010-04-20 09:16:50',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['969',
#   'NGHBR: Central Bronx',
#   '2010-04-20 17:54:27',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['970',
#   'NGHBR: Central Bronx',
#   '2010-04-20 18:01:52',
#   'Noise - Vehicle',
#   'Car/Truck Music',
#   'Street/Sidewalk',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['971',
#   'NGHBR: Central Bronx',
#   '2010-04-21 02:22:42',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['972',
#   'NGHBR: Central Bronx',
#   '2010-04-21 05:16:51',
#   'Noise - Vehicle',
#   'Car/Truck Music',
#   'Street/Sidewalk',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['973',
#   'NGHBR: Central Bronx',
#   '2010-04-21 08:59:55',
#   'Noise - Vehicle',
#   'Car/Truck Music',
#   'Street/Sidewalk',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['974',
#   'NGHBR: Central Bronx',
#   '2010-04-21 20:11:23',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['975',
#   'NGHBR: Central Bronx',
#   '2010-04-21 21:39:02',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['976',
#   'NGHBR: Central Bronx',
#   '2010-04-21 22:19:42',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['977',
#   'NGHBR: Central Bronx',
#   '2010-04-22 00:34:09',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['978',
#   'NGHBR: Central Bronx',
#   '2010-04-22 16:57:45',
#   'Noise - Vehicle',
#   'Car/Truck Horn',
#   'Street/Sidewalk',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['979',
#   'NGHBR: Central Bronx',
#   '2010-04-22 19:11:00',
#   'Noise',
#   'Noise, Ice Cream Truck (NR4)',
#   'nan',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['980',
#   'NGHBR: Central Bronx',
#   '2010-04-22 20:23:18',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['981',
#   'NGHBR: Central Bronx',
#   '2010-04-23 01:31:06',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['982',
#   'NGHBR: Central Bronx',
#   '2010-04-23 08:38:58',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['983',
#   'NGHBR: Central Bronx',
#   '2010-04-23 14:30:13',
#   'Noise - Street/Sidewalk',
#   'Loud Music/Party',
#   'Street/Sidewalk',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['984',
#   'NGHBR: Central Bronx',
#   '2010-04-23 14:45:31',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['985',
#   'NGHBR: Central Bronx',
#   '2010-04-23 16:26:46',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['986',
#   'NGHBR: Central Bronx',
#   '2010-04-23 19:28:59',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['987',
#   'NGHBR: Central Bronx',
#   '2010-04-23 19:34:53',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['988',
#   'NGHBR: Central Bronx',
#   '2010-04-23 20:19:38',
#   'Noise - Vehicle',
#   'Car/Truck Music',
#   'Street/Sidewalk',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['989',
#   'NGHBR: Central Bronx',
#   '2010-04-23 20:38:57',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['990',
#   'NGHBR: Central Bronx',
#   '2010-04-23 23:09:06',
#   'Noise - Street/Sidewalk',
#   'Loud Music/Party',
#   'Street/Sidewalk',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['991',
#   'NGHBR: Central Bronx',
#   '2010-04-23 23:24:02',
#   'Noise - Street/Sidewalk',
#   'Loud Music/Party',
#   'Street/Sidewalk',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['992',
#   'NGHBR: Central Bronx',
#   '2010-04-24 00:04:49',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['993',
#   'NGHBR: Central Bronx',
#   '2010-04-24 02:16:53',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['994',
#   'NGHBR: Central Bronx',
#   '2010-04-24 03:07:29',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['995',
#   'NGHBR: Central Bronx',
#   '2010-04-24 05:17:54',
#   'Noise - Residential',
#   'Loud Television',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['996',
#   'NGHBR: Central Bronx',
#   '2010-04-24 08:18:16',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['997',
#   'NGHBR: Central Bronx',
#   '2010-04-24 10:12:24',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['998',
#   'NGHBR: Central Bronx',
#   '2010-04-24 15:01:32',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ['999',
#   'NGHBR: Central Bronx',
#   '2010-04-24 17:07:38',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR',
#   'Noise Within Higher IQR'],
#  ...]

# %%
def label_column(data,index):
    label = data[0][index]
    for i in range(1,len(data)):
        data[i][index] = str(label)+str(data[i][index])
    return data

# %%
def readLines(data_file):
    r = csv.reader(open(data_file, "rt", newline=''),delimiter='\t')
    return [l for l in r]

# %%
directory = "e:/Franco/Downloads/"
transactions = readLines(directory+'revised_result.csv')

# %%
transactions
# Out:
# [['Created_Date',
#   'Complaint Type',
#   'Descriptor',
#   'Location Type',
#   'Zip Code',
#   'City',
#   'Borough',
#   'Precinct',
#   'Population',
#   '% Poverty Level',
#   'Year',
#   'Violence Binning',
#   'Misd Binning',
#   'Major Binning',
#   'Nonmajor Binning'],
#  ['2010-01-01 00:03:46',
#   'Noise - Residential',
#   'Loud Television',
#   'Residential Building/House',
#   '11230',
#   'BROOKLYN',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 00:08:02',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11220',
#   'BROOKLYN',
#   'BROOKLYN',
#   '68',
#   'Population Higher than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 00:15:08',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11355',
#   'FLUSHING',
#   'QUEENS',
#   '109',
#   'Population Higher than IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 00:15:12',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10014',
#   'NEW YORK',
#   'MANHATTAN',
#   '6',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 00:15:51',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Club/Bar/Restaurant',
#   '11220',
#   'BROOKLYN',
#   'BROOKLYN',
#   '68',
#   'Population Higher than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 00:19:07',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   'BRONX',
#   'BRONX',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-01 00:23:08',
#   'Noise - Street/Sidewalk',
#   'Loud Talking',
#   'Street/Sidewalk',
#   '10011',
#   'NEW YORK',
#   'MANHATTAN',
#   '10',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 00:24:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   '',
#   '10473',
#   'BRONX',
#   'BRONX',
#   '43',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher Outliers',
#   'Major Higher than IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-01 00:27:45',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11218',
#   'BROOKLYN',
#   'BROOKLYN',
#   '66',
#   'Population Within Higher IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 00:29:18',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11215',
#   'BROOKLYN',
#   'BROOKLYN',
#   '78',
#   'Population Within Higher IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 00:29:25',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10463',
#   'BRONX',
#   'BRONX',
#   '50',
#   'Population Within Higher IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 00:29:36',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10310',
#   'STATEN ISLAND',
#   'STATEN ISLAND',
#   '120',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher Outliers',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-01 00:29:57',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11233',
#   'BROOKLYN',
#   'BROOKLYN',
#   '60',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 00:30:50',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11355',
#   'FLUSHING',
#   'QUEENS',
#   '109',
#   'Population Higher than IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 00:34:02',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10301',
#   'STATEN ISLAND',
#   'STATEN ISLAND',
#   '120',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher Outliers',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-01 00:36:01',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Store/Commercial',
#   '11230',
#   'BROOKLYN',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 00:36:07',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11220',
#   'BROOKLYN',
#   'BROOKLYN',
#   '68',
#   'Population Higher than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 00:37:58',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11219',
#   'BROOKLYN',
#   'BROOKLYN',
#   '66',
#   'Population Higher than IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 00:38:36',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Store/Commercial',
#   '11434',
#   'JAMAICA',
#   'QUEENS',
#   '113',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Higher than IQR',
#   'Major Higher than IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-01 00:39:57',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Club/Bar/Restaurant',
#   '11234',
#   'BROOKLYN',
#   'BROOKLYN',
#   '63',
#   'Population Higher than IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 00:40:48',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10025',
#   'NEW YORK',
#   'MANHATTAN',
#   '24',
#   'Population Higher than IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 00:43:06',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11209',
#   'BROOKLYN',
#   'BROOKLYN',
#   '68',
#   'Population Within Higher IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 00:45:07',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10466',
#   'BRONX',
#   'BRONX',
#   '47',
#   'Population Within Higher IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Higher than IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 00:46:57',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11203',
#   'BROOKLYN',
#   'BROOKLYN',
#   '67',
#   'Population Higher than IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-01 00:48:21',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10451',
#   'BRONX',
#   'BRONX',
#   '42',
#   'Population Within Lower IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Higher than IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 00:48:31',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10023',
#   'NEW YORK',
#   'MANHATTAN',
#   '20',
#   'Population Within Higher IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 00:48:39',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Club/Bar/Restaurant',
#   '10014',
#   'NEW YORK',
#   'MANHATTAN',
#   '6',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 00:48:43',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11373',
#   'ELMHURST',
#   'QUEENS',
#   '110',
#   'Population Higher than IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 00:50:09',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11377',
#   'WOODSIDE',
#   'QUEENS',
#   '108',
#   'Population Higher than IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 00:50:23',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10466',
#   'BRONX',
#   'BRONX',
#   '47',
#   'Population Within Higher IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Higher than IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 00:52:22',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10304',
#   'STATEN ISLAND',
#   'STATEN ISLAND',
#   '122',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher Outliers',
#   'Misd Within Higher IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 00:53:03',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10029',
#   'NEW YORK',
#   'MANHATTAN',
#   '23',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Within Higher IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 00:53:37',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11206',
#   'BROOKLYN',
#   'BROOKLYN',
#   '90',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 00:54:26',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11354',
#   'FLUSHING',
#   'QUEENS',
#   '109',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 00:57:54',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11372',
#   'JACKSON HEIGHTS',
#   'QUEENS',
#   '115',
#   'Population Within Higher IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 00:58:11',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11375',
#   'FOREST HILLS',
#   'QUEENS',
#   '112',
#   'Population Within Higher IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 00:58:33',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11369',
#   'EAST ELMHURST',
#   'QUEENS',
#   '115',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 00:58:47',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10459',
#   'BRONX',
#   'BRONX',
#   '42',
#   'Population Within Lower IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Higher than IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 00:59:47',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10013',
#   'NEW YORK',
#   'MANHATTAN',
#   '5',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:02:17',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Club/Bar/Restaurant',
#   '10312',
#   'STATEN ISLAND',
#   'STATEN ISLAND',
#   '123',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:03:35',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11209',
#   'BROOKLYN',
#   'BROOKLYN',
#   '68',
#   'Population Within Higher IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:04:31',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11208',
#   'BROOKLYN',
#   'BROOKLYN',
#   '75',
#   'Population Higher than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher Outliers',
#   'Misd Higher Outliers',
#   'Major Higher Outliers',
#   'Nonmajor Higher Outliers'],
#  ['2010-01-01 01:04:51',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11211',
#   'BROOKLYN',
#   'BROOKLYN',
#   '90',
#   'Population Higher than IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:05:34',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Store/Commercial',
#   '10451',
#   'BRONX',
#   'BRONX',
#   '42',
#   'Population Within Lower IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Higher than IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 01:05:49',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11231',
#   'BROOKLYN',
#   'BROOKLYN',
#   '76',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:05:58',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10473',
#   'BRONX',
#   'BRONX',
#   '43',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher Outliers',
#   'Major Higher than IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-01 01:06:23',
#   'Noise - Street/Sidewalk',
#   'Loud Music/Party',
#   'Street/Sidewalk',
#   '10025',
#   'NEW YORK',
#   'MANHATTAN',
#   '24',
#   'Population Higher than IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:07:31',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11221',
#   'BROOKLYN',
#   'BROOKLYN',
#   '81',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 01:07:51',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10028',
#   'NEW YORK',
#   'MANHATTAN',
#   '30',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:08:00',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10452',
#   'BRONX',
#   'BRONX',
#   '44',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher Outliers',
#   'Major Higher than IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-01 01:08:48',
#   'Noise - Residential',
#   'Loud Talking',
#   'Residential Building/House',
#   '10454',
#   'BRONX',
#   'BRONX',
#   '40',
#   'Population Within Lower IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher Outliers',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-01 01:09:04',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11374',
#   'REGO PARK',
#   'QUEENS',
#   '112',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:09:34',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11377',
#   'WOODSIDE',
#   'QUEENS',
#   '108',
#   'Population Higher than IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:10:30',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10458',
#   'BRONX',
#   'BRONX',
#   '48',
#   'Population Higher than IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-01 01:12:00',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11373',
#   'ELMHURST',
#   'QUEENS',
#   '110',
#   'Population Higher than IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:12:15',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Club/Bar/Restaurant',
#   '11420',
#   'SOUTH OZONE PARK',
#   'QUEENS',
#   '106',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Within Lower IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:12:41',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11374',
#   'REGO PARK',
#   'QUEENS',
#   '112',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:14:25',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10306',
#   'STATEN ISLAND',
#   'STATEN ISLAND',
#   '122',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher Outliers',
#   'Misd Within Higher IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:14:42',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Club/Bar/Restaurant',
#   '10003',
#   'NEW YORK',
#   'MANHATTAN',
#   '9',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:15:21',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10027',
#   'NEW YORK',
#   'MANHATTAN',
#   '26',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:15:21',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10027',
#   'NEW YORK',
#   'MANHATTAN',
#   '28',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 01:16:13',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11219',
#   'BROOKLYN',
#   'BROOKLYN',
#   '66',
#   'Population Higher than IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:16:24',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10031',
#   'NEW YORK',
#   'MANHATTAN',
#   '33',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 01:16:24',
#   'Noise - Street/Sidewalk',
#   'Loud Music/Party',
#   'Street/Sidewalk',
#   '10011',
#   'NEW YORK',
#   'MANHATTAN',
#   '10',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:16:34',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10456',
#   'BRONX',
#   'BRONX',
#   '42',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Higher than IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 01:17:01',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11224',
#   'BROOKLYN',
#   'BROOKLYN',
#   '60',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 01:19:25',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11201',
#   'BROOKLYN',
#   'BROOKLYN',
#   '84',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:19:49',
#   'Noise - Commercial',
#   'Loud Talking',
#   'Club/Bar/Restaurant',
#   '11415',
#   'KEW GARDENS',
#   'QUEENS',
#   '102',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Within Lower IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:20:10',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10466',
#   'BRONX',
#   'BRONX',
#   '47',
#   'Population Within Higher IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Higher than IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 01:21:11',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Store/Commercial',
#   '11230',
#   'BROOKLYN',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 01:21:17',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10473',
#   'BRONX',
#   'BRONX',
#   '43',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher Outliers',
#   'Major Higher than IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-01 01:21:52',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Club/Bar/Restaurant',
#   '10023',
#   'NEW YORK',
#   'MANHATTAN',
#   '20',
#   'Population Within Higher IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:22:31',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10032',
#   'NEW YORK',
#   'MANHATTAN',
#   '33',
#   'Population Within Higher IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 01:23:48',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11238',
#   'BROOKLYN',
#   'BROOKLYN',
#   '77',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Within Higher IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 01:23:55',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11358',
#   'FLUSHING',
#   'QUEENS',
#   '109',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 01:24:43',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10031',
#   'NEW YORK',
#   'MANHATTAN',
#   '33',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 01:25:21',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11104',
#   'SUNNYSIDE',
#   'QUEENS',
#   '108',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:25:40',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10033',
#   'NEW YORK',
#   'MANHATTAN',
#   '34',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:25:47',
#   'Noise - Commercial',
#   'Loud Talking',
#   'Club/Bar/Restaurant',
#   '11231',
#   'BROOKLYN',
#   'BROOKLYN',
#   '76',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:25:53',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10463',
#   'BRONX',
#   'BRONX',
#   '50',
#   'Population Within Higher IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:28:26',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Store/Commercial',
#   '11217',
#   'BROOKLYN',
#   'BROOKLYN',
#   '78',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:29:14',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11217',
#   'BROOKLYN',
#   'BROOKLYN',
#   '78',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:30:24',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10451',
#   'BRONX',
#   'BRONX',
#   '42',
#   'Population Within Lower IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Higher than IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 01:32:12',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11421',
#   'WOODHAVEN',
#   'QUEENS',
#   '102',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Within Lower IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:32:28',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10035',
#   'NEW YORK',
#   'MANHATTAN',
#   '25',
#   'Population Within Lower IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Higher than IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-01 01:33:04',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10025',
#   'NEW YORK',
#   'MANHATTAN',
#   '24',
#   'Population Higher than IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:33:07',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10023',
#   'NEW YORK',
#   'MANHATTAN',
#   '20',
#   'Population Within Higher IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:33:39',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10473',
#   'BRONX',
#   'BRONX',
#   '43',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher Outliers',
#   'Major Higher than IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-01 01:36:56',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10460',
#   'BRONX',
#   'BRONX',
#   '48',
#   'Population Within Lower IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-01 01:36:57',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11210',
#   'BROOKLYN',
#   'BROOKLYN',
#   '63',
#   'Population Within Higher IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:37:13',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10460',
#   'BRONX',
#   'BRONX',
#   '48',
#   'Population Within Lower IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-01 01:37:20',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10301',
#   'STATEN ISLAND',
#   'STATEN ISLAND',
#   '120',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher Outliers',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-01 01:40:12',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11385',
#   'RIDGEWOOD',
#   'QUEENS',
#   '104',
#   'Population Higher than IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 01:41:15',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11226',
#   'BROOKLYN',
#   'BROOKLYN',
#   '67',
#   'Population Higher than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-01 01:42:41',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11213',
#   'BROOKLYN',
#   'BROOKLYN',
#   '77',
#   'Population Within Higher IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Within Higher IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 01:42:45',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11207',
#   'BROOKLYN',
#   'BROOKLYN',
#   '75',
#   'Population Higher than IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher Outliers',
#   'Misd Higher Outliers',
#   'Major Higher Outliers',
#   'Nonmajor Higher Outliers'],
#  ['2010-01-01 01:42:52',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11426',
#   'BELLEROSE',
#   'QUEENS',
#   '105',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Within Lower IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 01:43:00',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11217',
#   'BROOKLYN',
#   'BROOKLYN',
#   '78',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:43:49',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11217',
#   'BROOKLYN',
#   'BROOKLYN',
#   '78',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:45:58',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11225',
#   'BROOKLYN',
#   'BROOKLYN',
#   '71',
#   'Population Within Higher IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 01:47:56',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11212',
#   'BROOKLYN',
#   'BROOKLYN',
#   '73',
#   'Population Higher than IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Higher than IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-01 01:48:17',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11385',
#   'RIDGEWOOD',
#   'QUEENS',
#   '104',
#   'Population Higher than IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 01:49:05',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10034',
#   'NEW YORK',
#   'MANHATTAN',
#   '34',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:49:12',
#   'Noise - Residential',
#   'Loud Talking',
#   'Residential Building/House',
#   '11218',
#   'BROOKLYN',
#   'BROOKLYN',
#   '66',
#   'Population Within Higher IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:49:19',
#   'Noise - Residential',
#   'Loud Talking',
#   'Residential Building/House',
#   '11203',
#   'BROOKLYN',
#   'BROOKLYN',
#   '67',
#   'Population Higher than IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-01 01:50:30',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10452',
#   'BRONX',
#   'BRONX',
#   '44',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher Outliers',
#   'Major Higher than IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-01 01:51:27',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11215',
#   'BROOKLYN',
#   'BROOKLYN',
#   '78',
#   'Population Within Higher IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:51:47',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10454',
#   'BRONX',
#   'BRONX',
#   '40',
#   'Population Within Lower IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher Outliers',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-01 01:52:31',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11106',
#   'ASTORIA',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:55:30',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10458',
#   'BRONX',
#   'BRONX',
#   '48',
#   'Population Higher than IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-01 01:55:34',
#   'Noise - House of Worship',
#   'Loud Music/Party',
#   'House of Worship',
#   '10472',
#   'BRONX',
#   'BRONX',
#   '43',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher Outliers',
#   'Major Higher than IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-01 01:56:50',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Store/Commercial',
#   '11420',
#   'SOUTH OZONE PARK',
#   'QUEENS',
#   '106',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Within Lower IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:57:27',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Club/Bar/Restaurant',
#   '11206',
#   'BROOKLYN',
#   'BROOKLYN',
#   '90',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:57:53',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10033',
#   'NEW YORK',
#   'MANHATTAN',
#   '34',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 01:59:08',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Club/Bar/Restaurant',
#   '11211',
#   'BROOKLYN',
#   'BROOKLYN',
#   '90',
#   'Population Higher than IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 02:00:04',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11435',
#   'JAMAICA',
#   'QUEENS',
#   '103',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 02:01:03',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10458',
#   'BRONX',
#   'BRONX',
#   '48',
#   'Population Higher than IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-01 02:01:43',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11372',
#   'JACKSON HEIGHTS',
#   'QUEENS',
#   '115',
#   'Population Within Higher IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 02:03:07',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10452',
#   'BRONX',
#   'BRONX',
#   '44',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher Outliers',
#   'Major Higher than IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-01 02:05:41',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10023',
#   'NEW YORK',
#   'MANHATTAN',
#   '20',
#   'Population Within Higher IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 02:06:01',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11368',
#   'CORONA',
#   'QUEENS',
#   '110',
#   'Population Higher than IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 02:06:22',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Club/Bar/Restaurant',
#   '11231',
#   'BROOKLYN',
#   'BROOKLYN',
#   '76',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 02:06:29',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10462',
#   'BRONX',
#   'BRONX',
#   '43',
#   'Population Within Higher IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher Outliers',
#   'Major Higher than IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-01 02:06:38',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10456',
#   'BRONX',
#   'BRONX',
#   '42',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Higher than IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 02:07:17',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Club/Bar/Restaurant',
#   '11238',
#   'BROOKLYN',
#   'BROOKLYN',
#   '77',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Within Higher IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 02:07:55',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10473',
#   'BRONX',
#   'BRONX',
#   '43',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher Outliers',
#   'Major Higher than IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-01 02:08:09',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11358',
#   'FLUSHING',
#   'QUEENS',
#   '109',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 02:10:31',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11221',
#   'BROOKLYN',
#   'BROOKLYN',
#   '81',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 02:11:21',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11377',
#   'WOODSIDE',
#   'QUEENS',
#   '108',
#   'Population Higher than IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 02:12:15',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10029',
#   'NEW YORK',
#   'MANHATTAN',
#   '23',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Within Higher IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 02:12:34',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10034',
#   'NEW YORK',
#   'MANHATTAN',
#   '34',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 02:13:30',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11208',
#   'BROOKLYN',
#   'BROOKLYN',
#   '75',
#   'Population Higher than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher Outliers',
#   'Misd Higher Outliers',
#   'Major Higher Outliers',
#   'Nonmajor Higher Outliers'],
#  ['2010-01-01 02:13:49',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11203',
#   'BROOKLYN',
#   'BROOKLYN',
#   '67',
#   'Population Higher than IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-01 02:14:21',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Store/Commercial',
#   '11230',
#   'BROOKLYN',
#   'BROOKLYN',
#   '70',
#   'Population Higher than IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 02:15:31',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11372',
#   'JACKSON HEIGHTS',
#   'QUEENS',
#   '115',
#   'Population Within Higher IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 02:15:39',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11385',
#   'RIDGEWOOD',
#   'QUEENS',
#   '104',
#   'Population Higher than IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 02:17:22',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11234',
#   'BROOKLYN',
#   'BROOKLYN',
#   '63',
#   'Population Higher than IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 02:17:55',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10451',
#   'BRONX',
#   'BRONX',
#   '42',
#   'Population Within Lower IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Higher than IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-01 02:20:33',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11102',
#   'ASTORIA',
#   'QUEENS',
#   '114',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-01 02:21:13',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10023',
#   'NEW YORK',
#   'MANHATTAN',
#   '20',
#   'Population Within Higher IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
# ...
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-02 15:00:59',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10037',
#   'NEW YORK',
#   'MANHATTAN',
#   '32',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-02 15:02:57',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10468',
#   'BRONX',
#   'BRONX',
#   '52',
#   'Population Higher than IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Higher Outliers',
#   'Major Higher than IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-02 15:11:54',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11220',
#   'BROOKLYN',
#   'BROOKLYN',
#   '68',
#   'Population Higher than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-02 15:14:23',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10003',
#   'NEW YORK',
#   'MANHATTAN',
#   '9',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-02 15:16:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   '',
#   '10309',
#   'STATEN ISLAND',
#   'STATEN ISLAND',
#   '123',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-02 15:16:40',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10468',
#   'BRONX',
#   'BRONX',
#   '52',
#   'Population Higher than IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Higher Outliers',
#   'Major Higher than IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-02 15:20:24',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11224',
#   'BROOKLYN',
#   'BROOKLYN',
#   '60',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Higher IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-02 15:22:06',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11221',
#   'BROOKLYN',
#   'BROOKLYN',
#   '81',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-02 15:39:16',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10040',
#   'NEW YORK',
#   'MANHATTAN',
#   '34',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-02 15:45:32',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10469',
#   'BRONX',
#   'BRONX',
#   '49',
#   'Population Within Higher IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-02 15:46:02',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11419',
#   'SOUTH RICHMOND HILL',
#   'QUEENS',
#   '102',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Within Lower IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-02 15:49:49',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10463',
#   'BRONX',
#   'BRONX',
#   '50',
#   'Population Within Higher IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-02 15:50:27',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10466',
#   'BRONX',
#   'BRONX',
#   '47',
#   'Population Within Higher IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Higher than IQR',
#   'Major Higher than IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-02 15:53:31',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10032',
#   'NEW YORK',
#   'MANHATTAN',
#   '33',
#   'Population Within Higher IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-02 15:57:52',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11208',
#   'BROOKLYN',
#   'BROOKLYN',
#   '75',
#   'Population Higher than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher Outliers',
#   'Misd Higher Outliers',
#   'Major Higher Outliers',
#   'Nonmajor Higher Outliers'],
#  ['2010-01-02 16:05:42',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Store/Commercial',
#   '10002',
#   'NEW YORK',
#   'MANHATTAN',
#   '7',
#   'Population Higher than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-02 16:08:50',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10469',
#   'BRONX',
#   'BRONX',
#   '49',
#   'Population Within Higher IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-02 16:12:58',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Store/Commercial',
#   '10009',
#   'NEW YORK',
#   'MANHATTAN',
#   '9',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-02 16:13:08',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10460',
#   'BRONX',
#   'BRONX',
#   '48',
#   'Population Within Lower IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-02 16:15:11',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10453',
#   'BRONX',
#   'BRONX',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-02 16:18:03',
#   'Noise - Street/Sidewalk',
#   'Loud Music/Party',
#   'Street/Sidewalk',
#   '10002',
#   'NEW YORK',
#   'MANHATTAN',
#   '7',
#   'Population Higher than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-02 16:20:51',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10456',
#   'BRONX',
#   'BRONX',
#   '42',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Higher than IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-02 16:24:19',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10032',
#   'NEW YORK',
#   'MANHATTAN',
#   '33',
#   'Population Within Higher IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-02 16:32:40',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11201',
#   'BROOKLYN',
#   'BROOKLYN',
#   '84',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-02 16:33:09',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11361',
#   'BAYSIDE',
#   'QUEENS',
#   '111',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-02 16:38:52',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10457',
#   'BRONX',
#   'BRONX',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-02 16:49:58',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11226',
#   'BROOKLYN',
#   'BROOKLYN',
#   '67',
#   'Population Higher than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-02 16:54:46',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10029',
#   'NEW YORK',
#   'MANHATTAN',
#   '23',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Within Higher IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-02 17:17:48',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11210',
#   'BROOKLYN',
#   'BROOKLYN',
#   '63',
#   'Population Within Higher IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-02 17:23:03',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10473',
#   'BRONX',
#   'BRONX',
#   '43',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher Outliers',
#   'Major Higher than IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-02 17:25:16',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10452',
#   'BRONX',
#   'BRONX',
#   '44',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher Outliers',
#   'Major Higher than IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-02 17:27:16',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10461',
#   'BRONX',
#   'BRONX',
#   '49',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-02 17:28:08',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10452',
#   'BRONX',
#   'BRONX',
#   '44',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher Outliers',
#   'Major Higher than IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-02 17:34:28',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10453',
#   'BRONX',
#   'BRONX',
#   '46',
#   'Population Within Higher IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-02 17:39:00',
#   'Noise',
#   'Noise, Barking Dog (NR5)',
#   '',
#   '11435',
#   'Jamaica',
#   'QUEENS',
#   '103',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-02 17:42:20',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10467',
#   'BRONX',
#   'BRONX',
#   '52',
#   'Population Higher than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Higher Outliers',
#   'Major Higher than IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-02 17:44:56',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10458',
#   'BRONX',
#   'BRONX',
#   '48',
#   'Population Higher than IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-02 17:49:11',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11203',
#   'BROOKLYN',
#   'BROOKLYN',
#   '67',
#   'Population Higher than IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Higher than IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-02 17:51:07',
#   'Noise - Commercial',
#   'Loud Music/Party',
#   'Store/Commercial',
#   '10009',
#   'NEW YORK',
#   'MANHATTAN',
#   '9',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-02 17:52:52',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10467',
#   'BRONX',
#   'BRONX',
#   '52',
#   'Population Higher than IQR',
#   '% Poverty Level Within Higher IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Higher Outliers',
#   'Major Higher than IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-02 17:53:27',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11225',
#   'BROOKLYN',
#   'BROOKLYN',
#   '71',
#   'Population Within Higher IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-02 17:58:39',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11378',
#   'MASPETH',
#   'QUEENS',
#   '104',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Higher IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-02 17:58:46',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '10458',
#   'BRONX',
#   'BRONX',
#   '48',
#   'Population Higher than IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-02 18:03:58',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11377',
#   'WOODSIDE',
#   'QUEENS',
#   '108',
#   'Population Higher than IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Within Lower IQR',
#   'Major Within Lower IQR',
#   'Nonmajor Within Lower IQR'],
#  ['2010-01-02 18:16:56',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '10460',
#   'BRONX',
#   'BRONX',
#   '48',
#   'Population Within Lower IQR',
#   '% Poverty Level Higher than IQR',
#   '2010',
#   'VC Within Lower IQR',
#   'Misd Higher than IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Higher than IQR'],
#  ['2010-01-02 18:20:16',
#   'Noise - Residential',
#   'Banging/Pounding',
#   'Residential Building/House',
#   '11432',
#   'JAMAICA',
#   'QUEENS',
#   '103',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR'],
#  ['2010-01-02 18:21:24',
#   'Noise - Residential',
#   'Loud Music/Party',
#   'Residential Building/House',
#   '11435',
#   'JAMAICA',
#   'QUEENS',
#   '103',
#   'Population Within Lower IQR',
#   '% Poverty Level Within Lower IQR',
#   '2010',
#   'VC Higher than IQR',
#   'Misd Within Higher IQR',
#   'Major Within Higher IQR',
#   'Nonmajor Within Higher IQR'],
#  ...]

# %%
len(transactions)
# Out:
# 1539583

# %%
for row in transactions:
    del row[0:2]

# %%
min_sup = 0.15
min_conf = 0.7
patterns = list(apyori.apriori(transactions,min_support=min_sup,min_confidence=min_conf))

# %%
for record in patterns:
    print(record)
# Out:
# RelationRecord(items=frozenset({'% Poverty Level Within Lower IQR', 'Nonmajor Within Lower IQR'}), support=0.3579378312179337, ordered_statistics=[OrderedStatistic(items_base=frozenset({'% Poverty Level Within Lower IQR'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.702184375402172, lift=1.3748278427366585), OrderedStatistic(items_base=frozenset({'Nonmajor Within Lower IQR'}), items_add=frozenset({'% Poverty Level Within Lower IQR'}), confidence=0.7008172120681849, lift=1.3748278427366585)])
# RelationRecord(items=frozenset({'% Poverty Level Within Lower IQR', 'QUEENS'}), support=0.17000252665819252, ordered_statistics=[OrderedStatistic(items_base=frozenset({'QUEENS'}), items_add=frozenset({'% Poverty Level Within Lower IQR'}), confidence=0.924035304501324, lift=1.812725832676133)])
# RelationRecord(items=frozenset({'Noise - Residential', 'Loud Music/Party'}), support=0.38286730887519543, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Loud Music/Party'}), items_add=frozenset({'Noise - Residential'}), confidence=0.7157014397661018, lift=1.2470354489632927)])
# RelationRecord(items=frozenset({'Residential Building/House', 'Loud Music/Party'}), support=0.38155786339547787, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Loud Music/Party'}), items_add=frozenset({'Residential Building/House'}), confidence=0.713253667408931, lift=1.247056683024112)])
# RelationRecord(items=frozenset({'MANHATTAN', 'Major Within Lower IQR'}), support=0.26676184395384983, ordered_statistics=[OrderedStatistic(items_base=frozenset({'MANHATTAN'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.8931488617681087, lift=1.7610179832123913)])
# RelationRecord(items=frozenset({'MANHATTAN', 'Misd Within Lower IQR'}), support=0.2304065451489137, ordered_statistics=[OrderedStatistic(items_base=frozenset({'MANHATTAN'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.7714272044815979, lift=1.5203987523153253)])
# RelationRecord(items=frozenset({'MANHATTAN', 'NEW YORK'}), support=0.2986548955139151, ordered_statistics=[OrderedStatistic(items_base=frozenset({'MANHATTAN'}), items_add=frozenset({'NEW YORK'}), confidence=0.999930409972251, lift=3.3480331445827303), OrderedStatistic(items_base=frozenset({'NEW YORK'}), items_add=frozenset({'MANHATTAN'}), confidence=0.9999760773354501, lift=3.3480331445827303)])
# RelationRecord(items=frozenset({'MANHATTAN', 'Nonmajor Within Lower IQR'}), support=0.22902175459199017, ordered_statistics=[OrderedStatistic(items_base=frozenset({'MANHATTAN'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.7667907688828192, lift=1.5013226376758384)])
# RelationRecord(items=frozenset({'MANHATTAN', 'Population Within Lower IQR'}), support=0.2243990742947928, ordered_statistics=[OrderedStatistic(items_base=frozenset({'MANHATTAN'}), items_add=frozenset({'Population Within Lower IQR'}), confidence=0.7513135117737628, lift=1.4545304351071053)])
# RelationRecord(items=frozenset({'VC Within Lower IQR', 'MANHATTAN'}), support=0.2736481241998645, ordered_statistics=[OrderedStatistic(items_base=frozenset({'MANHATTAN'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.916204907836707, lift=1.792800322092378)])
# RelationRecord(items=frozenset({'Major Within Lower IQR', 'Misd Within Lower IQR'}), support=0.3934338064268052, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Major Within Lower IQR'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.7757318381951791, lift=1.528882715143291), OrderedStatistic(items_base=frozenset({'Misd Within Lower IQR'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.7754150552830978, lift=1.528882715143291)])
# RelationRecord(items=frozenset({'Major Within Lower IQR', 'NEW YORK'}), support=0.26674625531718654, ordered_statistics=[OrderedStatistic(items_base=frozenset({'NEW YORK'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.8931374574557159, lift=1.7609954973759654)])
# RelationRecord(items=frozenset({'Major Within Lower IQR', 'Nonmajor Within Lower IQR'}), support=0.39339678341472983, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Major Within Lower IQR'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.7756588400726395, lift=1.518685700156619), OrderedStatistic(items_base=frozenset({'Nonmajor Within Lower IQR'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.770243357767457, lift=1.5186857001566192)])
# RelationRecord(items=frozenset({'VC Within Lower IQR', 'Major Within Lower IQR'}), support=0.40169058764613536, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Major Within Lower IQR'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.7920117001903074, lift=1.5497830442261544), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.7860152338780299, lift=1.5497830442261544)])
# RelationRecord(items=frozenset({'NEW YORK', 'Misd Within Lower IQR'}), support=0.2303909565122504, ordered_statistics=[OrderedStatistic(items_base=frozenset({'NEW YORK'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.771410241075215, lift=1.5203653192943616)])
# RelationRecord(items=frozenset({'Nonmajor Within Lower IQR', 'Misd Within Lower IQR'}), support=0.4394579571221558, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Misd Within Lower IQR'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.8661236288037932, lift=1.6958094224890126), OrderedStatistic(items_base=frozenset({'Nonmajor Within Lower IQR'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.8604279108569917, lift=1.6958094224890128)])
# RelationRecord(items=frozenset({'VC Within Lower IQR', 'Misd Within Lower IQR'}), support=0.40694980394041763, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Misd Within Lower IQR'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.8020536099472452, lift=1.5694327305492375), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.7963062993216818, lift=1.5694327305492373)])
# RelationRecord(items=frozenset({'Nonmajor Within Lower IQR', 'NEW YORK'}), support=0.22900616595532686, ordered_statistics=[OrderedStatistic(items_base=frozenset({'NEW YORK'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.7667735937279123, lift=1.5012890099250702)])
# RelationRecord(items=frozenset({'NEW YORK', 'Population Within Lower IQR'}), support=0.22440621908659683, ordered_statistics=[OrderedStatistic(items_base=frozenset({'NEW YORK'}), items_add=frozenset({'Population Within Lower IQR'}), confidence=0.7513717473331667, lift=1.4546431781793796)])
# RelationRecord(items=frozenset({'VC Within Lower IQR', 'NEW YORK'}), support=0.2736325355632012, ordered_statistics=[OrderedStatistic(items_base=frozenset({'NEW YORK'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.9161945565064211, lift=1.7927800669419067)])
# RelationRecord(items=frozenset({'Nonmajor Higher than IQR', 'Noise - Residential'}), support=0.15031148044632864, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Nonmajor Higher than IQR'}), items_add=frozenset({'Noise - Residential'}), confidence=0.7152500254986137, lift=1.2462489064716227)])
# RelationRecord(items=frozenset({'Residential Building/House', 'Noise - Residential'}), support=0.5719496772827447, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Noise - Residential'}), items_add=frozenset({'Residential Building/House'}), confidence=0.9965629282900313, lift=1.7423961720278724), OrderedStatistic(items_base=frozenset({'Residential Building/House'}), items_add=frozenset({'Noise - Residential'}), confidence=1.0, lift=1.7423961720278722)])
# RelationRecord(items=frozenset({'VC Within Lower IQR', 'Nonmajor Within Lower IQR'}), support=0.4263622032719249, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Nonmajor Within Lower IQR'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.8347873417335171, lift=1.6334850450345175), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.8342918585305776, lift=1.6334850450345175)])
# RelationRecord(items=frozenset({'% Poverty Level Higher than IQR', 'Residential Building/House', 'Noise - Residential'}), support=0.16849497558754545, ordered_statistics=[OrderedStatistic(items_base=frozenset({'% Poverty Level Higher than IQR', 'Noise - Residential'}), items_add=frozenset({'Residential Building/House'}), confidence=0.9961790581666391, lift=1.7417250113669975), OrderedStatistic(items_base=frozenset({'% Poverty Level Higher than IQR', 'Residential Building/House'}), items_add=frozenset({'Noise - Residential'}), confidence=1.0, lift=1.7423961720278722)])
# RelationRecord(items=frozenset({'VC Within Lower IQR', '% Poverty Level Within Higher IQR', 'Major Within Lower IQR'}), support=0.15422682635492857, ordered_statistics=[OrderedStatistic(items_base=frozenset({'% Poverty Level Within Higher IQR', 'Major Within Lower IQR'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.9697055087947137, lift=1.897488578845031), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', '% Poverty Level Within Higher IQR'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.9999705203577987, lift=1.971637813596119)])
# RelationRecord(items=frozenset({'% Poverty Level Within Lower IQR', 'Major Within Lower IQR', 'Misd Within Lower IQR'}), support=0.2465524755729311, ordered_statistics=[OrderedStatistic(items_base=frozenset({'% Poverty Level Within Lower IQR', 'Major Within Lower IQR'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.9110082847734887, lift=1.7954978142744222), OrderedStatistic(items_base=frozenset({'% Poverty Level Within Lower IQR', 'Misd Within Lower IQR'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.7235539899659942, lift=1.426628463291953)])
# RelationRecord(items=frozenset({'% Poverty Level Within Lower IQR', 'Major Within Lower IQR', 'Nonmajor Within Lower IQR'}), support=0.2563954005727525, ordered_statistics=[OrderedStatistic(items_base=frozenset({'% Poverty Level Within Lower IQR', 'Major Within Lower IQR'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.9473777683911412, lift=1.8548993386927382), OrderedStatistic(items_base=frozenset({'% Poverty Level Within Lower IQR', 'Nonmajor Within Lower IQR'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.7163126616159325, lift=1.4123507655948864)])
# RelationRecord(items=frozenset({'% Poverty Level Within Lower IQR', 'VC Within Lower IQR', 'Major Within Lower IQR'}), support=0.2241503056347076, ordered_statistics=[OrderedStatistic(items_base=frozenset({'% Poverty Level Within Lower IQR', 'Major Within Lower IQR'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.828232549655841, lift=1.6206588385302836), OrderedStatistic(items_base=frozenset({'% Poverty Level Within Lower IQR', 'VC Within Lower IQR'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.7728525838418903, lift=1.5238303006101732)])
# RelationRecord(items=frozenset({'% Poverty Level Within Lower IQR', 'Nonmajor Within Lower IQR', 'Misd Within Lower IQR'}), support=0.31453906674729454, ordered_statistics=[OrderedStatistic(items_base=frozenset({'% Poverty Level Within Lower IQR', 'Misd Within Lower IQR'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.9230732573920734, lift=1.8073128078667284), OrderedStatistic(items_base=frozenset({'% Poverty Level Within Lower IQR', 'Nonmajor Within Lower IQR'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.8787533457333393, lift=1.731926852830814), OrderedStatistic(items_base=frozenset({'Nonmajor Within Lower IQR', 'Misd Within Lower IQR'}), items_add=frozenset({'% Poverty Level Within Lower IQR'}), confidence=0.7157432506333304, lift=1.4041089920117518)])
# RelationRecord(items=frozenset({'% Poverty Level Within Lower IQR', 'VC Within Lower IQR', 'Misd Within Lower IQR'}), support=0.2574820584534903, ordered_statistics=[OrderedStatistic(items_base=frozenset({'% Poverty Level Within Lower IQR', 'Misd Within Lower IQR'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.7556288790277078, lift=1.4785903089100463), OrderedStatistic(items_base=frozenset({'% Poverty Level Within Lower IQR', 'VC Within Lower IQR'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.8877778399865629, lift=1.749713145203143)])
# RelationRecord(items=frozenset({'% Poverty Level Within Lower IQR', 'Residential Building/House', 'Noise - Residential'}), support=0.2625626549526722, ordered_statistics=[OrderedStatistic(items_base=frozenset({'% Poverty Level Within Lower IQR', 'Noise - Residential'}), items_add=frozenset({'Residential Building/House'}), confidence=0.996855826707964, lift=1.7429082772524513), OrderedStatistic(items_base=frozenset({'% Poverty Level Within Lower IQR', 'Residential Building/House'}), items_add=frozenset({'Noise - Residential'}), confidence=1.0, lift=1.7423961720278722)])
# RelationRecord(items=frozenset({'% Poverty Level Within Lower IQR', 'Nonmajor Within Lower IQR', 'Population Within Lower IQR'}), support=0.21610786816949784, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Nonmajor Within Lower IQR', 'Population Within Lower IQR'}), items_add=frozenset({'% Poverty Level Within Lower IQR'}), confidence=0.7241993269862829, lift=1.4206976958993711)])
# RelationRecord(items=frozenset({'% Poverty Level Within Lower IQR', 'VC Within Lower IQR', 'Nonmajor Within Lower IQR'}), support=0.2795880442951111, ordered_statistics=[OrderedStatistic(items_base=frozenset({'% Poverty Level Within Lower IQR', 'Nonmajor Within Lower IQR'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.7811078346867486, lift=1.5284467105963893), OrderedStatistic(items_base=frozenset({'% Poverty Level Within Lower IQR', 'VC Within Lower IQR'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.9639975365321092, lift=1.8874396810592906)])
# RelationRecord(items=frozenset({'BROOKLYN', 'Residential Building/House', 'Noise - Residential'}), support=0.1765581979016396, ordered_statistics=[OrderedStatistic(items_base=frozenset({'BROOKLYN', 'Noise - Residential'}), items_add=frozenset({'Residential Building/House'}), confidence=0.9965940129420174, lift=1.7424505206064638), OrderedStatistic(items_base=frozenset({'BROOKLYN', 'Residential Building/House'}), items_add=frozenset({'Noise - Residential'}), confidence=1.0, lift=1.7423961720278722)])
# RelationRecord(items=frozenset({'Major Within Lower IQR', 'Loud Music/Party', 'Misd Within Lower IQR'}), support=0.18856924245071555, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Major Within Lower IQR', 'Loud Music/Party'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.7440121371788234, lift=1.4663666493772531), OrderedStatistic(items_base=frozenset({'Loud Music/Party', 'Misd Within Lower IQR'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.7516751763207224, lift=1.4820748922130045)])
# RelationRecord(items=frozenset({'Major Within Lower IQR', 'Nonmajor Within Lower IQR', 'Loud Music/Party'}), support=0.1891479705868407, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Major Within Lower IQR', 'Loud Music/Party'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.7462955464549493, lift=1.4611944271602202), OrderedStatistic(items_base=frozenset({'Nonmajor Within Lower IQR', 'Loud Music/Party'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.75544711903891, lift=1.4895120163506603)])
# RelationRecord(items=frozenset({'VC Within Lower IQR', 'Major Within Lower IQR', 'Loud Music/Party'}), support=0.1957289733648657, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Major Within Lower IQR', 'Loud Music/Party'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.7722613183805478, lift=1.5111361317646297), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Loud Music/Party'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.7779693966329584, lift=1.5339190996083203)])
# RelationRecord(items=frozenset({'Nonmajor Within Lower IQR', 'Loud Music/Party', 'Misd Within Lower IQR'}), support=0.20987825924292486, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Loud Music/Party', 'Misd Within Lower IQR'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.8366172312727196, lift=1.6380379620498051), OrderedStatistic(items_base=frozenset({'Nonmajor Within Lower IQR', 'Loud Music/Party'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.8382428095953346, lift=1.652085011316763)])
# RelationRecord(items=frozenset({'VC Within Lower IQR', 'Loud Music/Party', 'Misd Within Lower IQR'}), support=0.1910095136150503, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Loud Music/Party', 'Misd Within Lower IQR'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.7614025912155514, lift=1.4898881233852765), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Loud Music/Party'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.7592108286454123, lift=1.4963216100117513)])
# RelationRecord(items=frozenset({'Residential Building/House', 'Noise - Residential', 'Loud Music/Party'}), support=0.38155786339547787, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Noise - Residential', 'Loud Music/Party'}), items_add=frozenset({'Residential Building/House'}), confidence=0.9965798973969219, lift=1.7424258409088327), OrderedStatistic(items_base=frozenset({'Residential Building/House', 'Loud Music/Party'}), items_add=frozenset({'Noise - Residential'}), confidence=1.0, lift=1.7423961720278722)])
# RelationRecord(items=frozenset({'VC Within Lower IQR', 'Nonmajor Within Lower IQR', 'Loud Music/Party'}), support=0.20242429281175486, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Nonmajor Within Lower IQR', 'Loud Music/Party'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.8084720568435635, lift=1.5819921411839415), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Loud Music/Party'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.8045814691371729, lift=1.5753141828116062)])
# RelationRecord(items=frozenset({'MANHATTAN', 'Major Within Lower IQR', 'Misd Within Lower IQR'}), support=0.20378634994021108, ordered_statistics=[OrderedStatistic(items_base=frozenset({'MANHATTAN', 'Major Within Lower IQR'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.7639261557041359, lift=1.5056150045604435), OrderedStatistic(items_base=frozenset({'MANHATTAN', 'Misd Within Lower IQR'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.8844642404081977, lift=1.7438945505497583)])
# RelationRecord(items=frozenset({'MANHATTAN', 'Major Within Lower IQR', 'NEW YORK'}), support=0.26674105910496543, ordered_statistics=[OrderedStatistic(items_base=frozenset({'MANHATTAN', 'Major Within Lower IQR'}), items_add=frozenset({'NEW YORK'}), confidence=0.9999220846258358, lift=3.3480052691071367), OrderedStatistic(items_base=frozenset({'MANHATTAN', 'NEW YORK'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.8931414254769424, lift=1.7610033211073015), OrderedStatistic(items_base=frozenset({'Major Within Lower IQR', 'NEW YORK'}), items_add=frozenset({'MANHATTAN'}), confidence=0.9999805200181163, lift=3.348048019187388)])
# RelationRecord(items=frozenset({'MANHATTAN', 'Major Within Lower IQR', 'Nonmajor Within Lower IQR'}), support=0.19722288437843233, ordered_statistics=[OrderedStatistic(items_base=frozenset({'MANHATTAN', 'Major Within Lower IQR'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.7393219414563357, lift=1.4475405968384467), OrderedStatistic(items_base=frozenset({'MANHATTAN', 'Nonmajor Within Lower IQR'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.8611534949148888, lift=1.697932848337499)])
# RelationRecord(items=frozenset({'MANHATTAN', 'Major Within Lower IQR', 'Population Within Lower IQR'}), support=0.19674093569492518, ordered_statistics=[OrderedStatistic(items_base=frozenset({'MANHATTAN', 'Major Within Lower IQR'}), items_add=frozenset({'Population Within Lower IQR'}), confidence=0.7375152787179026, lift=1.4278172859144775), OrderedStatistic(items_base=frozenset({'MANHATTAN', 'Population Within Lower IQR'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.876745754469855, lift=1.7286760431738595)])
# RelationRecord(items=frozenset({'VC Within Lower IQR', 'MANHATTAN', 'Major Within Lower IQR'}), support=0.24187978173310565, ordered_statistics=[OrderedStatistic(items_base=frozenset({'MANHATTAN', 'Major Within Lower IQR'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.9067255577036392, lift=1.7742514343638487), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'MANHATTAN'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.8839080568900366, lift=1.7427979257659465)])
# RelationRecord(items=frozenset({'MANHATTAN', 'NEW YORK', 'Misd Within Lower IQR'}), support=0.2303857603000293, ordered_statistics=[OrderedStatistic(items_base=frozenset({'MANHATTAN', 'Misd Within Lower IQR'}), items_add=frozenset({'NEW YORK'}), confidence=0.9999097905449215, lift=3.34796410525216), OrderedStatistic(items_base=frozenset({'MANHATTAN', 'NEW YORK'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.7714112969874121, lift=1.520367400381958), OrderedStatistic(items_base=frozenset({'NEW YORK', 'Misd Within Lower IQR'}), items_add=frozenset({'MANHATTAN'}), confidence=0.9999774461102998, lift=3.3480377273959276)])
# RelationRecord(items=frozenset({'MANHATTAN', 'Nonmajor Within Lower IQR', 'Misd Within Lower IQR'}), support=0.19777887908609018, ordered_statistics=[OrderedStatistic(items_base=frozenset({'MANHATTAN', 'Misd Within Lower IQR'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.858390888845037, lift=1.6806692590670462), OrderedStatistic(items_base=frozenset({'MANHATTAN', 'Nonmajor Within Lower IQR'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.8635811887758863, lift=1.7020241888152958)])
# RelationRecord(items=frozenset({'MANHATTAN', 'Population Within Lower IQR', 'Misd Within Lower IQR'}), support=0.17034417761172993, ordered_statistics=[OrderedStatistic(items_base=frozenset({'MANHATTAN', 'Misd Within Lower IQR'}), items_add=frozenset({'Population Within Lower IQR'}), confidence=0.7393200462323457, lift=1.431311285738669), OrderedStatistic(items_base=frozenset({'MANHATTAN', 'Population Within Lower IQR'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.7591126574254445, lift=1.4961281252610386)])
# RelationRecord(items=frozenset({'VC Within Lower IQR', 'MANHATTAN', 'Misd Within Lower IQR'}), support=0.22831247162380983, ordered_statistics=[OrderedStatistic(items_base=frozenset({'MANHATTAN', 'Misd Within Lower IQR'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.9909113974008401, lift=1.9389835802340591), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'MANHATTAN'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.8343286557924919, lift=1.644370641738351)])
# RelationRecord(items=frozenset({'MANHATTAN', 'Nonmajor Within Lower IQR', 'NEW YORK'}), support=0.22900096974310577, ordered_statistics=[OrderedStatistic(items_base=frozenset({'MANHATTAN', 'NEW YORK'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.7667745387164967, lift=1.501290860146554), OrderedStatistic(items_base=frozenset({'MANHATTAN', 'Nonmajor Within Lower IQR'}), items_add=frozenset({'NEW YORK'}), confidence=0.9999092450893086, lift=3.3479622789215946), OrderedStatistic(items_base=frozenset({'Nonmajor Within Lower IQR', 'NEW YORK'}), items_add=frozenset({'MANHATTAN'}), confidence=0.999977309727887, lift=3.3480372707721657)])
# RelationRecord(items=frozenset({'MANHATTAN', 'NEW YORK', 'Population Within Lower IQR'}), support=0.2243990742947928, ordered_statistics=[OrderedStatistic(items_base=frozenset({'MANHATTAN', 'NEW YORK'}), items_add=frozenset({'Population Within Lower IQR'}), confidence=0.7513657993405887, lift=1.4546316629648959), OrderedStatistic(items_base=frozenset({'MANHATTAN', 'Population Within Lower IQR'}), items_add=frozenset({'NEW YORK'}), confidence=1.0, lift=3.348266150517056), OrderedStatistic(items_base=frozenset({'NEW YORK', 'Population Within Lower IQR'}), items_add=frozenset({'MANHATTAN'}), confidence=0.9999681613467171, lift=3.3480066409560427)])
# RelationRecord(items=frozenset({'VC Within Lower IQR', 'MANHATTAN', 'NEW YORK'}), support=0.2736273393509801, ordered_statistics=[OrderedStatistic(items_base=frozenset({'MANHATTAN', 'NEW YORK'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.9161990761280895, lift=1.7927889107923527), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'MANHATTAN'}), items_add=frozenset({'NEW YORK'}), confidence=0.9999240453449291, lift=3.3480118341165075), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'NEW YORK'}), items_add=frozenset({'MANHATTAN'}), confidence=0.9999810102544625, lift=3.3480496605541896)])
# RelationRecord(items=frozenset({'MANHATTAN', 'Nonmajor Within Lower IQR', 'Population Within Lower IQR'}), support=0.16704523237785815, ordered_statistics=[OrderedStatistic(items_base=frozenset({'MANHATTAN', 'Nonmajor Within Lower IQR'}), items_add=frozenset({'Population Within Lower IQR'}), confidence=0.7293858728637144, lift=1.4120788916902896), OrderedStatistic(items_base=frozenset({'MANHATTAN', 'Population Within Lower IQR'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.7444114148100763, lift=1.4575054293193481)])
# RelationRecord(items=frozenset({'VC Within Lower IQR', 'MANHATTAN', 'Nonmajor Within Lower IQR'}), support=0.22509146957325457, ordered_statistics=[OrderedStatistic(items_base=frozenset({'MANHATTAN', 'Nonmajor Within Lower IQR'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.98283881360643, lift=1.9231874076716267), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'MANHATTAN'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.8225580578394698, lift=1.610511084837784)])
# RelationRecord(items=frozenset({'VC Within Lower IQR', 'MANHATTAN', 'Population Within Lower IQR'}), support=0.21358575666268073, ordered_statistics=[OrderedStatistic(items_base=frozenset({'MANHATTAN', 'Population Within Lower IQR'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.9518121112304294, lift=1.8624753534822467), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'MANHATTAN'}), items_add=frozenset({'Population Within Lower IQR'}), confidence=0.7805124090917722, lift=1.511059013596721)])
# RelationRecord(items=frozenset({'Residential Building/House', 'Noise - Residential', 'Major Within Higher IQR'}), support=0.1572471247084438, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Noise - Residential', 'Major Within Higher IQR'}), items_add=frozenset({'Residential Building/House'}), confidence=0.9968048881916739, lift=1.7428192160669775), OrderedStatistic(items_base=frozenset({'Residential Building/House', 'Major Within Higher IQR'}), items_add=frozenset({'Noise - Residential'}), confidence=1.0, lift=1.7423961720278722)])
# RelationRecord(items=frozenset({'Major Within Lower IQR', 'NEW YORK', 'Misd Within Lower IQR'}), support=0.2037707613035478, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Major Within Lower IQR', 'NEW YORK'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.7639123595615056, lift=1.5055878138703562), OrderedStatistic(items_base=frozenset({'NEW YORK', 'Misd Within Lower IQR'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.884456423065863, lift=1.7438791371276272)])
# RelationRecord(items=frozenset({'Major Within Lower IQR', 'Noise - Residential', 'Misd Within Lower IQR'}), support=0.18601660319709948, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Major Within Lower IQR', 'Noise - Residential'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.73079229471761, lift=1.4403117839705541), OrderedStatistic(items_base=frozenset({'Noise - Residential', 'Misd Within Lower IQR'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.7480579455754593, lift=1.4749428130439992)])
# RelationRecord(items=frozenset({'Major Within Lower IQR', 'Nonmajor Within Lower IQR', 'Misd Within Lower IQR'}), support=0.3583431357711796, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Major Within Lower IQR', 'Misd Within Lower IQR'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.9108092134371429, lift=1.7833006684850632), OrderedStatistic(items_base=frozenset({'Major Within Lower IQR', 'Nonmajor Within Lower IQR'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.9108949307127514, lift=1.7952744058030672), OrderedStatistic(items_base=frozenset({'Nonmajor Within Lower IQR', 'Misd Within Lower IQR'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.8154207472265003, lift=1.6077617754644562)])
# RelationRecord(items=frozenset({'Major Within Lower IQR', 'Population Within Lower IQR', 'Misd Within Lower IQR'}), support=0.2434834627298431, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Major Within Lower IQR', 'Population Within Lower IQR'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.7605532358657854, lift=1.4989673480037449), OrderedStatistic(items_base=frozenset({'Population Within Lower IQR', 'Misd Within Lower IQR'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.78400915220774, lift=1.545827661144571)])
# RelationRecord(items=frozenset({'Major Within Lower IQR', 'Residential Building/House', 'Misd Within Lower IQR'}), support=0.1854138425794517, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Major Within Lower IQR', 'Residential Building/House'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.7310864108999641, lift=1.4408914548378622), OrderedStatistic(items_base=frozenset({'Residential Building/House', 'Misd Within Lower IQR'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.7481098080324968, lift=1.4750450700399)])
# RelationRecord(items=frozenset({'VC Within Lower IQR', 'Major Within Lower IQR', 'Misd Within Lower IQR'}), support=0.3558742854396288, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Major Within Lower IQR', 'Misd Within Lower IQR'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.9045340782270472, lift=1.7699632177456148), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Major Within Lower IQR'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.8859413100142941, lift=1.7460935452432174), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Misd Within Lower IQR'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.8744918463991522, lift=1.724232021785132)])
# RelationRecord(items=frozenset({'Major Within Lower IQR', 'Nonmajor Within Lower IQR', 'NEW YORK'}), support=0.19720729574176904, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Major Within Lower IQR', 'NEW YORK'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.7393067074447621, lift=1.447510769710414), OrderedStatistic(items_base=frozenset({'Nonmajor Within Lower IQR', 'NEW YORK'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.861144043519942, lift=1.6979142130604692)])
# RelationRecord(items=frozenset({'Major Within Lower IQR', 'NEW YORK', 'Population Within Lower IQR'}), support=0.1967461319071463, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Major Within Lower IQR', 'NEW YORK'}), items_add=frozenset({'Population Within Lower IQR'}), confidence=0.7375778590525911, lift=1.4279384403992794), OrderedStatistic(items_base=frozenset({'NEW YORK', 'Population Within Lower IQR'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.876740995449967, lift=1.728666659833675)])
# RelationRecord(items=frozenset({'VC Within Lower IQR', 'Major Within Lower IQR', 'NEW YORK'}), support=0.24186419309644236, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Major Within Lower IQR', 'NEW YORK'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.9067201067503008, lift=1.7742407681135186), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'NEW YORK'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.8839014432206609, lift=1.7427848856209)])
# RelationRecord(items=frozenset({'Major Within Lower IQR', 'Nonmajor Within Lower IQR', 'Noise - Residential'}), support=0.18489681946345213, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Major Within Lower IQR', 'Noise - Residential'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.7263930673893241, lift=1.4222267666462227), OrderedStatistic(items_base=frozenset({'Nonmajor Within Lower IQR', 'Noise - Residential'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.7476205483769304, lift=1.4740803987641542)])
# RelationRecord(items=frozenset({'Major Within Lower IQR', 'Residential Building/House', 'Noise - Residential'}), support=0.253614127981408, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Major Within Lower IQR', 'Noise - Residential'}), items_add=frozenset({'Residential Building/House'}), confidence=0.9963586442010071, lift=1.7420390005893032), OrderedStatistic(items_base=frozenset({'Major Within Lower IQR', 'Residential Building/House'}), items_add=frozenset({'Noise - Residential'}), confidence=1.0, lift=1.7423961720278722)])
# RelationRecord(items=frozenset({'VC Within Lower IQR', 'Major Within Lower IQR', 'Noise - Residential'}), support=0.1862101621023355, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Major Within Lower IQR', 'Noise - Residential'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.7315527180028938, lift=1.431478850686197), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Noise - Residential'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.7739610273909734, lift=1.5260158142539426)])
# RelationRecord(items=frozenset({'Major Within Lower IQR', 'Nonmajor Within Lower IQR', 'Population Within Lower IQR'}), support=0.2388893615998618, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Major Within Lower IQR', 'Population Within Lower IQR'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.7462029451268255, lift=1.4610131202433492), OrderedStatistic(items_base=frozenset({'Nonmajor Within Lower IQR', 'Population Within Lower IQR'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.8005424159712337, lift=1.5784262301569842)])
# RelationRecord(items=frozenset({'Major Within Lower IQR', 'Nonmajor Within Lower IQR', 'Residential Building/House'}), support=0.18426807778469884, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Major Within Lower IQR', 'Residential Building/House'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.7265686626030834, lift=1.422570569780249), OrderedStatistic(items_base=frozenset({'Residential Building/House', 'Nonmajor Within Lower IQR'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.7475284048989228, lift=1.4738987198428086)])
# RelationRecord(items=frozenset({'VC Within Lower IQR', 'Major Within Lower IQR', 'Nonmajor Within Lower IQR'}), support=0.35025718002861816, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Major Within Lower IQR', 'Nonmajor Within Lower IQR'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.8903407317882599, lift=1.7421901335268148), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Major Within Lower IQR'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.8719576480023803, lift=1.707232023603832), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Nonmajor Within Lower IQR'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.8215014777124403, lift=1.6197511270666178)])
# RelationRecord(items=frozenset({'VC Within Lower IQR', 'Major Within Lower IQR', 'Population Within Lower IQR'}), support=0.2653783524499816, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Major Within Lower IQR', 'Population Within Lower IQR'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.8289448590129078, lift=1.622052662590661), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Population Within Lower IQR'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.8675983122506227, lift=1.7106400685026555)])
# RelationRecord(items=frozenset({'VC Within Lower IQR', 'Major Within Lower IQR', 'Residential Building/House'}), support=0.18549048670971297, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Major Within Lower IQR', 'Residential Building/House'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.7313886185524765, lift=1.4311577461548342), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Residential Building/House'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.7737563671832666, lift=1.5256122865536372)])
# RelationRecord(items=frozenset({'Nonmajor Within Lower IQR', 'NEW YORK', 'Misd Within Lower IQR'}), support=0.1977632904494269, ordered_statistics=[OrderedStatistic(items_base=frozenset({'NEW YORK', 'Misd Within Lower IQR'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.8583813073362165, lift=1.6806504991436368), OrderedStatistic(items_base=frozenset({'Nonmajor Within Lower IQR', 'NEW YORK'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.8635719026360424, lift=1.7020058868480454)])
# RelationRecord(items=frozenset({'NEW YORK', 'Population Within Lower IQR', 'Misd Within Lower IQR'}), support=0.17034937382395104, ordered_statistics=[OrderedStatistic(items_base=frozenset({'NEW YORK', 'Misd Within Lower IQR'}), items_add=frozenset({'Population Within Lower IQR'}), confidence=0.7393926237503736, lift=1.4314517946037724), OrderedStatistic(items_base=frozenset({'NEW YORK', 'Population Within Lower IQR'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.7591116436849479, lift=1.4961261272892568)])
# RelationRecord(items=frozenset({'VC Within Lower IQR', 'NEW YORK', 'Misd Within Lower IQR'}), support=0.2282968829871465, ordered_statistics=[OrderedStatistic(items_base=frozenset({'NEW YORK', 'Misd Within Lower IQR'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.9909107824508184, lift=1.9389823769196177), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'NEW YORK'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.8343192176224837, lift=1.644352040136254)])
# RelationRecord(items=frozenset({'Nonmajor Within Lower IQR', 'Noise - Residential', 'Misd Within Lower IQR'}), support=0.2084772305228104, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Noise - Residential', 'Misd Within Lower IQR'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.838382413632778, lift=1.6414940655193901), OrderedStatistic(items_base=frozenset({'Nonmajor Within Lower IQR', 'Noise - Residential'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.8429666981825822, lift=1.6613952797029476)])
# RelationRecord(items=frozenset({'Residential Building/House', 'Noise - Residential', 'Misd Within Lower IQR'}), support=0.24784308478334718, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Noise - Residential', 'Misd Within Lower IQR'}), items_add=frozenset({'Residential Building/House'}), confidence=0.9966905407452683, lift=1.7426192903550708), OrderedStatistic(items_base=frozenset({'Residential Building/House', 'Misd Within Lower IQR'}), items_add=frozenset({'Noise - Residential'}), confidence=1.0, lift=1.7423961720278722)])
# RelationRecord(items=frozenset({'VC Within Lower IQR', 'Noise - Residential', 'Misd Within Lower IQR'}), support=0.18373156887287012, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Noise - Residential', 'Misd Within Lower IQR'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.7388687761530867, lift=1.4457946781784135), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Noise - Residential'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.7636590409649744, lift=1.5050885505881348)])
# RelationRecord(items=frozenset({'Nonmajor Within Lower IQR', 'Population Within Lower IQR', 'Misd Within Lower IQR'}), support=0.26057510377810095, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Population Within Lower IQR', 'Misd Within Lower IQR'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.8390437030468318, lift=1.6427888238911177), OrderedStatistic(items_base=frozenset({'Nonmajor Within Lower IQR', 'Population Within Lower IQR'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.8732135316677767, lift=1.7210084844554074)])
# RelationRecord(items=frozenset({'Residential Building/House', 'Nonmajor Within Lower IQR', 'Misd Within Lower IQR'}), support=0.20769909774270046, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Residential Building/House', 'Misd Within Lower IQR'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.8380266002751753, lift=1.640797407877913), OrderedStatistic(items_base=frozenset({'Residential Building/House', 'Nonmajor Within Lower IQR'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.8425820527414153, lift=1.6606371855555848)])
# RelationRecord(items=frozenset({'VC Within Lower IQR', 'Nonmajor Within Lower IQR', 'Misd Within Lower IQR'}), support=0.37540619765222144, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Nonmajor Within Lower IQR', 'Misd Within Lower IQR'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.8542482655465266, lift=1.6715655553895188), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Misd Within Lower IQR'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.9224877221151959, lift=1.8061663707915736), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Nonmajor Within Lower IQR'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.8804865787148473, lift=1.735342865705713)])
# RelationRecord(items=frozenset({'VC Within Lower IQR', 'Population Within Lower IQR', 'Misd Within Lower IQR'}), support=0.24520795566072112, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Population Within Lower IQR', 'Misd Within Lower IQR'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.7895619656332089, lift=1.54498948236522), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Population Within Lower IQR'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.8016554723383653, lift=1.5799753662421925)])
# RelationRecord(items=frozenset({'VC Within Lower IQR', 'Residential Building/House', 'Misd Within Lower IQR'}), support=0.18302358495774504, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Residential Building/House', 'Misd Within Lower IQR'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.7384655703334861, lift=1.445005697987338), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Residential Building/House'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.7634659152487265, lift=1.5047079208977152)])
# RelationRecord(items=frozenset({'Nonmajor Within Lower IQR', 'NEW YORK', 'Population Within Lower IQR'}), support=0.16705042859007926, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Nonmajor Within Lower IQR', 'NEW YORK'}), items_add=frozenset({'Population Within Lower IQR'}), confidence=0.7294582130276198, lift=1.4122189410417683), OrderedStatistic(items_base=frozenset({'NEW YORK', 'Population Within Lower IQR'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.7444108691373461, lift=1.4575043609303484)])
# RelationRecord(items=frozenset({'VC Within Lower IQR', 'Nonmajor Within Lower IQR', 'NEW YORK'}), support=0.22507588093659128, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Nonmajor Within Lower IQR', 'NEW YORK'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.9828376454304629, lift=1.9231851218224327), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'NEW YORK'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.822547949107482, lift=1.610491292648327)])
# RelationRecord(items=frozenset({'VC Within Lower IQR', 'NEW YORK', 'Population Within Lower IQR'}), support=0.21359095287490185, ordered_statistics=[OrderedStatistic(items_base=frozenset({'NEW YORK', 'Population Within Lower IQR'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.9518049621988353, lift=1.8624613644869519), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'NEW YORK'}), items_add=frozenset({'Population Within Lower IQR'}), confidence=0.7805758640334219, lift=1.5111818613060208)])
# RelationRecord(items=frozenset({'Nonmajor Within Higher IQR', 'Residential Building/House', 'Noise - Residential'}), support=0.1556648780871184, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Nonmajor Within Higher IQR', 'Noise - Residential'}), items_add=frozenset({'Residential Building/House'}), confidence=0.9964533994145822, lift=1.7422046711322525), OrderedStatistic(items_base=frozenset({'Nonmajor Within Higher IQR', 'Residential Building/House'}), items_add=frozenset({'Noise - Residential'}), confidence=1.0, lift=1.7423961720278722)])
# RelationRecord(items=frozenset({'Residential Building/House', 'Nonmajor Within Lower IQR', 'Noise - Residential'}), support=0.24650311155683066, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Nonmajor Within Lower IQR', 'Noise - Residential'}), items_add=frozenset({'Residential Building/House'}), confidence=0.996722344784116, lift=1.742674896713656), OrderedStatistic(items_base=frozenset({'Residential Building/House', 'Nonmajor Within Lower IQR'}), items_add=frozenset({'Noise - Residential'}), confidence=1.0, lift=1.7423961720278722)])
# RelationRecord(items=frozenset({'VC Within Lower IQR', 'Nonmajor Within Lower IQR', 'Noise - Residential'}), support=0.19338678070620421, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Nonmajor Within Lower IQR', 'Noise - Residential'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.7819492593759849, lift=1.5300931833897309), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Noise - Residential'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.8037898135599627, lift=1.5737641766201655)])
# RelationRecord(items=frozenset({'Population Higher than IQR', 'Residential Building/House', 'Noise - Residential'}), support=0.157257517132886, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Population Higher than IQR', 'Noise - Residential'}), items_add=frozenset({'Residential Building/House'}), confidence=0.9965138007392226, lift=1.7423102771445285), OrderedStatistic(items_base=frozenset({'Population Higher than IQR', 'Residential Building/House'}), items_add=frozenset({'Noise - Residential'}), confidence=1.0, lift=1.7423961720278722)])
# ...
# RelationRecord(items=frozenset({'VC Within Lower IQR', 'MANHATTAN', 'Major Within Lower IQR', 'NEW YORK', 'Population Within Lower IQR'}), support=0.18607311200500395, ordered_statistics=[OrderedStatistic(items_base=frozenset({'MANHATTAN', 'Major Within Lower IQR', 'NEW YORK', 'Population Within Lower IQR'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.9457773053063893, lift=1.8506666391740796), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'MANHATTAN', 'Major Within Lower IQR', 'NEW YORK'}), items_add=frozenset({'Population Within Lower IQR'}), confidence=0.7693454219281237, lift=1.4894399125910305), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'MANHATTAN', 'Major Within Lower IQR', 'Population Within Lower IQR'}), items_add=frozenset({'NEW YORK'}), confidence=1.0, lift=3.348266150517056), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'MANHATTAN', 'NEW YORK', 'Population Within Lower IQR'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.8711868942593961, lift=1.7177156610742812), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Major Within Lower IQR', 'NEW YORK', 'Population Within Lower IQR'}), items_add=frozenset({'MANHATTAN'}), confidence=0.9999720751318578, lift=3.3480197447518925)])
# RelationRecord(items=frozenset({'VC Within Lower IQR', 'MANHATTAN', 'Nonmajor Within Lower IQR', 'NEW YORK', 'Misd Within Lower IQR'}), support=0.19775809423720578, ordered_statistics=[OrderedStatistic(items_base=frozenset({'MANHATTAN', 'Nonmajor Within Lower IQR', 'NEW YORK', 'Misd Within Lower IQR'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=1.0, lift=1.9567678657446184), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'MANHATTAN', 'NEW YORK', 'Misd Within Lower IQR'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.8662518422415313, lift=1.6960604554230825), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'MANHATTAN', 'Nonmajor Within Lower IQR', 'Misd Within Lower IQR'}), items_add=frozenset({'NEW YORK'}), confidence=0.9998949086526304, lift=3.347914276715946), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'MANHATTAN', 'Nonmajor Within Lower IQR', 'NEW YORK'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.8786488319408972, lift=1.7317208675625924), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Nonmajor Within Lower IQR', 'NEW YORK', 'Misd Within Lower IQR'}), items_add=frozenset({'MANHATTAN'}), confidence=0.9999737250922084, lift=3.3480252690059884)])
# RelationRecord(items=frozenset({'VC Within Lower IQR', 'MANHATTAN', 'NEW YORK', 'Population Within Lower IQR', 'Misd Within Lower IQR'}), support=0.16825010408662605, ordered_statistics=[OrderedStatistic(items_base=frozenset({'MANHATTAN', 'NEW YORK', 'Population Within Lower IQR', 'Misd Within Lower IQR'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.9877068089179017, lift=1.93271294446771), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'MANHATTAN', 'NEW YORK', 'Misd Within Lower IQR'}), items_add=frozenset({'Population Within Lower IQR'}), confidence=0.7369961931750285, lift=1.4268123449561394), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'MANHATTAN', 'Population Within Lower IQR', 'Misd Within Lower IQR'}), items_add=frozenset({'NEW YORK'}), confidence=1.0, lift=3.348266150517056), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'MANHATTAN', 'NEW YORK', 'Population Within Lower IQR'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.7877402815410862, lift=1.5525500452222654), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'NEW YORK', 'Population Within Lower IQR', 'Misd Within Lower IQR'}), items_add=frozenset({'MANHATTAN'}), confidence=0.9999691170963894, lift=3.348009840914175)])
# RelationRecord(items=frozenset({'VC Within Lower IQR', 'MANHATTAN', 'Nonmajor Within Lower IQR', 'NEW YORK', 'Population Within Lower IQR'}), support=0.1670147046310592, ordered_statistics=[OrderedStatistic(items_base=frozenset({'MANHATTAN', 'Nonmajor Within Lower IQR', 'NEW YORK', 'Population Within Lower IQR'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.9998172486196439, lift=1.9564102637161171), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'MANHATTAN', 'Nonmajor Within Lower IQR', 'NEW YORK'}), items_add=frozenset({'Population Within Lower IQR'}), confidence=0.742054456517034, lift=1.4366050584697876), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'MANHATTAN', 'NEW YORK', 'Population Within Lower IQR'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.7819561905283229, lift=1.5310154714321265), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'MANHATTAN', 'Nonmajor Within Lower IQR', 'Population Within Lower IQR'}), items_add=frozenset({'NEW YORK'}), confidence=1.0, lift=3.348266150517056), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Nonmajor Within Lower IQR', 'NEW YORK', 'Population Within Lower IQR'}), items_add=frozenset({'MANHATTAN'}), confidence=0.999968888664196, lift=3.348009076097324)])
# RelationRecord(items=frozenset({'VC Within Lower IQR', 'Major Within Lower IQR', 'Nonmajor Within Lower IQR', 'NEW YORK', 'Misd Within Lower IQR'}), support=0.17114309524072427, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Major Within Lower IQR', 'Nonmajor Within Lower IQR', 'NEW YORK', 'Misd Within Lower IQR'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=1.0, lift=1.9567678657446184), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Major Within Lower IQR', 'NEW YORK', 'Misd Within Lower IQR'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.8486012792352929, lift=1.6615018888826982), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Major Within Lower IQR', 'Nonmajor Within Lower IQR', 'NEW YORK'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.8853410301297322, lift=1.7449104591629938), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Nonmajor Within Lower IQR', 'NEW YORK', 'Misd Within Lower IQR'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.8653936473841687, lift=1.7062931397397432)])
# RelationRecord(items=frozenset({'Major Within Lower IQR', 'Nonmajor Within Lower IQR', 'Noise - Residential', 'Residential Building/House', 'Misd Within Lower IQR'}), support=0.16606444732112527, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Major Within Lower IQR', 'Nonmajor Within Lower IQR', 'Noise - Residential', 'Misd Within Lower IQR'}), items_add=frozenset({'Residential Building/House'}), confidence=0.9963834480393455, lift=1.7420823677583455), OrderedStatistic(items_base=frozenset({'Major Within Lower IQR', 'Residential Building/House', 'Noise - Residential', 'Misd Within Lower IQR'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.8956421214881245, lift=1.7536045643914417), OrderedStatistic(items_base=frozenset({'Major Within Lower IQR', 'Nonmajor Within Lower IQR', 'Residential Building/House', 'Misd Within Lower IQR'}), items_add=frozenset({'Noise - Residential'}), confidence=1.0, lift=1.7423961720278722), OrderedStatistic(items_base=frozenset({'Major Within Lower IQR', 'Nonmajor Within Lower IQR', 'Noise - Residential', 'Residential Building/House'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.9012111556031809, lift=1.7761887428801642), OrderedStatistic(items_base=frozenset({'Residential Building/House', 'Nonmajor Within Lower IQR', 'Noise - Residential', 'Misd Within Lower IQR'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.7995434218344435, lift=1.5764565174749028)])
# RelationRecord(items=frozenset({'VC Within Lower IQR', 'Major Within Lower IQR', 'Residential Building/House', 'Noise - Residential', 'Misd Within Lower IQR'}), support=0.16215299857169116, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Major Within Lower IQR', 'Residential Building/House', 'Noise - Residential', 'Misd Within Lower IQR'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.8745463462481609, lift=1.7112841874427678), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Major Within Lower IQR', 'Noise - Residential', 'Misd Within Lower IQR'}), items_add=frozenset({'Residential Building/House'}), confidence=0.9965073067143536, lift=1.7422989229552932), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Major Within Lower IQR', 'Residential Building/House', 'Misd Within Lower IQR'}), items_add=frozenset({'Noise - Residential'}), confidence=1.0, lift=1.7423961720278722), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Major Within Lower IQR', 'Residential Building/House', 'Noise - Residential'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.8741849862384357, lift=1.722923115296244), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Residential Building/House', 'Noise - Residential', 'Misd Within Lower IQR'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.885967776279367, lift=1.746859066120312)])
# RelationRecord(items=frozenset({'VC Within Lower IQR', 'Major Within Lower IQR', 'Nonmajor Within Lower IQR', 'Population Within Lower IQR', 'Misd Within Lower IQR'}), support=0.19328545456789273, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Major Within Lower IQR', 'Nonmajor Within Lower IQR', 'Population Within Lower IQR', 'Misd Within Lower IQR'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.9145218243785207, lift=1.7895069184660326), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Major Within Lower IQR', 'Population Within Lower IQR', 'Misd Within Lower IQR'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.8673597873419492, lift=1.6982297343555648), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Major Within Lower IQR', 'Nonmajor Within Lower IQR', 'Population Within Lower IQR'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.8904751930097552, lift=1.7550293333634652), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Nonmajor Within Lower IQR', 'Population Within Lower IQR', 'Misd Within Lower IQR'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.8962925927153016, lift=1.7672164647526674)])
# RelationRecord(items=frozenset({'VC Within Lower IQR', 'Major Within Lower IQR', 'Nonmajor Within Lower IQR', 'Noise - Residential', 'Residential Building/House'}), support=0.15787781496677997, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Major Within Lower IQR', 'Nonmajor Within Lower IQR', 'Noise - Residential', 'Residential Building/House'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.8567833173537872, lift=1.6765260633039643), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Major Within Lower IQR', 'Nonmajor Within Lower IQR', 'Noise - Residential'}), items_add=frozenset({'Residential Building/House'}), confidence=0.9964130670940925, lift=1.7421341538785646), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Major Within Lower IQR', 'Residential Building/House', 'Noise - Residential'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.8511369923453487, lift=1.6664666376111221), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Major Within Lower IQR', 'Nonmajor Within Lower IQR', 'Residential Building/House'}), items_add=frozenset({'Noise - Residential'}), confidence=1.0, lift=1.7423961720278722), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Residential Building/House', 'Nonmajor Within Lower IQR', 'Noise - Residential'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.8194110607312017, lift=1.6156294603949657)])
# RelationRecord(items=frozenset({'VC Within Lower IQR', 'Residential Building/House', 'Nonmajor Within Lower IQR', 'Noise - Residential', 'Misd Within Lower IQR'}), support=0.1661963012062357, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Residential Building/House', 'Nonmajor Within Lower IQR', 'Noise - Residential', 'Misd Within Lower IQR'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=0.8001782531194296, lift=1.5657630925717632), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Nonmajor Within Lower IQR', 'Noise - Residential', 'Misd Within Lower IQR'}), items_add=frozenset({'Residential Building/House'}), confidence=0.9957581441686156, lift=1.7409890829894816), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Residential Building/House', 'Noise - Residential', 'Misd Within Lower IQR'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.9080594790261907, lift=1.7779168810344481), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Residential Building/House', 'Nonmajor Within Lower IQR', 'Misd Within Lower IQR'}), items_add=frozenset({'Noise - Residential'}), confidence=1.0, lift=1.7423961720278722), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Residential Building/House', 'Nonmajor Within Lower IQR', 'Noise - Residential'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.862585332142195, lift=1.7000614641738092)])
# RelationRecord(items=frozenset({'NEW YORK', 'VC Within Lower IQR', 'Major Within Lower IQR', 'Misd Within Lower IQR', 'MANHATTAN', 'Nonmajor Within Lower IQR'}), support=0.17113789902850318, ordered_statistics=[OrderedStatistic(items_base=frozenset({'MANHATTAN', 'Major Within Lower IQR', 'Nonmajor Within Lower IQR', 'NEW YORK', 'Misd Within Lower IQR'}), items_add=frozenset({'VC Within Lower IQR'}), confidence=1.0, lift=1.9567678657446184), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'MANHATTAN', 'Major Within Lower IQR', 'NEW YORK', 'Misd Within Lower IQR'}), items_add=frozenset({'Nonmajor Within Lower IQR'}), confidence=0.8485973783374666, lift=1.6614942511978805), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'MANHATTAN', 'Major Within Lower IQR', 'Nonmajor Within Lower IQR', 'Misd Within Lower IQR'}), items_add=frozenset({'NEW YORK'}), confidence=0.9998785638659193, lift=3.347859550019864), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'MANHATTAN', 'Major Within Lower IQR', 'Nonmajor Within Lower IQR', 'NEW YORK'}), items_add=frozenset({'Misd Within Lower IQR'}), confidence=0.8853379479511434, lift=1.7449043845256804), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'MANHATTAN', 'Nonmajor Within Lower IQR', 'NEW YORK', 'Misd Within Lower IQR'}), items_add=frozenset({'Major Within Lower IQR'}), confidence=0.865390110521735, lift=1.7062861661224478), OrderedStatistic(items_base=frozenset({'VC Within Lower IQR', 'Major Within Lower IQR', 'Nonmajor Within Lower IQR', 'NEW YORK', 'Misd Within Lower IQR'}), items_add=frozenset({'MANHATTAN'}), confidence=0.9999696382012153, lift=3.3480115856321424)])

# %%
thresh = 0.10
min_sup = thresh*len(transactions)
patterns1 = pyfpgrowth.find_frequent_patterns(transactions, min_sup)

# %%
patterns_sorted1 = sorted(patterns1.items(), key=lambda x: x[1],reverse=True)

# %%
rules1 = pyfpgrowth.generate_association_rules(patterns1, 0.7)

# %%
rules_sorted1 = sorted(rules1.items(), key=lambda x: x[1],reverse=True)
